# %% [markdown]
# import libraries

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
import json
import PyPDF2

# %%
pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (1.58.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting openai
#   Downloading openai-1.59.6-py3-none-any.whl (454 kB)
#      ---------------------------------------- 0.0/454.8 kB ? eta -:--:--
#      --------------- ---------------------- 184.3/454.8 kB 5.4 MB/s eta 0:00:01
#      -------------------------------------- 454.8/454.8 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (0.25.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (2.5.1)
# Requirement already satisfied: sniffio in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\roohana karim\appdata\roaming\python\python311\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.3)
# Requirement already satisfied: colorama in c:\users\roohana karim\appdata\roaming\python\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from httpcore->httpx<1,>=0.23.0->openai) (0.14.0)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.58.1
#     Uninstalling openai-1.58.1:
#       Successfully uninstalled openai-1.58.1
# Successfully installed openai-1.59.6

# %% [markdown]
# Parsing PDFS

# %%
def load_papers_from_jsonl(file_path):
    papers = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                try:
                    paper = json.loads(line.strip())
                    papers.append(paper)
                except json.JSONDecodeError:
                    print(f"Skipping a line due to JSON decoding error.")
    except FileNotFoundError:
        print(f"The file {file_path} was not found.")
    except Exception as e:
        print(f"An unexpected error occurred while reading the file: {e}")

    print(f"Loaded papers from {file_path}.")
    return papers

# Specify the path to your JSONL file
jsonl_file_path = "extracted_test_papers_new_NEWEST.jsonl"

# Load papers
papers = load_papers_from_jsonl(jsonl_file_path)

# Display loaded papers (Optional)
for i, paper in enumerate(papers[:]):  # Limit display to the first 5 papers for readability
    print(f"Paper {i+1}:")
    print(f"Title: {paper.get('title', 'No title provided')}")
    print("Content:")
    print(paper.get('content', 'No content provided')[:100])  # Print first 500 characters of content
    print("-" * 50)  # Separator
# Out:
# Loaded papers from extracted_test_papers_new_NEWEST.jsonl.
# Paper 1:
# Title: NetCA T: Practical Cache Attacks from the Network
# Content:
# NetCA T: Practical Cache Attacks from the Network
# Michael Kurth∗§, Ben Gras∗, Dennis Andriesse∗, Cri
# --------------------------------------------------
# Paper 2:
# Title: (Un)informed Consent: Studying GDPR Consent Notices in the
# Content:
# (Un)informed Consent: Studying GDPR Consent Notices in the
# Field
# Christine Utz
# Ruhr-Universität Boch
# --------------------------------------------------
# Paper 3:
# Title: (Un)linkable Pseudonyms for Governmental Databases
# Content:
# (Un)linkable Pseudonyms for Governmental Databases
# Jan Camenisch
# IBM Research – Zurich
# jca@zurich.ib
# --------------------------------------------------
# Paper 4:
# Title: ObliviSync: Practical Oblivious
# Content:
# ObliviSync: Practical Oblivious
# File Backup and Synchronization
# Adam J. Aviv, Seung Geol Choi, Travi
# --------------------------------------------------
# Paper 5:
# Title: SYMTCP: Eluding Stateful Deep Packet Inspection
# Content:
# SYMTCP: Eluding Stateful Deep Packet Inspection
# with Automated Discrepancy Discovery
# Zhongjie Wang,
# --------------------------------------------------
# Paper 6:
# Title: Interpretable Federated Transformer Log Learning
# Content:
# Interpretable Federated Transformer Log Learning
# for Cloud Threat Forensics
# Gonzalo De La Torre Parr
# --------------------------------------------------
# Paper 7:
# Title: How to Count Bots
# Content:
# How to Count Bots
# in Longitudinal Datasets of IP Addresses
# Leon B ¨ockDave LevinyRamakrishna Padman
# --------------------------------------------------
# Paper 8:
# Title: Testability Tarpits: the Impact of Code Patterns
# Content:
# Testability Tarpits: the Impact of Code Patterns
# on the Security Testing of Web Applications
# Feras A
# --------------------------------------------------
# Paper 9:
# Title: FedCRI: Federated Mobile Cyber-Risk Intelligence
# Content:
# FedCRI: Federated Mobile Cyber-Risk Intelligence
# Hossein Fereidooni, Alexandra Dmitrienkoy, Phillip
# --------------------------------------------------
# Paper 10:
# Title: Hybrid Trust Multi-party Computation with
# Content:
# Hybrid Trust Multi-party Computation with
# Trusted Execution Environment
# Pengfei Wuy, Jianting Ningz,
# --------------------------------------------------
# Paper 11:
# Title: A Lightweight IoT Cryptojacking Detection
# Content:
# A Lightweight IoT Cryptojacking Detection
# Mechanism in Heterogeneous Smart Home
# Networks
# Ege Tekiner
# --------------------------------------------------
# Paper 12:
# Title: Hiding My Real Self! Protecting Intellectual
# Content:
# Hiding My Real Self! Protecting Intellectual
# Property in Additive Manufacturing Systems Against
# Opti
# --------------------------------------------------
# Paper 13:
# Title: Towards Precise Reporting of
# Content:
# Towards Precise Reporting of
# Cryptographic Misuses
# Yikang Chen∗, Yibo Liu†, Ka Lok Wu∗, Duc V . Le‡,
# --------------------------------------------------
# Paper 14:
# Title: Understanding and Analyzing Appraisal Systems in
# Content:
# Understanding and Analyzing Appraisal Systems in
# the Underground Marketplaces
# Zhengyi Li, Xiaojing L
# --------------------------------------------------
# Paper 15:
# Title: Understanding Route Origin Validation (ROV)
# Content:
# Understanding Route Origin Validation (ROV)
# Deployment in the Real World and Why MANRS
# Action 1 Is N
# --------------------------------------------------
# Paper 16:
# Title: MPCD IFF: Testing and Repairing MPC-Hardened
# Content:
# MPCD IFF: Testing and Repairing MPC-Hardened
# Deep Learning Models
# Qi Pangy
# Carnegie Mellon Universit
# --------------------------------------------------
# Paper 17:
# Title: DorPatch: Distributed and Occlusion-Robust
# Content:
# DorPatch: Distributed and Occlusion-Robust
# Adversarial Patch to Evade Certifiable Defenses
# Chaoxiang
# --------------------------------------------------
# Paper 18:
# Title: Differentially Private Publishing of High-dimensional Data
# Content:
# Differentially Private Publishing of High-dimensional Data
# Using Sensitivity Control
# Wei-Y en Day
# De
# --------------------------------------------------
# Paper 19:
# Title: 27 Years and 81 Million Opportunities Later:
# Content:
# 27 Years and 81 Million Opportunities Later:
# Investigating the Use of Email Encryption for an
# Entire
# --------------------------------------------------
# Paper 20:
# Title: 28 Blinks Later: Tackling Practical Challenges of
# Content:
# 28 Blinks Later: Tackling Practical Challenges of
# Eye Movement Biometrics
# Simon Eberz
# simon.eberz@cs
# --------------------------------------------------
# Paper 21:
# Title: High Fidelity Data Reduction for Big Data Security
# Content:
# High Fidelity Data Reduction for Big Data Security
# Dependency Analyses
# Zhang Xuy1
# zhang@nofutznetwor
# --------------------------------------------------
# Paper 22:
# Title: Identifying Open-Source License Violation and 1-day Security
# Content:
# Identifying Open-Source License Violation and 1-day Security
# Risk at Large Scale
# Ruian Duan∗
# Georgia
# --------------------------------------------------
# Paper 23:
# Title: POISED: Spotting Twitter Spam Off the Beaten Paths
# Content:
# POISED: Spotting Twitter Spam Off the Beaten Paths
# Shirin Nilizadeh
# UC Santa Barbara
# California, USA
# --------------------------------------------------
# Paper 24:
# Title: MineSweeper: An In-depth Look into Drive-by
# Content:
# MineSweeper: An In-depth Look into Drive-by
# Cryptocurrency Mining and Its Defense
# Radhesh Krishnan K
# --------------------------------------------------
# Paper 25:
# Title: Quantitative Verification of Neural Networks
# Content:
# Quantitative Verification of Neural Networks
# and Its Security Applications
# Teodora Baluta
# teobaluta@
# --------------------------------------------------
# Paper 26:
# Title: Poirot: Aligning Attack Behavior with Kernel Audit Records for
# Content:
# Poirot: Aligning Attack Behavior with Kernel Audit Records for
# Cyber Threat Hunting
# Sadegh M. Milaje
# --------------------------------------------------
# Paper 27:
# Title: Preparing Network Intrusion Detection Deep Learning Models
# Content:
# Preparing Network Intrusion Detection Deep Learning Models
# with Minimal Data Using Adversarial Domai
# --------------------------------------------------
# Paper 28:
# Title: EIGER: Automated IOC Generation for Accurate and
# Content:
# EIGER: Automated IOC Generation for Accurate and
# Interpretable Endpoint Malware Detection
# Yuma Kurog
# --------------------------------------------------
# Paper 29:
# Title: PDiff: Semantic-based Patch Presence Testing
# Content:
# PDiff: Semantic-based Patch Presence Testing
# for Downstream Kernels
# Zheyue Jiang∗
# Fudan University
# z
# --------------------------------------------------
# Paper 30:
# Title: Filtering DDoS Attacks from Unlabeled Network Traffic Data
# Content:
# Filtering DDoS Attacks from Unlabeled Network Traffic Data
# Using Online Deep Learning
# Wesley Joon-Wi
# --------------------------------------------------
# Paper 31:
# Title: Recompose Event Sequences vs. Predict Next Events: A Novel
# Content:
# Recompose Event Sequences vs. Predict Next Events: A Novel
# Anomaly Detection Approach for Discrete E
# --------------------------------------------------
# Paper 32:
# Title: Honest-but-Curious Nets: Sensitive Attributes of Private Inputs
# Content:
# Honest-but-Curious Nets: Sensitive Attributes of Private Inputs
# Can Be Secretly Coded into the Class
# --------------------------------------------------
# Paper 33:
# Title: Consistency Analysis of Data-Usage Purposes in Mobile Apps
# Content:
# Consistency Analysis of Data-Usage Purposes in Mobile Apps
# Duc Bui, Yuan Yao, Kang G. Shin
# Universit
# --------------------------------------------------
# Paper 34:
# Title: C3PO: Large-Scale Study of Covert Monitoring of C&C Servers
# Content:
# C3PO: Large-Scale Study of Covert Monitoring of C&C Servers
# via Over-Permissioned Protocol Infiltrat
# --------------------------------------------------
# Paper 35:
# Title: Cert-RNN: Towards Certifying the Robustness of Recurrent
# Content:
# Cert-RNN: Towards Certifying the Robustness of Recurrent
# Neural Networks
# Tianyu Du
# Zhejiang Universi
# --------------------------------------------------
# Paper 36:
# Title: LEAP: Leakage-Abuse Attack on Efficiently Deployable,
# Content:
# LEAP: Leakage-Abuse Attack on Efficiently Deployable,
# Efficiently Searchable Encryption with Partial
# --------------------------------------------------
# Paper 37:
# Title: Dissecting Click Fraud Autonomy in the Wild
# Content:
# Dissecting Click Fraud Autonomy in the Wild
# Tong Zhu
# tongzhu@sjtu .edu.cn
# Shanghai Jiao Tong Univers
# --------------------------------------------------
# Paper 38:
# Title: Periscope: A Keystroke Inference Attack Using Human Coupled
# Content:
# Periscope: A Keystroke Inference Attack Using Human Coupled
# Electromagnetic Emanations
# Wenqiang Jin∗
# --------------------------------------------------
# Paper 39:
# Title: Secure Multi-party Computation of Differentially Private Heavy
# Content:
# Secure Multi-party Computation of Differentially Private Heavy
# Hitters
# Jonas Böhler
# SAP Security Res
# --------------------------------------------------
# Paper 40:
# Title: ZKCPlus: Optimized Fair-exchange Protocol
# Content:
# ZKCPlus: Optimized Fair-exchange Protocol
# Supporting Practical and Flexible Data Exchange
# Yun Li
# Tsi
# --------------------------------------------------
# Paper 41:
# Title: Locally Private Graph Neural Networks
# Content:
# Locally Private Graph Neural Networks
# Sina Sajadmanesh
# sajadmanesh@idiap.ch
# Idiap Research Institute
# --------------------------------------------------
# Paper 42:
# Title: All your Credentials are Belong to Us:
# Content:
# All your Credentials are Belong to Us:
# On Insecure WPA2-Enterprise Configurations
# Man Hong Hue
# The C
# --------------------------------------------------
# Paper 43:
# Title: On the Robustness of Domain Constraints
# Content:
# On the Robustness of Domain Constraints
# Ryan Sheatsley
# The Pennsylvania State University
# State Colle
# --------------------------------------------------
# Paper 44:
# Title: Quantifying and Mitigating Privacy Risks of
# Content:
# Quantifying and Mitigating Privacy Risks of
# Contrastive Learning
# Xinlei He and Yang Zhang
# CISPA Helm
# --------------------------------------------------
# Paper 45:
# Title: Membership Leakage in Label-Only Exposures
# Content:
# Membership Leakage in Label-Only Exposures
# Zheng Li and Yang Zhang
# CISPA Helmholtz Center for Inform
# --------------------------------------------------
# Paper 46:
# Title: SugarCoat: Programmatically Generating Privacy-Preserving,
# Content:
# SugarCoat: Programmatically Generating Privacy-Preserving,
# Web-Compatible Resource Replacements for
# --------------------------------------------------
# Paper 47:
# Title: DataLens: Scalable Privacy Preserving Training via Gradient
# Content:
# DataLens: Scalable Privacy Preserving Training via Gradient
# Compression and Aggregation
# Boxin Wang∗
#
# --------------------------------------------------
# Paper 48:
# Title: On-device IoT Certificate Revocation Checking with Small
# Content:
# On-device IoT Certificate Revocation Checking with Small
# Memory and Low Latency
# Xiaofeng Shi
# xshi24@
# --------------------------------------------------
# Paper 49:
# Title: Oblivious Linear Group Actions and Applications
# Content:
# Oblivious Linear Group Actions and Applications
# Nuttapong Attrapadung
# AIST, Japan
# n.attrapadung@aist
# --------------------------------------------------
# Paper 50:
# Title: Revisiting Fuzzy Signatures: Towards a More Risk-Free
# Content:
# Revisiting Fuzzy Signatures: Towards a More Risk-Free
# Cryptographic Authentication System based on B
# --------------------------------------------------
# Paper 51:
# Title: An In-Depth Symbolic Security Analysis of the ACME Standard
# Content:
# An In-Depth Symbolic Security Analysis of the ACME Standard
# Karthikeyan Bhargavan
# karthikeyan.bharga
# --------------------------------------------------
# Paper 52:
# Title: Differential Privacy for Directional Data
# Content:
# Differential Privacy for Directional Data
# Benjamin Weggenmann
# SAP Security Research
# Karlsruhe, Germa
# --------------------------------------------------
# Paper 53:
# Title: Deterrence of Intelligent DDoS via Multi-Hop Traffic Divergence
# Content:
# Deterrence of Intelligent DDoS via Multi-Hop Traffic Divergence
# Yuanjie Li∗, Hewu Li∗, Zhizheng Lv∗,
# --------------------------------------------------
# Paper 54:
# Title: HardsHeap: A Universal and Extensible Framework for
# Content:
# HardsHeap: A Universal and Extensible Framework for
# Evaluating Secure Allocators
# Insu Yun∗
# KAIST
# ins
# --------------------------------------------------
# Paper 55:
# Title: “Hello,It’s Me”:DeepLearning-based SpeechSynthesis A/t_tack s
# Content:
# “Hello,It’s Me”:DeepLearning-based SpeechSynthesis A/t_tack s
# in theRealWorld
# EmilyWenger∗
# ewenger@u
# --------------------------------------------------
# Paper 56:
# Title: Demons in the Shared Kernel: Abstract Resource Attacks Against
# Content:
# Demons in the Shared Kernel: Abstract Resource Attacks Against
# OS-level Virtualization
# Nanzi Yang∗
# X
# --------------------------------------------------
# Paper 57:
# Title: DoubleX: Statically Detecting Vulnerable Data Flows
# Content:
# DoubleX: Statically Detecting Vulnerable Data Flows
# in Browser Extensions at Scale
# Aurore Fass, Doli
# --------------------------------------------------
# Paper 58:
# Title: EncoderMI: Membership Inference against Pre-trained
# Content:
# EncoderMI: Membership Inference against Pre-trained
# Encoders in Contrastive Learning
# Hongbin Liu∗
# Du
# --------------------------------------------------
# Paper 59:
# Title: Continuous Release of Data Streams under both Centralized
# Content:
# Continuous Release of Data Streams under both Centralized
# and Local Differential Privacy
# Tianhao Wan
# --------------------------------------------------
# Paper 60:
# Title: Robust Detection of Machine-induced Audio Attacks
# Content:
# Robust Detection of Machine-induced Audio Attacks
# in Intelligent Audio Systems with Microphone Array
# --------------------------------------------------
# Paper 61:
# Title: When Machine Unlearning Jeopardizes Privacy
# Content:
# When Machine Unlearning Jeopardizes Privacy
# Min Chen1∗Zhikun Zhang1∗Tianhao Wang2,3†Michael Backes1
#
# --------------------------------------------------
# Paper 62:
# Title: New Directions in Automated Traffic Analysis
# Content:
# New Directions in Automated Traffic Analysis
# Jordan Holland
# Princeton University
# Princeton, New Jers
# --------------------------------------------------
# Paper 63:
# Title: I Can See the Light: Attacks on Autonomous Vehicles Using
# Content:
# I Can See the Light: Attacks on Autonomous Vehicles Using
# Invisible Lights
# Wei Wang, Yao Yao, Xin Li
# --------------------------------------------------
# Paper 64:
# Title: Membership Inference Attacks Against Recommender Systems
# Content:
# Membership Inference Attacks Against Recommender Systems
# Minxing Zhang1,2∗Zhaochun Ren1∗†Zihan Wang1
# --------------------------------------------------
# Paper 65:
# Title: Learning Security Classifiers with
# Content:
# Learning Security Classifiers with
# Verified Global Robustness Properties
# Yizheng Chen
# UC Berkeley
# 1z
# --------------------------------------------------
# Paper 66:
# Title: One Glitch to Rule Them All: Fault Injection Attacks Against
# Content:
# One Glitch to Rule Them All: Fault Injection Attacks Against
# AMD’s Secure Encrypted Virtualization
# R
# --------------------------------------------------
# Paper 67:
# Title: DPGen: Automated Program Synthesis for Differential Privacy
# Content:
# DPGen: Automated Program Synthesis for Differential Privacy
# Yuxin Wang
# Pennsylvania State University
# --------------------------------------------------
# Paper 68:
# Title: Mining in
# Content:
# Mining in
# Logarithmic Space
# Aggelos Kiayias
# University of Edinburgh
# IOHKNikos Leonardos
# University o
# --------------------------------------------------
# Paper 69:
# Title: A Formally Verified Configuration
# Content:
# A Formally Verified Configuration
# for Hardware Security Modules in the Cloud
# Riccardo Focardi
# focard
# --------------------------------------------------
# Paper 70:
# Title: Epsolute: Efficiently Querying Databases While Providing
# Content:
# Epsolute: Efficiently Querying Databases While Providing
# Differential Privacy
# Dmytro Bogatov
# Boston
# --------------------------------------------------
# Paper 71:
# Title: Compressed Oblivious Encoding for Homomorphically
# Content:
# Compressed Oblivious Encoding for Homomorphically
# Encrypted Search
# Seung Geol Choi
# United States Nav
# --------------------------------------------------
# Paper 72:
# Title: WristPrint: Characterizing User Re-identification Risks from
# Content:
# WristPrint: Characterizing User Re-identification Risks from
# Wrist-worn Accelerometry Data
# Nazir Sal
# --------------------------------------------------
# Paper 73:
# Title: APECS: A Distributed A ccess Control Framework for P ervasive
# Content:
# APECS: A Distributed A ccess Control Framework for P ervasive
# Edge C omputing S ervices
# Sean Dougher
# --------------------------------------------------
# Paper 74:
# Title: Reverse Attack: Black-box Attacks on Collaborative
# Content:
# Reverse Attack: Black-box Attacks on Collaborative
# Recommendation
# Yihe Zhang
# yihe.zhang1@louisiana.e
# --------------------------------------------------
# Paper 75:
# Title: Asynchronous Data Dissemination and its Applications
# Content:
# Asynchronous Data Dissemination and its Applications
# Sourav Das
# University of Illinois at
# Urbana-Cha
# --------------------------------------------------
# Paper 76:
# Title: V-Shuttle: Scalable and Semantics-Aware Hypervisor Virtual
# Content:
# V-Shuttle: Scalable and Semantics-Aware Hypervisor Virtual
# Device Fuzzing
# Gaoning Pan
# pgn@zju.edu.cn
# --------------------------------------------------
# Paper 77:
# Title: The Security of ChaCha20-Poly1305 in the Multi-User Setting
# Content:
# The Security of ChaCha20-Poly1305 in the Multi-User Setting
# Jean Paul Degabriele
# jean_paul.degabriel
# --------------------------------------------------
# Paper 78:
# Title: AI-Lancet: Locating Error-inducing Neurons
# Content:
# AI-Lancet: Locating Error-inducing Neurons
# to Optimize Neural Networks
# Yue Zhao1,2, Hong Zhu1,2, Kai
# --------------------------------------------------
# Paper 79:
# Title: TableGAN-MCA: Evaluating Membership Collisions of
# Content:
# TableGAN-MCA: Evaluating Membership Collisions of
# GAN-Synthesized Tabular Data Releasing
# Aoting Hu
# S
# --------------------------------------------------
# Paper 80:
# Title: “I need a better description”:
# Content:
# “I need a better description”:
# An Investigation Into User Expectations For Differential Privacy
# Rach
# --------------------------------------------------
# Paper 81:
# Title: A One-Pass Distributed and Private Sketch for Kernel Sums
# Content:
# A One-Pass Distributed and Private Sketch for Kernel Sums
# with Applications to Machine Learning at S
# --------------------------------------------------
# Paper 82:
# Title: TSS: Transformation-Specific Smoothing
# Content:
# TSS: Transformation-Specific Smoothing
# for Robustness Certification
# Linyi Li*
# University of Illinois
# --------------------------------------------------
# Paper 83:
# Title: Unleashing the Tiger: Inference Attacks on Split Learning
# Content:
# Unleashing the Tiger: Inference Attacks on Split Learning
# Dario Pasquini
# Sapienza University of Rome
# --------------------------------------------------
# Paper 84:
# Title: A Security Framework for Distributed Ledgers
# Content:
# A Security Framework for Distributed Ledgers
# Mike Graf
# mike.graf@sec.uni-stuttgart .de
# University of
# --------------------------------------------------
# Paper 85:
# Title: Automated Bug Hunting With Data-Driven Symbolic Root
# Content:
# Automated Bug Hunting With Data-Driven Symbolic Root
# Cause Analysis
# Carter Yagemann
# Georgia Institut
# --------------------------------------------------
# Paper 86:
# Title: This Sneaky Piggy Went to the Android Ad Market:
# Content:
# This Sneaky Piggy Went to the Android Ad Market:
# Misusing Mobile Sensors for Stealthy Data Exfiltrat
# --------------------------------------------------
# Paper 87:
# Title: Out of Sight,
# Content:
# Out of Sight,
# Out of Mind:
# Detecting Orphaned Web Pages at Internet-Scale
# Stijn Pletinckx
# TU Delft
# S
# --------------------------------------------------
# Paper 88:
# Title: Subpopulation Data Poisoning Attacks
# Content:
# Subpopulation Data Poisoning Attacks
# Matthew Jagielski
# jagielski@ccs.neu.edu
# Northeastern University
# --------------------------------------------------
# Paper 89:
# Title: VIP: Safeguard Value Invariant Property for
# Content:
# VIP: Safeguard Value Invariant Property for
# Thwarting Critical Memory Corruption Attacks
# Mohannad Is
# --------------------------------------------------
# Paper 90:
# Title: zkCNN: Zero Knowledge Proofs for Convolutional Neural
# Content:
# zkCNN: Zero Knowledge Proofs for Convolutional Neural
# Network Predictions and Accuracy
# Tianyi Liu
# Te
# --------------------------------------------------
# Paper 91:
# Title: Black-box Adversarial Attacks on Commercial Speech Platforms
# Content:
# Black-box Adversarial Attacks on Commercial Speech Platforms
# with Minimal Information
# Baolin Zheng1,
# --------------------------------------------------
# Paper 92:
# Title: AHEAD: Adaptive Hierarchical Decomposition for Range Query
# Content:
# AHEAD: Adaptive Hierarchical Decomposition for Range Query
# under Local Differential Privacy
# Linkang
# --------------------------------------------------
# Paper 93:
# Title: BAPM: Block Attention Profiling Model for Multi-tab Website
# Content:
# BAPM: Block Attention Profiling Model for Multi-tab Website
# Fingerprinting Attacks on Tor
# Zhong Guan
# --------------------------------------------------
# Paper 94:
# Title: CommanderGabble: A Universal Attack
# Content:
# CommanderGabble: A Universal Attack
# Against ASR Systems Leveraging Fast Speech
# Zhaohe Zhang
# Universi
# --------------------------------------------------
# Paper 95:
# Title: An Exploration of ARM System-Level Cache and GPU Side
# Content:
# An Exploration of ARM System-Level Cache and GPU Side
# Channels
# Patrick Cronin
# University of Delaware
# --------------------------------------------------
# Paper 96:
# Title: Two Souls in an Adversarial Image: Towards
# Content:
# Two Souls in an Adversarial Image: Towards
# Universal Adversarial Example Detection
# using Multi-view
# --------------------------------------------------
# Paper 97:
# Title: Can We Leverage Predictive Uncertainty to Detect Dataset Shift
# Content:
# Can We Leverage Predictive Uncertainty to Detect Dataset Shift
# and Adversarial Examples in Android M
# --------------------------------------------------
# Paper 98:
# Title: SODA: A System for Cyber Deception Orchestration and
# Content:
# SODA: A System for Cyber Deception Orchestration and
# Automation
# Md Sajidul Islam Sajid*, Jinpeng Wei
# --------------------------------------------------
# Paper 99:
# Title: TEEKAP : Self-Expiring Data Capsule using
# Content:
# TEEKAP : Self-Expiring Data Capsule using
# Trusted Execution Environment
# Mingyuan Gao
# mingyuan.gao@u.
# --------------------------------------------------
# Paper 100:
# Title: Try before You Buy: Privacy-preserving Data Evaluation on
# Content:
# Try before You Buy: Privacy-preserving Data Evaluation on
# Cloud-based Machine Learning Data Marketpl
# --------------------------------------------------
# Paper 101:
# Title: Program Obfuscation via ABI Debiasing
# Content:
# Program Obfuscation via ABI Debiasing
# David Demicco
# Computer Science
# Binghamton University
# United St
# --------------------------------------------------
# Paper 102:
# Title: Reproducible and Adaptable
# Content:
# Reproducible and Adaptable
# Log Data Generation for
# Sound Cybersecurity Experiments
# Rafael Uetz
# Fraun
# --------------------------------------------------
# Paper 103:
# Title: Platform-Oblivious Anti-Spam Gateway
# Content:
# Platform-Oblivious Anti-Spam Gateway
# Yihe Zhang
# yihe.zhang1@louisiana.edu
# University of Louisiana at
# --------------------------------------------------
# Paper 104:
# Title: Model Extraction Attacks on Graph Neural Networks:
# Content:
# Model Extraction Attacks on Graph Neural Networks:
# Taxonomy and Realisation
# Bang Wu
# bang.wu@monash.e
# --------------------------------------------------
# Paper 105:
# Title: SteinerLog : Prize Collecting the Audit Logs for Threat Hunting
# Content:
# SteinerLog : Prize Collecting the Audit Logs for Threat Hunting
# on Enterprise Network
# Bibek Bhattara
# --------------------------------------------------
# Paper 106:
# Title: WINK: Wireless Inference of Numerical Keystrokes via
# Content:
# WINK: Wireless Inference of Numerical Keystrokes via
# Zero-Training Spatiotemporal Analysis
# Edwin Yan
# --------------------------------------------------
# Paper 107:
# Title: Empirical Analysis of EIP-1559:
# Content:
# Empirical Analysis of EIP-1559:
# Transaction Fees, Waiting Times, and Consensus Security
# Yulin Liu‡
# S
# --------------------------------------------------
# Paper 108:
# Title: Constant Latency in Sleepy Consensus
# Content:
# Constant Latency in Sleepy Consensus
# Atsuki Momose∗
# University of Illinois at Urbana-Champaign
# Urban
# --------------------------------------------------
# Paper 109:
# Title: Graph Unlearning
# Content:
# Graph Unlearning
# Min Chen
# CISPA Helmholtz Center for
# Information Security, GermanyZhikun Zhang∗
# CISP
# --------------------------------------------------
# Paper 110:
# Title: SSLGuard: A Watermarking Scheme for Self-supervised
# Content:
# SSLGuard: A Watermarking Scheme for Self-supervised
# Learning Pre-trained Encoders
# Tianshuo Cong
# Inst
# --------------------------------------------------
# Paper 111:
# Title: Finding MNEMON: Reviving Memories of Node Embeddings
# Content:
# Finding MNEMON: Reviving Memories of Node Embeddings
# Yun Shen∗
# NetAppYufei Han
# InriaZhikun Zhang
# CIS
# --------------------------------------------------
# Paper 112:
# Title: 𝐴                      𝑆
# Content:
#
#
#
#
# --------------------------------------------------
# Paper 113:
# Title: Low-Latency Hardware Private Circuits
# Content:
# Low-Latency Hardware Private Circuits
# David Knichel
# firstname.lastname@rub.de
# Ruhr University Bochum
# --------------------------------------------------
# Paper 114:
# Title: Victory by KO: Attacking OpenPGP Using Key Overwriting
# Content:
# Victory by KO: Attacking OpenPGP Using Key Overwriting
# Lara Bruseghini∗
# ETH Zurich
# Switzerland
# larab
# --------------------------------------------------
# Paper 115:
# Title: Sleepy Channels:
# Content:
# Sleepy Channels:
# Bi-directional Payment Channels without Watchtowers
# Lukas Aumayr∗
# TU Wien
# Vienna, A
# --------------------------------------------------
# Paper 116:
# Title: Two-Client Inner-Product Functional Encryption
# Content:
# Two-Client Inner-Product Functional Encryption
# with an Application to Money-Laundering Detection
# Pao
# --------------------------------------------------
# Paper 117:
# Title: Distributed, Private, Sparse Histograms in the Two-Server Model
# Content:
# Distributed, Private, Sparse Histograms in the Two-Server Model
# James Bell
# Google
# London, UK
# jhbell@
# --------------------------------------------------
# Paper 118:
# Title: Understanding Real-world Threats to Deep Learning Models in
# Content:
# Understanding Real-world Threats to Deep Learning Models in
# Android Apps
# Zizhuang Deng
# SKLOIS, IIE,
# --------------------------------------------------
# Paper 119:
# Title: VRust: Automated Vulnerability Detection for Solana Smart
# Content:
# VRust: Automated Vulnerability Detection for Solana Smart
# Contracts
# Siwei Cui
# siweicui@tamu.edu
# Texa
# --------------------------------------------------
# Paper 120:
# Title: Truth Serum: Poisoning Machine Learning Models
# Content:
# Truth Serum: Poisoning Machine Learning Models
# to Reveal Their Secrets
# Florian Tramèr∗†
# ETH ZürichRe
# --------------------------------------------------
# Paper 121:
# Title: Automatic Detection of Speculative Execution Combinations
# Content:
# Automatic Detection of Speculative Execution Combinations
# Xaver Fabian
# Cispa Helmholtz Center for
# In
# --------------------------------------------------
# Paper 122:
# Title: Proof-of-Possession for KEM Certificates using Verifiable
# Content:
# Proof-of-Possession for KEM Certificates using Verifiable
# Generation
# Tim Güneysu
# Ruhr University Boc
# --------------------------------------------------
# Paper 123:
# Title: DPIS: An Enhanced Mechanism for Differentially Private SGD
# Content:
# DPIS: An Enhanced Mechanism for Differentially Private SGD
# with Importance Sampling
# Jianxin Wei
# Nati
# --------------------------------------------------
# Paper 124:
# Title: Shifted Inverse: A General Mechanism for Monotonic Functions
# Content:
# Shifted Inverse: A General Mechanism for Monotonic Functions
# under User Differential Privacy
# Juanru
# --------------------------------------------------
# Paper 125:
# Title: Understanding the How and the Why: Exploring Secure
# Content:
# Understanding the How and the Why: Exploring Secure
# Development Practices through a Course Competiti
# --------------------------------------------------
# Paper 126:
# Title: Do Opt-Outs Really Opt Me Out?
# Content:
# Do Opt-Outs Really Opt Me Out?
# Duc Bui
# University of Michigan
# Ann Arbor, USA
# ducbui@umich.eduBrian T
# --------------------------------------------------
# Paper 127:
# Title: Escaping the Confines of Time: Continuous Browser
# Content:
# Escaping the Confines of Time: Continuous Browser
# Extension Fingerprinting Through Ephemeral Modific
# --------------------------------------------------
# Paper 128:
# Title: QuerySnout: Automating the Discovery of Attribute Inference
# Content:
# QuerySnout: Automating the Discovery of Attribute Inference
# Attacks against Query-Based Systems
# Ana-
# --------------------------------------------------
# Paper 129:
# Title: DirtyCred: Escalating Privilege in Linux Kernel
# Content:
# DirtyCred: Escalating Privilege in Linux Kernel
# Zhenpeng Lin
# zplin@u.northwestern.edu
# Northwestern U
# --------------------------------------------------
# Paper 130:
# Title: StolenEncoder: Stealing Pre-trained Encoders in Self-supervised
# Content:
# StolenEncoder: Stealing Pre-trained Encoders in Self-supervised
# Learning
# Yupei Liu
# Duke University
# y
# --------------------------------------------------
# Paper 131:
# Title: Detecting Missing-Permission-Check Vulnerabilities in
# Content:
# Detecting Missing-Permission-Check Vulnerabilities in
# Distributed Cloud Systems
# Jie Lu
# lujie@ict.ac.
# --------------------------------------------------
# Paper 132:
# Title: Leakage Inversion: Towards Quantifying
# Content:
# Leakage Inversion: Towards Quantifying
# Privacy in Searchable Encryption
# Evgenios M. Kornaropoulos
# Ge
# --------------------------------------------------
# Paper 133:
# Title: Cross Miniapp Request Forgery: Root Causes, Attacks, and
# Content:
# Cross Miniapp Request Forgery: Root Causes, Attacks, and
# Vulnerability Detection
# Yuqing Yang
# The Ohi
# --------------------------------------------------
# Paper 134:
# Title: Why So Toxic? Measuring and Triggering Toxic Behavior in
# Content:
# Why So Toxic? Measuring and Triggering Toxic Behavior in
# Open-Domain Chatbots
# Wai Man Si
# CISPA Helmh
# --------------------------------------------------
# Paper 135:
# Title: Detecting and Measuring Misconfigured Manifests
# Content:
# Detecting and Measuring Misconfigured Manifests
# in Android Apps
# Yuqing Yang
# TheOhio State University
# --------------------------------------------------
# Paper 136:
# Title: AI/ML for Network Security: The Emperor has no Clothes
# Content:
# AI/ML for Network Security: The Emperor has no Clothes
# https://trusteeml.github.io/
# Arthur
# S. Jacobs
# --------------------------------------------------
# Paper 137:
# Title: A Run a Day Won’t Keep the Hacker Away: Inference Attacks on
# Content:
# A Run a Day Won’t Keep the Hacker Away: Inference Attacks on
# Endpoint Privacy Zones in Fitness Track
# --------------------------------------------------
# Paper 138:
# Title: CANflict: Exploiting Peripheral Conflicts for Data-Link Layer
# Content:
# CANflict: Exploiting Peripheral Conflicts for Data-Link Layer
# Attacks on Automotive Networks
# Alvise
# --------------------------------------------------
# Paper 139:
# Title: Adversarial Correctness and Privacy for Probabilistic Data
# Content:
# Adversarial Correctness and Privacy for Probabilistic Data
# Structures
# Mia Filić
# ETH Zürich
# Zürich, S
# --------------------------------------------------
# Paper 140:
# Title: Privacy Limitations of Interest-based Advertising on The Web: A
# Content:
# Privacy Limitations of Interest-based Advertising on The Web: A
# Post-mortem Empirical Analysis of Go
# --------------------------------------------------
# Paper 141:
# Title: StrongBox: A GPU TEE on Arm Endpoints
# Content:
# StrongBox: A GPU TEE on Arm Endpoints
# Yunjie Deng∗
# Research Institute of Trustworthy Autonomous
# Syst
# --------------------------------------------------
# Paper 142:
# Title: L-SRR: Local Differential Privacy for Location-Based Services
# Content:
# L-SRR: Local Differential Privacy for Location-Based Services
# with Staircase Randomized Response
# Han
# --------------------------------------------------
# Paper 143:
# Title: Understanding IoT Security from a Market-Scale Perspective
# Content:
# Understanding IoT Security from a Market-Scale Perspective
# Xin Jin∗
# The Ohio State University
# jin.96
# --------------------------------------------------
# Paper 144:
# Title: Ibex: Privacy-preserving Ad Conversion Tracking and Bidding
# Content:
# Ibex: Privacy-preserving Ad Conversion Tracking and Bidding
# Ke Zhong
# University of PennsylvaniaYipin
# --------------------------------------------------
# Paper 145:
# Title: Differentially Private Triangle and 4-Cycle Counting in the
# Content:
# Differentially Private Triangle and 4-Cycle Counting in the
# Shuffle Model
# Jacob Imola∗
# jimola@eng.uc
# --------------------------------------------------
# Paper 146:
# Title: Group Property Inference Attacks Against
# Content:
# Group Property Inference Attacks Against
# Graph Neural Networks
# Xiuling Wang
# Stevens Institute of Tec
# --------------------------------------------------
# Paper 147:
# Title: Are Attribute Inference Attacks Just Imputation?
# Content:
# Are Attribute Inference Attacks Just Imputation?
# Bargav Jayaraman
# University of Virginia
# Charlottesv
# --------------------------------------------------
# Paper 148:
# Title: Blacktooth: Breaking through the Defense of Bluetooth in Silence
# Content:
# Blacktooth: Breaking through the Defense of Bluetooth in Silence
# Mingrui Ai
# University of Science an
# --------------------------------------------------
# Paper 149:
# Title: HeatDeCam: Detecting Hidden Spy Cameras via Thermal
# Content:
# HeatDeCam: Detecting Hidden Spy Cameras via Thermal
# Emissions
# Zhiyuan Yu
# Washington University in St
# --------------------------------------------------
# Paper 150:
# Title: Enhanced Membership Inference Attacks against Machine
# Content:
# Enhanced Membership Inference Attacks against Machine
# Learning Models
# Jiayuan Ye
# National University
# --------------------------------------------------
# Paper 151:
# Title: LoneNeuron: A Highly-Effective Feature-Domain Neural Trojan
# Content:
# LoneNeuron: A Highly-Effective Feature-Domain Neural Trojan
# Using Invisible and Polymorphic Watermar
# --------------------------------------------------
# Paper 152:
# Title: On the (In)Security of Secure ROS2
# Content:
# On the (In)Security of Secure ROS2
# Gelei Deng
# Nanyang Technological University
# Singapore
# gdeng003@e.
# --------------------------------------------------
# Paper 153:
# Title: Frequency Throttling Side-Channel Attack
# Content:
# Frequency Throttling Side-Channel Attack
# Chen Liu
# Intel Corporation
# Hillsboro, OR, USA
# chen1.liu@int
# --------------------------------------------------
# Paper 154:
# Title: Federated Boosted Decision Trees with Differential Privacy
# Content:
# Federated Boosted Decision Trees with Differential Privacy
# Samuel Maddock∗
# University of WarwickGrah
# --------------------------------------------------
# Paper 155:
# Title: Efficient Secure Three-Party Sorting
# Content:
# Efficient Secure Three-Party Sorting
# with Applications to Data Analysis and Heavy Hitters
# Gilad Asha
# --------------------------------------------------
# Paper 156:
# Title: Am I Private and If So, how Many? Communicating Privacy
# Content:
# Am I Private and If So, how Many? Communicating Privacy
# Guarantees of Differential Privacy with Risk
# --------------------------------------------------
# Paper 157:
# Title: Secure Parallel Computation on Privately Partitioned Data and
# Content:
# Secure Parallel Computation on Privately Partitioned Data and
# Applications
# Nuttapong Attrapadung
# AIS
# --------------------------------------------------
# Paper 158:
# Title: FABEO: Fast Attribute-Based Encryption with Optimal Security
# Content:
# FABEO: Fast Attribute-Based Encryption with Optimal Security
# Doreen Riepel
# Ruhr-Universität Bochum
# B
# --------------------------------------------------
# Paper 159:
# Title: SortingHat: Efficient Private Decision Tree Evaluation
# Content:
# SortingHat: Efficient Private Decision Tree Evaluation
# via Homomorphic Encryption and Transciphering
# --------------------------------------------------
# Paper 160:
# Title: LPGNet: Link Private Graph Networks for Node Classification
# Content:
# LPGNet: Link Private Graph Networks for Node Classification
# Aashish Kolluri
# aashish7@comp.nus.edu.sg
# --------------------------------------------------
# Paper 161:
# Title: Widespread Underestimation of Sensitivity in Differentially
# Content:
# Widespread Underestimation of Sensitivity in Differentially
# Private Libraries and How to Fix It
# Sílv
# --------------------------------------------------
# Paper 162:
# Title: Are There Wireless Hidden Cameras Spying on Me?
# Content:
# Are There Wireless Hidden Cameras Spying on Me?
# Jeongyoon Heo
# Samsung Research
# Seoul, Republic of Ko
# --------------------------------------------------
# Paper 163:
# Title: Assessing Model-free Anomaly Detection in
# Content:
# Assessing Model-free Anomaly Detection in
# Industrial Control Systems Against Generic
# Concealment Att
# --------------------------------------------------
# Paper 164:
# Title: Spacelord : Private and Secure Smart Space
# Content:
# Spacelord : Private and Secure Smart Space
# Sharing
# Yechan Bae
# Georgia Institute of Technology
# Atlant
# --------------------------------------------------
# Paper 165:
# Title: Stepping out of the MUD: Contextual threat
# Content:
# Stepping out of the MUD: Contextual threat
# information for IoT devices with
# manufacturer-provided be
# --------------------------------------------------
# Paper 166:
# Title: Interaction matters: a comprehensive analysis and a dataset of
# Content:
# Interaction matters: a comprehensive analysis and a dataset of
# hybrid IoT/OT honeypots
# Shreyas Srini
# --------------------------------------------------
# Paper 167:
# Title: View from Above: Exploring the Malware Ecosystem from the
# Content:
# View from Above: Exploring the Malware Ecosystem from the
# Upper DNS Hierarchy
# Aaron Faulkenberry∗
# Ge
# --------------------------------------------------
# Paper 168:
# Title: Accept All Exploits:
# Content:
# Accept All Exploits:
# Exploring the Security Impact of Cookie Banners
# David Klein∗
# Technische Univers
# --------------------------------------------------
# Paper 169:
# Title: CoCoTPM: Trusted Platform Modules for Virtual Machines in
# Content:
# CoCoTPM: Trusted Platform Modules for Virtual Machines in
# Confidential Computing Environments
# Joana
# --------------------------------------------------
# Paper 170:
# Title: On the Implications of Spoofing and Jamming Aviation Datalink
# Content:
# On the Implications of Spoofing and Jamming Aviation Datalink
# Applications
# Harshad Sathaye
# Khoury Co
# --------------------------------------------------
# Paper 171:
# Title: Squeezing More Utility via Adaptive Clipping
# Content:
# Squeezing More Utility via Adaptive Clipping
# on Differentially Private Gradients in
# Federated Meta-L
# --------------------------------------------------
# Paper 172:
# Title: Compact Abstract Graphs for Detecting Code Vulnerability with
# Content:
# Compact Abstract Graphs for Detecting Code Vulnerability with
# GNN Models
# Yu Luo
# University of Missou
# --------------------------------------------------
# Paper 173:
# Title: Towards Enhanced EEG-based Authentication with Motor
# Content:
# Towards Enhanced EEG-based Authentication with Motor
# Imagery Brain-Computer Interface
# Bingkun Wu, We
# --------------------------------------------------
# Paper 174:
# Title: Make Data Reliable : An Explanation-powered
# Content:
# Make Data Reliable : An Explanation-powered
# Cleaning on Malware Dataset Against
# Backdoor Poisoning A
# --------------------------------------------------
# Paper 175:
# Title: DRAGON: Deep Reinforcement Learning for Autonomous Grid
# Content:
# DRAGON: Deep Reinforcement Learning for Autonomous Grid
# Operation and Attack Detection
# Matthew Lande
# --------------------------------------------------
# Paper 176:
# Title: Randezvous: Making Randomization Effective
# Content:
# Randezvous: Making Randomization Effective
# on MCUs
# Zhuojia Shen
# University of Rochester
# Rochester, N
# --------------------------------------------------
# Paper 177:
# Title: MADDC: Multi-Scale Anomaly Detection, Diagnosis and
# Content:
# MADDC: Multi-Scale Anomaly Detection, Diagnosis and
# Correction for Discrete Event Logs
# Xiaolei Wang1
# --------------------------------------------------
# Paper 178:
# Title: Differentially Private Map Matching for Mobility Trajectories
# Content:
# Differentially Private Map Matching for Mobility Trajectories
# Ammar Haydari
# University of California
# --------------------------------------------------
# Paper 179:
# Title: NeuGuard: Lightweight Neu ron-G uided D efense against
# Content:
# NeuGuard: Lightweight Neu ron-G uided D efense against
# Membership Inference Attacks
# Nuo Xu
# Lehigh Un
# --------------------------------------------------
# Paper 180:
# Title: No Signal Left to Chance: Driving Browser Extension Analysis by
# Content:
# No Signal Left to Chance: Driving Browser Extension Analysis by
# Download Patterns
# Pablo Picazo-Sanch
# --------------------------------------------------
# Paper 181:
# Title: AFLGuard: Byzantine-robust Asynchronous Federated Learning
# Content:
# AFLGuard: Byzantine-robust Asynchronous Federated Learning
# Minghong Fang
# The Ohio State University a
# --------------------------------------------------
# Paper 182:
# Title: ENIDrift: A Fast and Adaptive Ensemble
# Content:
# ENIDrift: A Fast and Adaptive Ensemble
# System for Network Intrusion Detection
# under Real-world Drift
# --------------------------------------------------
# Paper 183:
# Title: MoLE: M itigation o f Side-channel Attacks against SGX via
# Content:
# MoLE: M itigation o f Side-channel Attacks against SGX via
# Dynamic Data L ocation E scape
# Fan Lang∗
#
# --------------------------------------------------
# Paper 184:
# Title: Are we there yet? An Industrial Viewpoint on
# Content:
# Are we there yet? An Industrial Viewpoint on
# Provenance-based Endpoint Detection and Response Tools
#
# --------------------------------------------------
# Paper 185:
# Title: Alert Alchemy: SOC Workflows and Decisions in the
# Content:
# Alert Alchemy: SOC Workflows and Decisions in the
# Management of NIDS Rules
# Mathew Vermeer
# m.vermeer@
# --------------------------------------------------
# Paper 186:
# Title: Black Ostrich: Web Application Scanning with String Solvers
# Content:
# Black Ostrich: Web Application Scanning with String Solvers
# Benjamin Eriksson
# Chalmers University of
# --------------------------------------------------
# Paper 187:
# Title: CookieGraph:
# Content:
# CookieGraph:
# Understanding
# and Detecting First-Party Tracking Cookies
# Shaoor Munir
# smunir@ucdavis.ed
# --------------------------------------------------
# Paper 188:
# Title: CryptoConcurrency: (Almost) Consensusless Asset Transfer with
# Content:
# CryptoConcurrency: (Almost) Consensusless Asset Transfer with
# Shared Accounts
# Andrei Tonkikh∗
# tonkik
# --------------------------------------------------
# Paper 189:
# Title: General Data Protection Runtime:
# Content:
# General Data Protection Runtime:
# Enforcing Transparent GDPR Compliance for Existing
# Applications
# Dav
# --------------------------------------------------
# Paper 190:
# Title: Good-looking but Lacking Faithfulness: Understanding Local
# Content:
# Good-looking but Lacking Faithfulness: Understanding Local
# Explanation Methods through Trend-based T
# --------------------------------------------------
# Paper 191:
# Title: Lifting Network Protocol Implementation to Precise Format
# Content:
# Lifting Network Protocol Implementation to Precise Format
# Specification with Security Applications
# Q
# --------------------------------------------------
# Paper 192:
# Title: Narcissus : A Practical Clean-Label Backdoor Attack with Limited
# Content:
# Narcissus : A Practical Clean-Label Backdoor Attack with Limited
# Information
# Yi Zeng∗
# Virginia Tech
#
# --------------------------------------------------
# Paper 193:
# Title: Security Verification of Low-Trust Architectures
# Content:
# Security Verification of Low-Trust Architectures
# Qinhan Tan∗
# qinhant@princeton.edu
# Princeton Univers
# --------------------------------------------------
# Paper 194:
# Title: TunneL s for B ootlegging: Fully Reverse-Engineering GPU TLBs
# Content:
# TunneL s for B ootlegging: Fully Reverse-Engineering GPU TLBs
# for Challenging Isolation Guarantees o
# --------------------------------------------------
# Paper 195:
# Title: PolicyChecker: Analyzing the GDPR Completeness of Mobile
# Content:
# PolicyChecker: Analyzing the GDPR Completeness of Mobile
# Apps’ Privacy Policies
# Anhao Xiang
# Departme
# --------------------------------------------------
# Paper 196:
# Title: Splice: Efficiently Removing a User’s Data from In-memory
# Content:
# Splice: Efficiently Removing a User’s Data from In-memory
# Application State
# Xueyuan Han
# vanbasm@wfu.
# --------------------------------------------------
# Paper 197:
# Title: Phoenix: Detect and Locate Resilience Issues in Blockchain via
# Content:
# Phoenix: Detect and Locate Resilience Issues in Blockchain via
# Context-Sensitive Chaos
# Fuchen Ma
# BNR
# --------------------------------------------------
# Paper 198:
# Title: In Search of netUnicorn: A Data-Collection Platform to Develop
# Content:
# In Search of netUnicorn: A Data-Collection Platform to Develop
# Generalizable ML Models for Network S
# --------------------------------------------------
# Paper 199:
# Title: Unforgeability in Stochastic Gradient Descent
# Content:
# Unforgeability in Stochastic Gradient Descent
# Teodora Baluta∗
# National University of Singapore
# Singa
# --------------------------------------------------
# Paper 200:
# Title: Improving Security Tasks Using Compiler Provenance
# Content:
# Improving Security Tasks Using Compiler Provenance
# Information Recovered At the Binary-Level
# Yufei D
# --------------------------------------------------
# Paper 201:
# Title: Verifiable Learning for Robust Tree Ensembles
# Content:
# Verifiable Learning for Robust Tree Ensembles
# Stefano Calzavara
# Università Ca’ Foscari Venezia
# stefa
# --------------------------------------------------
# Paper 202:
# Title: Detecting Violations of Differential Privacy for Quantum
# Content:
# Detecting Violations of Differential Privacy for Quantum
# Algorithms
# Ji Guan
# State Key Laboratory of
# --------------------------------------------------
# Paper 203:
# Title: Using Range-Revocable Pseudonyms to Provide Backward
# Content:
# Using Range-Revocable Pseudonyms to Provide Backward
# Unlinkability in the Edge
# Cláudio Correia
# INESC
# --------------------------------------------------
# Paper 204:
# Title: Exploration of Power Side-Channel Vulnerabilities
# Content:
# Exploration of Power Side-Channel Vulnerabilities
# in Quantum Computer Controllers
# Chuanqi Xu
# Yale Un
# --------------------------------------------------
# Paper 205:
# Title: Learning from Limited Heterogeneous Training Data:
# Content:
# Learning from Limited Heterogeneous Training Data:
# Meta-Learning for Unsupervised Zero-Day Web Attac
# --------------------------------------------------
# Paper 206:
# Title: martFL: Enabling Utility-Driven Data Marketplace with a Robust
# Content:
# martFL: Enabling Utility-Driven Data Marketplace with a Robust
# and Verifiable Federated Learning Arc
# --------------------------------------------------
# Paper 207:
# Title: HELiKs: HE Linear Algebra Kernels for Secure Inference
# Content:
# HELiKs: HE Linear Algebra Kernels for Secure Inference
# Shashank Balla
# University of California San D
# --------------------------------------------------
# Paper 208:
# Title: Cryptographically Enforced Memory Safety
# Content:
# Cryptographically Enforced Memory Safety
# Martin Unterguggenberger
# martin.unterguggenberger@iaik.tugr
# --------------------------------------------------
# Paper 209:
# Title: Modular Sumcheck Proofs with Applications to Machine
# Content:
# Modular Sumcheck Proofs with Applications to Machine
# Learning and Image Processing
# David Balbás
# IMDE
# --------------------------------------------------
# Paper 210:
# ...
# Paper 1202:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1203:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1204:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1205:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1206:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1207:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1208:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1209:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1210:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1211:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1212:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1213:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1214:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1215:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1216:
# Title: This paper is included in the Proceedings of the
# Content:
# This paper is included in the Proceedings of the
# 33rd USENIX Security Symposium.
# August 14–16, 2024
# --------------------------------------------------
# Paper 1217:
# Title: Using Hardware Features for Increased Debugging
# Content:
# Using Hardware Features for Increased Debugging
# Transparency
# Fengwei Zhang1, Kevin Leach2, Angelos S
# --------------------------------------------------
# Paper 1218:
# Title: Utility-Aware Synthesis of Differentially Private and
# Content:
# Utility-Aware Synthesis of Differentially Private and
# Attack-Resilient Location Traces
# Mehmet Emre G
# --------------------------------------------------
# Paper 1219:
# Title: VC3: Trustworthy Data Analytics in the Cloud using SGX
# Content:
# VC3: Trustworthy Data Analytics in the Cloud using SGX
# Felix Schuster∗, Manuel Costa, C ´edric Fourn
# --------------------------------------------------
# Paper 1220:
# Title: Vectorized Batch Private Information Retrieval
# Content:
# Vectorized Batch Private Information Retrieval
# Muhammad Haris Mughees
# University of Illinois at Urba
# --------------------------------------------------
# Paper 1221:
# Title: V erena: End-to-End Integrity Protection
# Content:
# V erena: End-to-End Integrity Protection
# for Web Applications
# Nikolaos Karapanos1, Alexandros Filios
# --------------------------------------------------
# Paper 1222:
# Title: V erifying and Synthesizing Constant-Resource Implementations with Types
# Content:
# V erifying and Synthesizing Constant-Resource Implementations with Types
# Van Chan Ngo Mario Dehesa-A
# --------------------------------------------------
# Paper 1223:
# Title: Verifying Security Policies in Multi-agent Workflows with Loops
# Content:
# Verifying Security Policies in Multi-agent Workflows with Loops
# Bernd Finkbeiner
# finkbeiner@cs.uni-s
# --------------------------------------------------
# Paper 1224:
# Title: VerX: Safety Veriﬁcation of Smart Contracts
# Content:
# VerX: Safety Veriﬁcation of Smart Contracts
# Anton Permenev1;2Dimitar Dimitrov2Petar Tsankov1;2Dana D
# --------------------------------------------------
# Paper 1225:
# Title: V etting SSL Usage in Applications with SSL INT
# Content:
# V etting SSL Usage in Applications with SSL INT
# Boyuan He1, V aibhav Rastogi2, Yinzhi Cao3, Yan Chen
# --------------------------------------------------
# Paper 1226:
# Title: Viden: Attacker Identification on In-Vehicle Networks
# Content:
# Viden: Attacker Identification on In-Vehicle Networks
# Kyong-Tak Cho and Kang G. Shin
# University of M
# --------------------------------------------------
# Paper 1227:
# Title: VisualPhishNet: Zero-Day Phishing Website Detection by
# Content:
# VisualPhishNet: Zero-Day Phishing Website Detection by
# Visual Similarity
# Sahar
# Abdelnabi
# CISPA Helmh
# --------------------------------------------------
# Paper 1228:
# Title: VMHunt: A Verifiable Approach to Partially-Virtualized Binary
# Content:
# VMHunt: A Verifiable Approach to Partially-Virtualized Binary
# Code Simplification
# Dongpeng Xu
# Pennsy
# --------------------------------------------------
# Paper 1229:
# Title: VoiceLive: A Phoneme Localization based Liveness
# Content:
# VoiceLive: A Phoneme Localization based Liveness
# Detection for Voice Authentication on Smartphones
# L
# --------------------------------------------------
# Paper 1230:
# Title: Volttack : Control IoT Devices by Manipulating Power Supply Voltage
# Content:
# Volttack : Control IoT Devices by Manipulating Power Supply Voltage
# Kai Wang∗, Shilin Xiao∗, Xiaoyu
# --------------------------------------------------
# Paper 1231:
# Title: vRAM: Faster Veriﬁable RAM With
# Content:
# vRAM: Faster Veriﬁable RAM With
# Program-Independent Preprocessing
# Yupeng Zhang∗, Daniel Genkin†,∗, J
# --------------------------------------------------
# Paper 1232:
# Title: vSQL: Verifying Arbitrary SQL Queries over
# Content:
# vSQL: Verifying Arbitrary SQL Queries over
# Dynamic Outsourced Databases
# Yupeng Zhang∗, Daniel Genkin
# --------------------------------------------------
# Paper 1233:
# Title: VTint : Protecting Virtual Function Tables’ Integrity
# Content:
# VTint : Protecting Virtual Function Tables’ Integrity
# Chao Zhang, Chengyu Songz, Kevin Zhijie Chen
# --------------------------------------------------
# Paper 1234:
# Title: Waldo: A Private Time-Series Database from
# Content:
# Waldo: A Private Time-Series Database from
# Function Secret Sharing
# Emma Dauterman, Mayank Rathee, Ra
# --------------------------------------------------
# Paper 1235:
# Title: walk2friends: Inferring Social Links from Mobility Profiles
# Content:
# walk2friends: Inferring Social Links from Mobility Profiles
# Michael Backes
# CISPA, Saarland Universit
# --------------------------------------------------
# Paper 1236:
# Title: Walls Have Ears! Opportunistically Communicating Secret
# Content:
# Walls Have Ears! Opportunistically Communicating Secret
# Messages Over the Wiretap Channel: from Theo
# --------------------------------------------------
# Paper 1237:
# Title: WATSON : Abstracting Behaviors from Audit Logs
# Content:
# WATSON : Abstracting Behaviors from Audit Logs
# via Aggregation of Contextual Semantics
# Jun Zeng†Zhen
# --------------------------------------------------
# Paper 1238:
# Title: WaVe: a veriﬁably secure WebAssembly sandboxing runtime
# Content:
# WaVe: a veriﬁably secure WebAssembly sandboxing runtime
# Evan Johnson†Evan Laufer‡Zijie Zhao⋆Dan Gohm
# --------------------------------------------------
# Paper 1239:
# Title: WearID: Low-Effort Wearable-Assisted Authentication of Voice
# Content:
# WearID: Low-Effort Wearable-Assisted Authentication of Voice
# Commands via Cross-Domain Comparison wi
# --------------------------------------------------
# Paper 1240:
# Title: W
# Content:
# W
# eb Tracking Technologies and Protection Mechanisms
# Nataliia Bielova
# Universit e C^ ote d'Azur, In
# --------------------------------------------------
# Paper 1241:
# Title: WebCapsule: Towards a Lightweight Forensic Engine
# Content:
# WebCapsule: Towards a Lightweight Forensic Engine
# for Web Browsers
# Christopher Neasbitty, Bo Liy, Ro
# --------------------------------------------------
# Paper 1242:
# Title: What Else is Revealed by Order-Revealing Encryption?
# Content:
# What Else is Revealed by Order-Revealing Encryption?
# F . Betül Durak
# Rutgers UniversityThomas M. DuB
# --------------------------------------------------
# Paper 1243:
# Title: When CSI Meets Public WiFi: Inferring Your Mobile Phone
# Content:
# When CSI Meets Public WiFi: Inferring Your Mobile Phone
# Password via WiFi Signals
# Mengyuan Li1, Y an
# --------------------------------------------------
# Paper 1244:
# Title: When Good Becomes Evil: Keystroke Inference with
# Content:
# When Good Becomes Evil: Keystroke Inference with
# Smartwatch
# Xiangyu Liu
# The Chinese University of
# H
# --------------------------------------------------
# Paper 1245:
# Title: When the Differences in Frequency Domain are Compensated:
# Content:
# When the Differences in Frequency Domain are Compensated:
# Understanding and Defeating Modulated Repl
# --------------------------------------------------
# Paper 1246:
# Title: When Y our Fitness Tracker Betrays Y ou: Quantifying the Predictability of
# Content:
# When Y our Fitness Tracker Betrays Y ou: Quantifying the Predictability of
# Biometric Features Across
# --------------------------------------------------
# Paper 1247:
# Title: When and Why Do People Want Ad Targeting Explanations? Evidence from a
# Content:
# When and Why Do People Want Ad Targeting Explanations? Evidence from a
# Four-Week, Mixed-Methods Fiel
# --------------------------------------------------
# Paper 1248:
# Title: When Function Signature Recovery Meets Compiler
# Content:
# When Function Signature Recovery Meets Compiler
# Optimization
# Yan Lin
# Singapore Management University
# --------------------------------------------------
# Paper 1249:
# Title: When Top-down Meets Bottom-up: Detecting and
# Content:
# When Top-down Meets Bottom-up: Detecting and
# Exploiting Use-After-Cleanup Bugs in Linux Kernel
# Lin M
# --------------------------------------------------
# Paper 1250:
# Title: Which Privacy and Security Attributes Most Impact Consumers’ Risk
# Content:
# Which Privacy and Security Attributes Most Impact Consumers’ Risk
# Perception and Willingness to Purc
# --------------------------------------------------
# Paper 1251:
# Title: Who’s in Control of Your Control System?
# Content:
# Who’s in Control of Your Control System?
# Device Fingerprinting for Cyber-Physical Systems
# David Form
# --------------------------------------------------
# Paper 1252:
# Title: Why Does Y our Data Leak? Uncovering the Data
# Content:
# Why Does Y our Data Leak? Uncovering the Data
# Leakage in Cloud from Mobile Apps
# Chaoshun Zuo
# The Ohi
# --------------------------------------------------
# Paper 1253:
# Title: Why Crypto-detectors Fail : A Systematic Evaluation
# Content:
# Why Crypto-detectors Fail : A Systematic Evaluation
# of Cryptographic Misuse Detection Techniques
# Ami
# --------------------------------------------------
# Paper 1254:
# Title: WIGHT : Wired Ghost Touch Attack on Capacitive
# Content:
# WIGHT : Wired Ghost Touch Attack on Capacitive
# Touchscreens
# Yan Jiang1, Xiaoyu Ji1†, Kai Wang1, Chen
# --------------------------------------------------
# Paper 1255:
# Title: Wild Patterns: Ten Years After the Rise of Adversarial Machine
# Content:
# Wild Patterns: Ten Years After the Rise of Adversarial Machine
# Learning
# Half-day Tutorial
# Battista B
# --------------------------------------------------
# Paper 1256:
# Title: Wobfuscator: Obfuscating JavaScript Malware via
# Content:
# Wobfuscator: Obfuscating JavaScript Malware via
# Opportunistic Translation to WebAssembly
# Alan Romano
# --------------------------------------------------
# Paper 1257:
# Title: WooKey: Designing a Trusted and Efficient
# Content:
# WooKey: Designing a Trusted and Efficient
# USB Device
# Ryad Benadjila
# Arnauld Michelizza
# Mathieu Renar
# --------------------------------------------------
# Paper 1258:
# Title: WTAGRAPH : Web Tracking and Advertising
# Content:
# WTAGRAPH : Web Tracking and Advertising
# Detection using Graph Neural Networks
# Zhiju Yang
# Colorado Sc
# --------------------------------------------------
# Paper 1259:
# Title: XFL: Naming Functions in Binaries with
# Content:
# XFL: Naming Functions in Binaries with
# Extreme Multi-label Learning
# James Patrick-Evans∗†, Moritz Da
# --------------------------------------------------
# Paper 1260:
# Title: xMP: Selective Memory Protection
# Content:
# xMP: Selective Memory Protection
# for Kernel and User Space
# Sergej Proskurin,Marius Momeu,Seyedhame
# --------------------------------------------------
# Paper 1261:
# Title: Y ou Get Where Y ou’re Looking For
# Content:
# Y ou Get Where Y ou’re Looking For
# The Impact of Information Sources on Code Security
# Y asemin Acar,
# --------------------------------------------------
# Paper 1262:
# Title: You Shall Not Join: A Measurement Study of Cryptocurrency
# Content:
# You Shall Not Join: A Measurement Study of Cryptocurrency
# Peer-to-Peer Bootstrapping Techniques
# Ange
# --------------------------------------------------
# Paper 1263:
# Title: You’ve Changed: Detecting Malicious Browser Extensions
# Content:
# You’ve Changed: Detecting Malicious Browser Extensions
# through their Update Deltas
# Nikolaos Pantelai
# --------------------------------------------------
# Paper 1264:
# Title: “Your Hashed IP Address: Ubuntu.”
# Content:
# “Your Hashed IP Address: Ubuntu.”
# Perspectives on Transparency Tools for Online Advertising
# Tobias U
# --------------------------------------------------
# Paper 1265:
# Title: ZeeStar: Private Smart Contracts by Homomorphic
# Content:
# ZeeStar: Private Smart Contracts by Homomorphic
# Encryption and Zero-knowledge Proofs
# Samuel Steffen,
# --------------------------------------------------
# Paper 1266:
# Title: Zero Knowledge Proofs
# Content:
# Zero Knowledge Proofs
# for Decision Tree Predictions and Accuracy
# Jiaheng Zhang
# UC Berkeley
# jiaheng_z
# --------------------------------------------------
# Paper 1267:
# Title: zkay: Specifying and Enforcing Data Privacy in Smart Contracts
# Content:
# zkay: Specifying and Enforcing Data Privacy in Smart Contracts
# Samuel Steffen
# ETH Zurich, Switzerlan
# --------------------------------------------------
# Paper 1268:
# Title: Zombie Awakening: Stealthy Hijacking of Active Domains
# Content:
# Zombie Awakening: Stealthy Hijacking of Active Domains
# through DNS Hosting Referral
# Eihal Alowaisheq
# --------------------------------------------------
# Paper 1269:
# Title: ZombieLoad: Cross-Privilege-Boundary Data Sampling
# Content:
# ZombieLoad: Cross-Privilege-Boundary Data Sampling
# Michael Schwarz
# Graz University of Technology
# mic
# --------------------------------------------------
# Paper 1270:
# Title: o
# Content:
# oo& – Forward Secure Searchable Encryption
# Raphael Bost
# Direction Générale de l’Armement - Maîtris
# --------------------------------------------------
# Paper 1271:
# Title: o
# Content:
# oo& – Forward Secure Searchable Encryption
# Raphael Bost
# Direction Générale de l’Armement - Maîtris
# --------------------------------------------------

# %% [markdown]
# token calculations

# %%
pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (0.8.0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: regex>=2022.1.18 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roohana karim\appdata\roaming\python\python311\site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (2024.8.30)

# %%
pip install transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: transformers in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (4.45.2)
# Requirement already satisfied: filelock in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\roohana karim\appdata\roaming\python\python311\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\roohana karim\appdata\roaming\python\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roohana karim\appdata\roaming\python\python311\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roohana karim\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers) (2024.8.30)
# [notice] A new release of pip is available: 23.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
from transformers import GPT2Tokenizer

def load_papers_from_jsonl(file_path):
    papers = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                papers.append(json.loads(line.strip()))
    except Exception as e:
        print(f"Error loading or processing file: {e}")
    return papers

def calculate_total_tokens(papers):
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")  # Loading GPT-2 tokenizer
    total_tokens = 0
    for paper in papers:
        content = paper.get('content', '')
        tokens = tokenizer(content, add_special_tokens=False)['input_ids']  # Tokenize without adding special tokens
        total_tokens += len(tokens)
        print(f"Paper: {paper['title']} - Tokens: {len(tokens)}")
    return total_tokens

# Specify the path to your JSONL file
jsonl_file_path = "extracted_test_papers_new_NEWEST.jsonl"

# Load papers
papers = load_papers_from_jsonl(jsonl_file_path)

# Calculate total tokens
total_tokens = calculate_total_tokens(papers)
print(f"Total number of tokens in the dataset: {total_tokens}")
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Token indices sequence length is longer than the specified maximum sequence length for this model (26165 > 1024). Running this sequence through the model will result in indexing errors
# Paper: NetCA T: Practical Cache Attacks from the Network - Tokens: 26165
# Paper: (Un)informed Consent: Studying GDPR Consent Notices in the - Tokens: 25567
# Paper: (Un)linkable Pseudonyms for Governmental Databases - Tokens: 22965
# Paper: ObliviSync: Practical Oblivious - Tokens: 24117
# Paper: SYMTCP: Eluding Stateful Deep Packet Inspection - Tokens: 28403
# Paper: Interpretable Federated Transformer Log Learning - Tokens: 23609
# Paper: How to Count Bots - Tokens: 22539
# Paper: Testability Tarpits: the Impact of Code Patterns - Tokens: 24038
# Paper: FedCRI: Federated Mobile Cyber-Risk Intelligence - Tokens: 18979
# Paper: Hybrid Trust Multi-party Computation with - Tokens: 32704
# Paper: A Lightweight IoT Cryptojacking Detection - Tokens: 23031
# Paper: Hiding My Real Self! Protecting Intellectual - Tokens: 21336
# Paper: Towards Precise Reporting of - Tokens: 32222
# Paper: Understanding and Analyzing Appraisal Systems in - Tokens: 30263
# Paper: Understanding Route Origin Validation (ROV) - Tokens: 23597
# Paper: MPCD IFF: Testing and Repairing MPC-Hardened - Tokens: 41311
# Paper: DorPatch: Distributed and Occlusion-Robust - Tokens: 25763
# Paper: Differentially Private Publishing of High-dimensional Data - Tokens: 20578
# Paper: 27 Years and 81 Million Opportunities Later: - Tokens: 23624
# Paper: 28 Blinks Later: Tackling Practical Challenges of - Tokens: 18303
# Paper: High Fidelity Data Reduction for Big Data Security - Tokens: 19482
# Paper: Identifying Open-Source License Violation and 1-day Security - Tokens: 27571
# Paper: POISED: Spotting Twitter Spam Off the Beaten Paths - Tokens: 24969
# Paper: MineSweeper: An In-depth Look into Drive-by - Tokens: 28109
# Paper: Quantitative Verification of Neural Networks - Tokens: 29340
# Paper: Poirot: Aligning Attack Behavior with Kernel Audit Records for - Tokens: 29676
# Paper: Preparing Network Intrusion Detection Deep Learning Models - Tokens: 18681
# Paper: EIGER: Automated IOC Generation for Accurate and - Tokens: 23546
# Paper: PDiff: Semantic-based Patch Presence Testing - Tokens: 27207
# Paper: Filtering DDoS Attacks from Unlabeled Network Traffic Data - Tokens: 23179
# Paper: Recompose Event Sequences vs. Predict Next Events: A Novel - Tokens: 24078
# Paper: Honest-but-Curious Nets: Sensitive Attributes of Private Inputs - Tokens: 39625
# Paper: Consistency Analysis of Data-Usage Purposes in Mobile Apps - Tokens: 32730
# Paper: C3PO: Large-Scale Study of Covert Monitoring of C&C Servers - Tokens: 25403
# Paper: Cert-RNN: Towards Certifying the Robustness of Recurrent - Tokens: 30220
# Paper: LEAP: Leakage-Abuse Attack on Efficiently Deployable, - Tokens: 24272
# Paper: Dissecting Click Fraud Autonomy in the Wild - Tokens: 26222
# Paper: Periscope: A Keystroke Inference Attack Using Human Coupled - Tokens: 24019
# Paper: Secure Multi-party Computation of Differentially Private Heavy - Tokens: 33998
# Paper: ZKCPlus: Optimized Fair-exchange Protocol - Tokens: 37249
# Paper: Locally Private Graph Neural Networks - Tokens: 31275
# Paper: All your Credentials are Belong to Us: - Tokens: 33292
# Paper: On the Robustness of Domain Constraints - Tokens: 32754
# Paper: Quantifying and Mitigating Privacy Risks of - Tokens: 25235
# Paper: Membership Leakage in Label-Only Exposures - Tokens: 22232
# Paper: SugarCoat: Programmatically Generating Privacy-Preserving, - Tokens: 22362
# Paper: DataLens: Scalable Privacy Preserving Training via Gradient - Tokens: 44800
# Paper: On-device IoT Certificate Revocation Checking with Small - Tokens: 27109
# Paper: Oblivious Linear Group Actions and Applications - Tokens: 48524
# Paper: Revisiting Fuzzy Signatures: Towards a More Risk-Free - Tokens: 33199
# Paper: An In-Depth Symbolic Security Analysis of the ACME Standard - Tokens: 30742
# Paper: Differential Privacy for Directional Data - Tokens: 33296
# Paper: Deterrence of Intelligent DDoS via Multi-Hop Traffic Divergence - Tokens: 30524
# Paper: HardsHeap: A Universal and Extensible Framework for - Tokens: 21412
# Paper: “Hello,It’s Me”:DeepLearning-based SpeechSynthesis A/t_tack s - Tokens: 32220
# Paper: Demons in the Shared Kernel: Abstract Resource Attacks Against - Tokens: 22785
# Paper: DoubleX: Statically Detecting Vulnerable Data Flows - Tokens: 25798
# Paper: EncoderMI: Membership Inference against Pre-trained - Tokens: 27269
# Paper: Continuous Release of Data Streams under both Centralized - Tokens: 25709
# Paper: Robust Detection of Machine-induced Audio Attacks - Tokens: 26529
# Paper: When Machine Unlearning Jeopardizes Privacy - Tokens: 25443
# Paper: New Directions in Automated Traffic Analysis - Tokens: 23864
# Paper: I Can See the Light: Attacks on Autonomous Vehicles Using - Tokens: 23179
# Paper: Membership Inference Attacks Against Recommender Systems - Tokens: 23834
# Paper: Learning Security Classifiers with - Tokens: 32431
# Paper: One Glitch to Rule Them All: Fault Injection Attacks Against - Tokens: 25349
# Paper: DPGen: Automated Program Synthesis for Differential Privacy - Tokens: 33653
# Paper: Mining in - Tokens: 29810
# Paper: A Formally Verified Configuration - Tokens: 29739
# Paper: Epsolute: Efficiently Querying Databases While Providing - Tokens: 26555
# Paper: Compressed Oblivious Encoding for Homomorphically - Tokens: 25071
# Paper: WristPrint: Characterizing User Re-identification Risks from - Tokens: 26327
# Paper: APECS: A Distributed A ccess Control Framework for P ervasive - Tokens: 27691
# Paper: Reverse Attack: Black-box Attacks on Collaborative - Tokens: 31929
# Paper: Asynchronous Data Dissemination and its Applications - Tokens: 36876
# Paper: V-Shuttle: Scalable and Semantics-Aware Hypervisor Virtual - Tokens: 25803
# Paper: The Security of ChaCha20-Poly1305 in the Multi-User Setting - Tokens: 55185
# Paper: AI-Lancet: Locating Error-inducing Neurons - Tokens: 33178
# Paper: TableGAN-MCA: Evaluating Membership Collisions of - Tokens: 23515
# Paper: “I need a better description”: - Tokens: 25148
# Paper: A One-Pass Distributed and Private Sketch for Kernel Sums - Tokens: 20325
# Paper: TSS: Transformation-Specific Smoothing - Tokens: 51396
# Paper: Unleashing the Tiger: Inference Attacks on Split Learning - Tokens: 27153
# Paper: A Security Framework for Distributed Ledgers - Tokens: 35454
# Paper: Automated Bug Hunting With Data-Driven Symbolic Root - Tokens: 29359
# Paper: This Sneaky Piggy Went to the Android Ad Market: - Tokens: 29411
# Paper: Out of Sight, - Tokens: 26849
# Paper: Subpopulation Data Poisoning Attacks - Tokens: 32100
# Paper: VIP: Safeguard Value Invariant Property for - Tokens: 27137
# Paper: zkCNN: Zero Knowledge Proofs for Convolutional Neural - Tokens: 40083
# Paper: Black-box Adversarial Attacks on Commercial Speech Platforms - Tokens: 36040
# Paper: AHEAD: Adaptive Hierarchical Decomposition for Range Query - Tokens: 40396
# Paper: BAPM: Block Attention Profiling Model for Multi-tab Website - Tokens: 16324
# Paper: CommanderGabble: A Universal Attack - Tokens: 34321
# Paper: An Exploration of ARM System-Level Cache and GPU Side - Tokens: 17738
# Paper: Two Souls in an Adversarial Image: Towards - Tokens: 21568
# Paper: Can We Leverage Predictive Uncertainty to Detect Dataset Shift - Tokens: 20834
# Paper: SODA: A System for Cyber Deception Orchestration and - Tokens: 22917
# Paper: TEEKAP : Self-Expiring Data Capsule using - Tokens: 22212
# Paper: Try before You Buy: Privacy-preserving Data Evaluation on - Tokens: 19454
# Paper: Program Obfuscation via ABI Debiasing - Tokens: 17866
# Paper: Reproducible and Adaptable - Tokens: 23973
# Paper: Platform-Oblivious Anti-Spam Gateway - Tokens: 21934
# Paper: Model Extraction Attacks on Graph Neural Networks: - Tokens: 22150
# Paper: SteinerLog : Prize Collecting the Audit Logs for Threat Hunting - Tokens: 17086
# Paper: WINK: Wireless Inference of Numerical Keystrokes via - Tokens: 27408
# Paper: Empirical Analysis of EIP-1559: - Tokens: 25476
# Paper: Constant Latency in Sleepy Consensus - Tokens: 27855
# Paper: Graph Unlearning - Tokens: 28076
# Paper: SSLGuard: A Watermarking Scheme for Self-supervised - Tokens: 25218
# Paper: Finding MNEMON: Reviving Memories of Node Embeddings - Tokens: 27229
# Paper: 𝐴                      𝑆 - Tokens: 33470
# Paper: Low-Latency Hardware Private Circuits - Tokens: 24723
# Paper: Victory by KO: Attacking OpenPGP Using Key Overwriting - Tokens: 24223
# Paper: Sleepy Channels: - Tokens: 28297
# Paper: Two-Client Inner-Product Functional Encryption - Tokens: 30489
# Paper: Distributed, Private, Sparse Histograms in the Two-Server Model - Tokens: 28796
# Paper: Understanding Real-world Threats to Deep Learning Models in - Tokens: 25845
# Paper: VRust: Automated Vulnerability Detection for Solana Smart - Tokens: 21106
# Paper: Truth Serum: Poisoning Machine Learning Models - Tokens: 24281
# Paper: Automatic Detection of Speculative Execution Combinations - Tokens: 26452
# Paper: Proof-of-Possession for KEM Certificates using Verifiable - Tokens: 31709
# Paper: DPIS: An Enhanced Mechanism for Differentially Private SGD - Tokens: 30741
# Paper: Shifted Inverse: A General Mechanism for Monotonic Functions - Tokens: 30476
# Paper: Understanding the How and the Why: Exploring Secure - Tokens: 22875
# Paper: Do Opt-Outs Really Opt Me Out? - Tokens: 28791
# Paper: Escaping the Confines of Time: Continuous Browser - Tokens: 22893
# Paper: QuerySnout: Automating the Discovery of Attribute Inference - Tokens: 28598
# Paper: DirtyCred: Escalating Privilege in Linux Kernel - Tokens: 22788
# Paper: StolenEncoder: Stealing Pre-trained Encoders in Self-supervised - Tokens: 24044
# Paper: Detecting Missing-Permission-Check Vulnerabilities in - Tokens: 22493
# Paper: Leakage Inversion: Towards Quantifying - Tokens: 27664
# Paper: Cross Miniapp Request Forgery: Root Causes, Attacks, and - Tokens: 26520
# Paper: Why So Toxic? Measuring and Triggering Toxic Behavior in - Tokens: 25654
# Paper: Detecting and Measuring Misconfigured Manifests - Tokens: 27011
# Paper: AI/ML for Network Security: The Emperor has no Clothes - Tokens: 28301
# Paper: A Run a Day Won’t Keep the Hacker Away: Inference Attacks on - Tokens: 24710
# Paper: CANflict: Exploiting Peripheral Conflicts for Data-Link Layer - Tokens: 20876
# Paper: Adversarial Correctness and Privacy for Probabilistic Data - Tokens: 30406
# Paper: Privacy Limitations of Interest-based Advertising on The Web: A - Tokens: 18835
# Paper: StrongBox: A GPU TEE on Arm Endpoints - Tokens: 25053
# Paper: L-SRR: Local Differential Privacy for Location-Based Services - Tokens: 29121
# Paper: Understanding IoT Security from a Market-Scale Perspective - Tokens: 27524
# Paper: Ibex: Privacy-preserving Ad Conversion Tracking and Bidding - Tokens: 25279
# Paper: Differentially Private Triangle and 4-Cycle Counting in the - Tokens: 34747
# Paper: Group Property Inference Attacks Against - Tokens: 24905
# Paper: Are Attribute Inference Attacks Just Imputation? - Tokens: 22403
# Paper: Blacktooth: Breaking through the Defense of Bluetooth in Silence - Tokens: 21059
# Paper: HeatDeCam: Detecting Hidden Spy Cameras via Thermal - Tokens: 20289
# Paper: Enhanced Membership Inference Attacks against Machine - Tokens: 24629
# Paper: LoneNeuron: A Highly-Effective Feature-Domain Neural Trojan - Tokens: 28873
# Paper: On the (In)Security of Secure ROS2 - Tokens: 26159
# Paper: Frequency Throttling Side-Channel Attack - Tokens: 25523
# Paper: Federated Boosted Decision Trees with Differential Privacy - Tokens: 27450
# Paper: Efficient Secure Three-Party Sorting - Tokens: 25259
# Paper: Am I Private and If So, how Many? Communicating Privacy - Tokens: 24929
# Paper: Secure Parallel Computation on Privately Partitioned Data and - Tokens: 31548
# Paper: FABEO: Fast Attribute-Based Encryption with Optimal Security - Tokens: 32649
# Paper: SortingHat: Efficient Private Decision Tree Evaluation - Tokens: 29439
# Paper: LPGNet: Link Private Graph Networks for Node Classification - Tokens: 23847
# Paper: Widespread Underestimation of Sensitivity in Differentially - Tokens: 28467
# Paper: Are There Wireless Hidden Cameras Spying on Me? - Tokens: 20505
# Paper: Assessing Model-free Anomaly Detection in - Tokens: 23573
# Paper: Spacelord : Private and Secure Smart Space - Tokens: 22597
# Paper: Stepping out of the MUD: Contextual threat - Tokens: 28049
# Paper: Interaction matters: a comprehensive analysis and a dataset of - Tokens: 19010
# Paper: View from Above: Exploring the Malware Ecosystem from the - Tokens: 16766
# Paper: Accept All Exploits: - Tokens: 18375
# Paper: CoCoTPM: Trusted Platform Modules for Virtual Machines in - Tokens: 15036
# Paper: On the Implications of Spoofing and Jamming Aviation Datalink - Tokens: 18358
# Paper: Squeezing More Utility via Adaptive Clipping - Tokens: 20344
# Paper: Compact Abstract Graphs for Detecting Code Vulnerability with - Tokens: 17186
# Paper: Towards Enhanced EEG-based Authentication with Motor - Tokens: 19138
# Paper: Make Data Reliable : An Explanation-powered - Tokens: 21641
# Paper: DRAGON: Deep Reinforcement Learning for Autonomous Grid - Tokens: 24056
# Paper: Randezvous: Making Randomization Effective - Tokens: 28821
# Paper: MADDC: Multi-Scale Anomaly Detection, Diagnosis and - Tokens: 26092
# Paper: Differentially Private Map Matching for Mobility Trajectories - Tokens: 17105
# Paper: NeuGuard: Lightweight Neu ron-G uided D efense against - Tokens: 27322
# Paper: No Signal Left to Chance: Driving Browser Extension Analysis by - Tokens: 22157
# Paper: AFLGuard: Byzantine-robust Asynchronous Federated Learning - Tokens: 30311
# Paper: ENIDrift: A Fast and Adaptive Ensemble - Tokens: 25517
# Paper: MoLE: M itigation o f Side-channel Attacks against SGX via - Tokens: 23930
# Paper: Are we there yet? An Industrial Viewpoint on - Tokens: 26045
# Paper: Alert Alchemy: SOC Workflows and Decisions in the - Tokens: 25159
# Paper: Black Ostrich: Web Application Scanning with String Solvers - Tokens: 26939
# Paper: CookieGraph: - Tokens: 28687
# Paper: CryptoConcurrency: (Almost) Consensusless Asset Transfer with - Tokens: 25002
# Paper: General Data Protection Runtime: - Tokens: 24326
# Paper: Good-looking but Lacking Faithfulness: Understanding Local - Tokens: 27418
# Paper: Lifting Network Protocol Implementation to Precise Format - Tokens: 31432
# Paper: Narcissus : A Practical Clean-Label Backdoor Attack with Limited - Tokens: 25311
# Paper: Security Verification of Low-Trust Architectures - Tokens: 28513
# Paper: TunneL s for B ootlegging: Fully Reverse-Engineering GPU TLBs - Tokens: 28887
# Paper: PolicyChecker: Analyzing the GDPR Completeness of Mobile - Tokens: 28303
# Paper: Splice: Efficiently Removing a User’s Data from In-memory - Tokens: 25849
# Paper: Phoenix: Detect and Locate Resilience Issues in Blockchain via - Tokens: 26510
# Paper: In Search of netUnicorn: A Data-Collection Platform to Develop - Tokens: 24883
# Paper: Unforgeability in Stochastic Gradient Descent - Tokens: 25512
# Paper: Improving Security Tasks Using Compiler Provenance - Tokens: 22291
# Paper: Verifiable Learning for Robust Tree Ensembles - Tokens: 28317
# Paper: Detecting Violations of Differential Privacy for Quantum - Tokens: 26616
# Paper: Using Range-Revocable Pseudonyms to Provide Backward - Tokens: 27796
# Paper: Exploration of Power Side-Channel Vulnerabilities - Tokens: 23743
# Paper: Learning from Limited Heterogeneous Training Data: - Tokens: 24910
# Paper: martFL: Enabling Utility-Driven Data Marketplace with a Robust - Tokens: 29020
# Paper: HELiKs: HE Linear Algebra Kernels for Secure Inference - Tokens: 27058
# Paper: Cryptographically Enforced Memory Safety - Tokens: 27964
# Paper: Modular Sumcheck Proofs with Applications to Machine - Tokens: 32617
# Paper: The Effectiveness of Security Interventions on GitHub - Tokens: 19079
# Paper: Large Language Models for Code: - Tokens: 26313
# Paper: Attack Some while Protecting Others: - Tokens: 25242
# Paper: Simplifying Mixed Boolean-Arithmetic Obfuscation - Tokens: 29579
# Paper: ProvG-Searcher: A Graph Representation Learning Approach for - Tokens: 27203
# Paper: The Locality of Memory Checking - Tokens: 32409
# Paper: Experimenting with Zero-Knowledge Proofs of Training - Tokens: 29005
# Paper: PANIC: PAN-assisted Intra-process Memory Isolation on ARM - Tokens: 25635
# Paper: Extracting Privacy-Preserving Subgraphs in Federated Graph - Tokens: 21461
# Paper: DeepContract: Controllable Authorization of - Tokens: 20375
# Paper: A Tagging Solution to Discover IoT Devices in Apartments - Tokens: 14952
# Paper: TGC: Transaction Graph Contrast Network for Ethereum - Tokens: 21303
# Paper: Hades: Practical Decentralized Identity with Full Accountability - Tokens: 22992
# Paper: Remote attestation of confidential VMs using ephemeral vTPMs - Tokens: 22181
# Paper: DOPE: DOmain Protection Enforcement with PKS - Tokens: 24896
# Paper: Link Membership Inference Attacks against - Tokens: 23411
# Paper: Remote Attestation with Constrained Disclosure - Tokens: 26415
# Paper: Detecting Weak Keys in Manufacturing Certificates: A Case Study - Tokens: 19514
# Paper: ABFL: A Blockchain-enabled Robust Framework for Secure and - Tokens: 15190
# Paper: A First Look at Toxicity Injection Attacks on Open-domain - Tokens: 23844
# Paper: Detection of Anomalies in Electric Vehicle Charging Sessions - Tokens: 18377
# Paper: Mostree: Malicious Secure Private Decision Tree Evaluation with - Tokens: 31731
# Paper: The Queen’s Guard: A Secure Enforcement of Fine-grained Access - Tokens: 24166
# Paper: Binary Sight-Seeing: Accelerating Reverse Engineering via - Tokens: 21875
# Paper: Secure MLaaS with Temper : Trusted and Efficient Model - Tokens: 24833
# Paper: Lightweight Privacy-Preserving Proximity Discovery - Tokens: 19841
# Paper: PSP-Mal: Evading Malware Detection via Prioritized - Tokens: 23594
# Paper: Scamdog Millionaire: Detecting E-commerce Scams in the Wild - Tokens: 25982
# Paper: When Push Comes to Shove: - Tokens: 18086
# Paper: Mitigating Membership Inference Attacks via Weighted - Tokens: 17203
# Paper: Domain and Website Attribution beyond WHOIS - Tokens: 24255
# Paper: DefWeb: Defending User Privacy against Cache-based Website - Tokens: 24008
# Paper: The Day-After-Tomorrow: - Tokens: 18569
# Paper: FS3: Few-Shot and Self-Supervised Framework for Efficient - Tokens: 21076
# Paper: FLEDGE: Ledger-based Federated Learning Resilient to Inference - Tokens: 33768
# Paper: FraudLens: Graph Structural Learning for Bitcoin Illicit Activity - Tokens: 18655
# Paper: DeepTaster : Adversarial Perturbation-Based Fingerprinting to - Tokens: 23384
# Paper: 3DFed: Adaptive and Extensible Framework for - Tokens: 22732
# Paper: A Domain-Speciﬁc Language for Low-Level Secure - Tokens: 22099
# Paper: A Formal Analysis of 5G Authentication - Tokens: 21778
# Paper: A Formal Foundation for Secure Remote Execution of Enclaves - Tokens: 27745
# Paper: A Formal Treatment of Accountable Proxying over TLS - Tokens: 29516
# Paper: A Generic Approach to Automatic Deobfuscation of Executable Code - Tokens: 29590
# Paper: A Generic Technique for Automatically Finding - Tokens: 22882
# Paper: A Heuristic Framework to Detect Concurrency Vulnerabilities - Tokens: 20675
# Paper: A Large Scale Investigation of Obfuscation Use in Google Play - Tokens: 23825
# Paper: A Lustrum of Malware Network Communication: - Tokens: 23455
# Paper: A Machine Learning Approach To Prevent - Tokens: 21795
# Paper: A Measurement Study of Authentication Rate-Limiting - Tokens: 18820
# Paper: A Measurement Study on Linux Container Security: A￿acks and - Tokens: 20076
# Paper: A Method for V erifying Privacy-Type Properties: - Tokens: 30849
# Paper: A Practical Oblivious Map Data Structure - Tokens: 32649
# Paper: A Principled Approach for ROP Defense - Tokens: 18055
# Paper: A Programming Framework for Differential Privacy - Tokens: 29121
# Paper: A Robust and Efficient Defense against Use-after-Free Exploits - Tokens: 21728
# Paper: A Search Engine Backed by Internet-Wide Scanning - Tokens: 18199
# Paper: A Stealthier Partitioning Attack against Bitcoin Peer-to-Peer Network - Tokens: 27279
# Paper: A Tale of Sea and Sky - Tokens: 20575
# Paper: A Touch of Evil: High-Assurance Cryptographic - Tokens: 28028
# Paper: A Tough call : Mitigating Advanced Code-Reuse Attacks At The Binary Level - Tokens: 29764
# Paper: A2: Analog Malicious Hardware - Tokens: 24261
# Paper: ABS: Scanning Neural Networks for Back-doors by - Tokens: 30368
# Paper: ABY3: A Mixed Protocol Framework for Machine Learning - Tokens: 33436
# Paper: Accuracy-Privacy Trade-off in Deep Ensemble: - Tokens: 27814
# Paper: Accurate Malware Detection by Extreme Abstraction - Tokens: 16942
# Paper: Acing the IOC Game: Toward Automatic Discovery and - Tokens: 22897
# Paper: Ad Injection at Scale: Assessing Deceptive Advertisement Modiﬁcations - Tokens: 25861
# Paper: Address-Oblivious Code Reuse: - Tokens: 23814
# Paper: ADSNARK: Nearly Practical and - Tokens: 32441
# Paper: Advanced Probabilistic Couplings for Differential Privacy - Tokens: 22212
# Paper: Advanced Windows Methods on Malware Detection and - Tokens: 20761
# Paper: Adversarial Data Mining: Big Data Meets Cyber Security - Tokens: 3163
# Paper: “Adversarial Examples” for Proof-of-Learning - Tokens: 16016
# Paper: Adversarial Prefetch: New Cross-Core Cache Side - Tokens: 26045
# Paper: Adversarial Watermarking Transformer: Towards - Tokens: 35815
# Paper: Adversary Instantiation: Lower Bounds for - Tokens: 22468
# Paper: AI-Guardian: - Tokens: 29509
# Paper: AIM-SDN: A￿acking Information Mismanagement in - Tokens: 20282
# Paper: WIP: Auditing Artist Style Pirate in Text-to-image - Tokens: 10074
# Paper: Alchemy: A Language and Compiler for - Tokens: 30075
# Paper: All Y our DNS Records Point to Us - Tokens: 21020
# Paper: An Analysis of Pre-installed Android Software - Tokens: 26900
# Paper: An Empirical Study of Web Vulnerability Discovery - Tokens: 18163
# Paper: An End-to-End System for Large Scale P2P MPC-as-a-Service - Tokens: 26120
# Paper: An Experimental Security Analysis - Tokens: 24806
# Paper: An Extensive Formal Security Analysis of the - Tokens: 30141
# Paper: An In-depth Look Into SDN Topology Discovery Mechanisms: - Tokens: 21057
# Paper: An In-Depth Study of - Tokens: 17693
# Paper: Analyzing and Modeling Longitudinal Security Data: - Tokens: 16039
# Paper: Analyzing Information Leakage of Updates - Tokens: 20744
# Paper: Analyzing Subgraph Statistics from Extended Local Views with - Tokens: 26749
# Paper: Analyzing Ground-Truth Data of Mobile Gambling Scams - Tokens: 27698
# Paper: Analyzing Leakage of Personally Identifiable - Tokens: 28006
# Paper: Angora: Efﬁcient Fuzzing by Principled Search - Tokens: 18462
# Paper: Annotating, Tracking, and Protecting Cryptographic - Tokens: 24799
# Paper: Anti-Tamper Radio: System-Level Tamper - Tokens: 21315
# Paper: 56    COMMUNICATIONS OF THE ACM   |   NOVEMBER 2016  |   VOL. 59  |   NO. 11contributed articles - Tokens: 13501
# Paper: ARBITRAR : User-Guided API Misuse Detection - Tokens: 24945
# Paper: Are anonymity-seekers just like everybody else? - Tokens: 21032
# Paper: Are We There Yet? Timing and Floating-Point - Tokens: 23596
# Paper: Asking for a Friend: - Tokens: 24938
# Paper: ASLR-Guard: - Tokens: 21041
# Paper: Open access to the Proceedings of the - Tokens: 21205
# Paper: Open access to the Proceedings of the - Tokens: 17173
# Paper: Open access to the Proceedings of the - Tokens: 18744
# Paper: This paper is included in the Proceedings of the - Tokens: 21117
# Paper: This paper is included in the Proceedings of the - Tokens: 19358
# Paper: This paper is included in the Proceedings of the - Tokens: 22133
# Paper: Attacking Graph-based Classification via Manipulating the - Tokens: 27326
# Paper: Attacking Graph-Based Classification without Changing - Tokens: 15076
# Paper: A/t_tribute-Based Encryption in the Generic Group Model: - Tokens: 39805
# Paper: Augur: Internet-Wide Detection of Connectivity - Tokens: 24007
# Paper: Augury: Using Data Memory-Dependent - Tokens: 24063
# Paper: Automatic Fingerprinting of Vulnerable BLE IoT Devices with - Tokens: 22239
# Paper: Automatic Inference of Search Patterns - Tokens: 22111
# Paper: Automatic Uncovering of Hidden Behaviors From - Tokens: 24579
# Paper: Automatically Detecting Bystanders in Photos to - Tokens: 25764
# Paper: A First Look at Zoombombing - Tokens: 22608
# Paper: A Secure and Formally V erified Linux KVM Hypervisor - Tokens: 33155
# Paper: A Systematic Look at Ciphertext Side Channels - Tokens: 23249
# Paper: A Theory to Instruct Differentially-Private Learning via Clipping Bias Reduction - Tokens: 31268
# Paper: Back to the Drawing Board: Revisiting the Design of Optimal - Tokens: 21585
# Paper: Back to the Drawing Board: - Tokens: 29082
# Paper: BadEncoder: Backdoor Attacks to Pre-trained - Tokens: 25185
# Paper: Bandwidth-Hard Functions: Reductions and Lower Bounds - Tokens: 32162
# Paper: BayBFed : Bayesian Backdoor Defense for Federated Learning - Tokens: 28147
# Paper: Beauty and the Beast: Diverting modern web - Tokens: 21511
# Paper: Betrayed by the Guardian: - Tokens: 28367
# Paper: BEYOND PHISH : Toward Detecting Fraudulent e-Commerce Websites at Scale - Tokens: 26581
# Paper: Binary Code Continent: Finer-Grained Control Flow Integrity for Stripped - Tokens: 15470
# Paper: Bitcoin-Enhanced Proof-of-Stake Security: - Tokens: 32903
# Paper: Black Widow: Blackbox Data-driven Web Scanning - Tokens: 24890
# Paper: Blind Certiﬁcate Authorities - Tokens: 28403
# Paper: Blue Note: How Intentional Acoustic Interference - Tokens: 24426
# Paper: Bomberman: Deﬁning and Defeating - Tokens: 32769
# Paper: Breaking L TE on Layer Two - Tokens: 24075
# Paper: Breaking Web Applications Built On Top of Encrypted Data - Tokens: 19823
# Paper: Browsing Unicity: On the Limits of - Tokens: 18970
# Paper: Building Applications with Homomorphic Encryption - Tokens: 4150
# Paper: 4652020 IEEE Symposium on Security and Privacy - Tokens: 816
# Paper: C-FLAT: Control-Flow Attestation - Tokens: 21434
# Paper: C3APSULe: Cross-FPGA Covert-Channel Attacks - Tokens: 20782
# Paper: Cache-in-the-Middle (CITM) Attacks : Manipulating Sensitive - Tokens: 24549
# Paper: CacheOut: Leaking Data on Intel CPUs - Tokens: 25074
# Paper: Caelus: Verifying the Consistency of Cloud - Tokens: 25822
# Paper: CALLEE : Recovering Call Graphs for Binaries with Transfer and Contrastive Learning - Tokens: 30835
# Paper: CALM: Consistent Adaptive Local Marginal for - Tokens: 29012
# Paper: CaSE: Cache-Assisted Secure Execution on ARM Processors - Tokens: 24218
# Paper: Casino Royale: A Deep Exploration of Illegal Online - Tokens: 14974
# Paper: SoK: The Challenges, Pitfalls, and Perils of Using - Tokens: 30365
# Paper: CCCP: Closed Caption Crypto Phones to Resist - Tokens: 24790
# Paper: CDL: Classified Distributed Learning for Detecting Security - Tokens: 13289
# Paper: Censored Planet: An Internet-wide, Longitudinal - Tokens: 27293
# Paper: Certificate Transparency in the Wild: - Tokens: 25475
# Paper: Certified Copy? Understanding Security Risks of Wi-Fi Hotspot - Tokens: 22881
# Paper: Certiﬁed Robustness to Adversarial Examples with Differential Privacy - Tokens: 26966
# Paper: Characterizing Pixel Tracking through the Lens of - Tokens: 22797
# Paper: comings discussed above. As the left part of Figure 1 shows, - Tokens: 19725
# Paper: Cinderella: Turning Shabby X.509 Certiﬁcates - Tokens: 35546
# Paper: ClickShield: Are You Hiding Something? - Tokens: 23009
# Paper: Cloak of Visibility: Detecting When Machines - Tokens: 20577
# Paper: Clockwork Finance: Automated Analysis of - Tokens: 30230
# Paper: Collaborative Ad Transparency: Promises and - Tokens: 31334
# Paper: Combating Dependence Explosion in Forensic Analysis - Tokens: 28745
# Paper: Combining Differential Privacy and Secure Multiparty - Tokens: 19136
# Paper: Commoner Privacy And A Study On Network Traces - Tokens: 16767
# Paper: Compact Abstract Graphs for Detecting Code Vulnerability with - Tokens: 17186
# Paper: Comparing the Usability of Cryptographic APIs - Tokens: 23429
# Paper: Comparing Video Based Shoulder Surfing with Live Simulation - Tokens: 21266
# Paper: Compiler-assisted Code Randomization - Tokens: 33163
# Paper: Composite Backdoor Attack for Deep Neural Network by - Tokens: 25592
# Paper: Comprehensive Privacy Analysis of Deep Learning - Tokens: 18604
# Paper: Constrained Concealment Attacks against - Tokens: 52522
# Paper: Continual Observation under User-level Differential Privacy - Tokens: 28392
# Paper: Continuous Intrusion: Characterizingthe Security ofContinuous Integration Services - Tokens: 30738
# Paper: Control Flow and Code Integrity for COTS binaries: - Tokens: 16849
# Paper: Control Flow and Pointer Integrity Enforcement in a Secure Tagged Architecture - Tokens: 23869
# Paper: CoordinatedDataflowProtectionfor - Tokens: 27909
# Paper: Counter-RAPTOR: Safeguarding Tor Against Active - Tokens: 22015
# Paper: Covert Channels through Random Number Generator: - Tokens: 21831
# Paper: Cracking App Isolation on Apple: Unauthorized Cross-App - Tokens: 24437
# Paper: CrawlPhish: Large-scale Analysis of - Tokens: 24422
# Paper: CREDAL: Towards Locating a Memory Corruption - Tokens: 20628
# Paper: CRLite: A Scalable System for - Tokens: 30822
# Paper: Cross-App Poisoning in Software-Defined Networking - Tokens: 27442
# Paper: Crowd-GPS-Sec : Leveraging Crowdsourcing to - Tokens: 19836
# Paper: CRYP TF LOW : Secure TensorFlow Inference - Tokens: 30896
# Paper: CRYPT GPU: Fast Privacy-Preserving Machine Learning on the GPU - Tokens: 30100
# Paper: Cryptographic Function Detection in Obfuscated - Tokens: 26284
# Paper: D-ARM: Disassembling ARM Binaries by - Tokens: 30751
# Paper: D-DAE: Defense-Penetrating Model - Tokens: 32597
# Paper: D2NN: A Fine-Grained Dual Modular Redundancy Framework - Tokens: 16604
# Paper: Dark Hazard: Learning-based, Large-scale Discovery - Tokens: 22229
# Paper: Data Breaches, Phishing, or Malware? - Tokens: 18630
# Paper: Data Recovery on Encrypted Databases With - Tokens: 33128
# Paper: Data-Oriented Programming: - Tokens: 27941
# Paper: Data Privacy in Trigger-Action Systems - Tokens: 33574
# Paper: DBREACH: Stealing from Databases Using - Tokens: 20630
# Paper: Debin: Predicting Debug Information in Stripped Binaries - Tokens: 21346
# Paper: DECANTeR: DEteCtion of Anomalous outbouNd HTTP TRaffic - Tokens: 20439
# Paper: DECO: Liberating Web Data Using Decentralized Oracles for TLS - Tokens: 40777
# Paper: Dedup Est Machina: Memory Deduplication as an Advanced Exploitation V ector - Tokens: 28090
# Paper: DEEPCASE: Semi-Supervised Contextual Analysis of Security Events - Tokens: 30172
# Paper: DeepCoFFEA: Improved Flow Correlation Attacks - Tokens: 27924
# Paper: DeepCorr: Strong Flow Correlation Aacks on Tor - Tokens: 21140
# Paper: DeepDyve: Dynamic Verification for Deep Neural Networks - Tokens: 22581
# Paper: DeepIntent: Deep Icon-Behavior Learning for Detecting - Tokens: 24965
# Paper: DeepLog: Anomaly Detection and Diagnosis from System Logs - Tokens: 25266
# Paper: DeepMem: Learning Graph Neural Network Models for Fast and - Tokens: 18952
# Paper: DeepSteal: Advanced Model Extractions Leveraging Efﬁcient - Tokens: 28469
# Paper: Deep perceptual hashing algorithms with hidden dual purpose: - Tokens: 27616
# Paper: DEFTL: Implementing Plausibly Deniable Encryption in Flash - Tokens: 21812
# Paper: DEFY: A Deniable, Encrypted File System - Tokens: 14095
# Paper: DeHiREC: Detecting Hidden V oice Recorders - Tokens: 23116
# Paper: Drones’ Cryptanalysis - Smashing Cryptography - Tokens: 26639
# Paper: Demystifying Resource Management Risks in Emerging Mobile - Tokens: 27850
# Paper: DEPCOMM : Graph Summarization on System Audit Logs for Attack Investigation - Tokens: 32478
# Paper: Deploying Android Security Updates: an Extensive Study - Tokens: 25600
# Paper: “Desperate Times Call for Desperate Measures”: - Tokens: 24455
# Paper: Detecting (Absent) App-to-app Authentication on Cross-device - Tokens: 15473
# Paper: Detecting Fake Accounts in Online Social Networks - Tokens: 22295
# Paper: Detecting Structurally Anomalous Logins Within Enterprise - Tokens: 16589
# Paper: Detecting AI Trojans - Tokens: 25392
# Paper: Detection of Electromagnetic Interference Attacks - Tokens: 18317
# Paper: Detection of Inconsistencies in Privacy Practices of - Tokens: 25940
# Paper: Deterministic, Stash-Free Write-Only ORAM - Tokens: 23729
# Paper: Device Fingerprinting with Peripheral Timestamps - Tokens: 25712
# Paper: DIANE : Identifying Fuzzing Triggers in Apps to - Tokens: 29804
# Paper: Differential Privacy with Bounded Priors: - Tokens: 18973
# Paper: PrivKV: Key-Value Data Collection with Local - Tokens: 23001
# Paper: Differentially Private Nonparametric Hypothesis Testing - Tokens: 20483
# Paper: Differentially Private Histograms - Tokens: 27066
# Paper: Differential Privacy and Swapping: - Tokens: 20853
# Paper: DIFUZE: Interface Aware Fuzzing for Kernel Drivers - Tokens: 24026
# Paper: DRAFTDiogenes: Lightweight Scalable RSA Modulus - Tokens: 28366
# Paper: DRAFTDiogenes: Lightweight Scalable RSA Modulus - Tokens: 28366
# Paper: Discop: Provably Secure Steganography in Practice - Tokens: 28018
# Paper: DiSE: Distributed Symmetric-key Encryption - Tokens: 34110
# Paper: Dissecting Tor Bridges: a Security Evaluation of - Tokens: 24431
# Paper: Distributed Measurement with Private Set-Union Cardinality - Tokens: 27905
# Paper: DNS Cache Poisoning Attack Reloaded: Revolutions with Side - Tokens: 22202
# Paper: Do Cookie Banners Respect my Choice? - Tokens: 32533
# Paper: Do Y ou Feel What I Hear? Enabling Autonomous - Tokens: 28672
# Paper: Dominance as a New Trusted Computing Primitive - Tokens: 27294
# Paper: Doubly-eﬃcient zkSNARKs without trusted setup - Tokens: 39591
# Paper: DP-Finder: Finding Differential Privacy Violations - Tokens: 30931
# Paper: DP-Sniper: Black-Box Discovery of Differential - Tokens: 32225
# Paper: DR.SGX: Automated and Adjustable Side-Channel Protection - Tokens: 22139
# Paper: dStyle-GAN: Generative Adversarial Network based on - Tokens: 18487
# Paper: Automating Patching of Vulnerable Open-Source - Tokens: 23720
# Paper: DynPTA: Combining Static and Dynamic Analysis - Tokens: 31628
# Paper: Economic Factors of Vulnerability Trade and Exploitation - Tokens: 28084
# Paper: EC: Embedded Systems - Tokens: 26815
# Paper: EdgeMiner: Automatically Detecting Implicit - Tokens: 19427
# Paper: Effective Real-time Android Application Auditing - Tokens: 20257
# Paper: Effective Seed Scheduling for Fuzzing with - Tokens: 26702
# Paper: Efﬁcient Genome-Wide, Privacy-Preserving Similar Patient - Tokens: 20444
# Paper: Efficient Multi-Key Homomorphic Encryption - Tokens: 34196
# Paper: Efficient Oblivious Substring Search via Architectural Support - Tokens: 36350
# Paper: EKHUNTER : A Counter-Offensive Toolkit for - Tokens: 22632
# Paper: ELSA: Secure Aggregation for Federated Learning with Malicious Actors - Tokens: 33381
# Paper: EmPoWeb: Empowering Web Applications with - Tokens: 29077
# Paper: Enabling Rack-scale Conﬁdential Computing using - Tokens: 28223
# Paper: EnclaveDB: A Secure Database using SGX - Tokens: 22340
# Paper: Encrypted Databases: - Tokens: 29506
# Paper: 2NnL3a - Tokens: 73545
# Paper: EpicRec: Towards Practical Differentially Private - Tokens: 20141
# Paper: Equivalence-based Security for Querying Encrypted - Tokens: 27111
# Paper: Error Handling of In-vehicle Networks Makes Them Vulnerable - Tokens: 21229
# Paper: Estimating g-Leakage via Machine Learning - Tokens: 27573
# Paper: eThor : Practical and Provably Sound Static Analysis - Tokens: 37469
# Paper: Evading Classifiers by Morphing in the Dark - Tokens: 21241
# Paper: Evaluating Fuzz Testing - Tokens: 24578
# Paper: Even Black Cats Cannot Stay Hidden in the Dark: - Tokens: 17763
# Paper: EviHunter: Identifying Digital Evidence in the Permanent - Tokens: 20027
# Paper: &Y3BZ %FUFDUJPO PG )JTUPSZ-FBLJOH #SPXTFS&YUFOTJPOT - Tokens: 41698
# Paper: Exaggerated Error Handling Hurts! An In-Depth Study and - Tokens: 26330
# Paper: Experimental Study with Real-world Data for Android App - Tokens: 16071
# Paper: Exploitation and Mitigation of Authentication Schemes - Tokens: 18075
# Paper: Exploiting a Thermal Side Channel for Power Attacks in - Tokens: 24286
# Paper: Exploiting and Protecting Dynamic Code Generation - Tokens: 23645
# Paper: Exploiting Correcting Codes: On the Effectiveness - Tokens: 27271
# Paper: Exploiting Unintended Feature Leakage - Tokens: 21074
# Paper: Exploit the Last Straw That Breaks Android Systems - Tokens: 29204
# Paper: F-BLEAU: Fast Black-box Leakage Estimation - Tokens: 23021
# Paper: Faceted Secure Multi Execution - Tokens: 30999
# Paper: Fallout: Leaking Data on Meltdown-resistant CPUs - Tokens: 25334
# Paper: FAME: Fast Attribute-based Message Encryption - Tokens: 34144
# Paper: Fast Database Joins and PSI for Secret Shared Data - Tokens: 41918
# Paper: This paper is included in the Proceedings of the - Tokens: 20782
# Paper: This paper is included in the Proceedings of the - Tokens: 20023
# Paper: FeatureSmith: Automatically Engineering Features for - Tokens: 19217
# Paper: Februus: Input Purification Defense Against - Tokens: 21774
# Paper: Fidelius: Protecting User Secrets - Tokens: 27489
# Paper: Fill in the B lanks: Empirical Analysis of the Privacy Threats of - Tokens: 20637
# Paper: Finding Dependencies between Cyber-Physical Domains for - Tokens: 17868
# Paper: Fingerprinting the Fingerprinters: - Tokens: 34361
# Paper: FirmXRay: Detecting Bluetooth Link Layer Vulnerabilities - Tokens: 23862
# Paper: Five Years of the Right to be Forgotten - Tokens: 18639
# Paper: Flamingo: Multi-Round Single-Server Secure Aggregation - Tokens: 32754
# Paper: Flash Boys 2.0: - Tokens: 25338
# Paper: “Flawed, but like democracy we don’t have a better system” : - Tokens: 24595
# Paper: FlowWatcher: Defending against Data Disclosure - Tokens: 22885
# Paper: FLUTE: Fast and Secure Lookup Table Evaluations - Tokens: 32846
# Paper: FlyClient: Super-Light Clients for Cryptocurrencies - Tokens: 31479
# Paper: Following Devil’s Footprints: Cross-Platform - Tokens: 30778
# Paper: Forensic Analysis in Access Control: Foundations and a - Tokens: 34933
# Paper: Formal Model-Driven Discovery - Tokens: 38831
# Paper: Forward Secure Asynchronous Messaging from - Tokens: 23454
# Paper: Forward Secure Dynamic Searchable Symmetric Encryption - Tokens: 25675
# Paper: FP-STALKER : - Tokens: 20600
# Paper: FPGA-Based Remote Power Side-Channel Attacks - Tokens: 23127
# Paper: FPSelect: Low-Cost Browser Fingerprints for Mitigating - Tokens: 25159
# Paper: Fraud De-Anonymization For Fun and Profit - Tokens: 26852
# Paper: Fraud Detection through - Tokens: 1899
# Paper: FreeDom: Engineering a State-of-the-Art DOM Fuzzer - Tokens: 25887
# Paper: Frequency-Hiding Order-Preserving Encryption - Tokens: 17540
# Paper: From Facepalm to Brain Bender: - Tokens: 17410
# Paper: From trash to treasure: timing-sensitive garbage - Tokens: 25920
# Paper: From Grim Reality to Practical Solution: Malware Classification in Real-World - Tokens: 36044
# Paper: FSAFlow: Lightweight and Fast Dynamic Path Tracking - Tokens: 34229
# Paper: Fuzzing File Systems via - Tokens: 27518
# Paper: Game-Set-MATCH: Using Mobile Devices for Seamless - Tokens: 37662
# Paper: GAN-Leaks: A Taxonomy of Membership Inference Attacks - Tokens: 26717
# Paper: GEESOLVER : A Generic, Efficient, and Effortless Solver with Self-Supervised - Tokens: 23713
# Paper: Generic Attacks on Secure Outsourced Databases - Tokens: 19208
# Paper: Geneva: Evolving Censorship Evasion Strategies - Tokens: 23840
# Paper: GenoGuard: Protecting Genomic Data against - Tokens: 25321
# Paper: Gesture Authentication for Smartphones: Evaluation - Tokens: 32165
# Paper: Getting to know your Card: Reverse-Engineering the - Tokens: 16780
# Paper: Gollum: Modular and Greybox Exploit Generation - Tokens: 27226
# Paper: Goshawk: Hunting Memory Corruptions via - Tokens: 27341
# Paper: Gracewipe: - Tokens: 26018
# Paper: GraphSC: Parallel Secure Computation Made Easy - Tokens: 27898
# Paper: GraphSPD: Graph-Based Security Patch Detection - Tokens: 30696
# Paper: GROV E: Ownership Verification of Graph Neural Networks using Embeddings - Tokens: 26824
# Paper: GuardSpark++: Fine-Grained Purpose-Aware Access Control for - Tokens: 30129
# Paper: GUITAR: Piecing Together Android App GUIs from - Tokens: 19412
# Paper: HACLxN: Verified Generic SIMD Crypto - Tokens: 33664
# Paper: Handling Reboots and Mobility in 802.15.4 Security - Tokens: 14847
# Paper: Happer: Unpacking Android Apps via a - Tokens: 40161
# Paper: Hardware-Backed Heist - Tokens: 22564
# Paper: Hardware-Software Contracts for - Tokens: 28596
# Paper: Hash First, Argue Later - Tokens: 23570
# Paper: Hawkeye: Towards a Desired Directed Grey-box Fuzzer - Tokens: 24388
# Paper: HDFI: Hardware-Assisted Data-ﬂow Isolation - Tokens: 28221
# Paper: Hearing Your Voice is Not Enough: An Articulatory Gesture - Tokens: 19920
# Paper: Heavy Hitter Estimation over Set-Valued Data with Local - Tokens: 20368
# Paper: Helen: Maliciously Secure Coopetitive Learning for Linear Models - Tokens: 23065
# Paper: Here Is Your Fingerprint! Actual Risk versus User Perception of - Tokens: 23549
# Paper: HexType: Eﬀicient Detection of Type Confusion Errors for C++ - Tokens: 21991
# Paper: HideNoSeek: Camouflaging Malicious JavaScript in Benign ASTs - Tokens: 25454
# Paper: Hiding in Plain Sight: - Tokens: 24900
# Paper: High Fidelity Data Reduction for Big Data Security - Tokens: 19481
# Paper: High Precision Open-World Website Fingerprinting - Tokens: 23784
# Paper: High-Assurance Cryptography in the Spectre Era - Tokens: 29974
# Paper: High-Speed Inter-domain Fault Localization - Tokens: 29945
# Paper: Hijacking Bitcoin: Routing Attacks on Cryptocurrencies - Tokens: 26609
# Paper: Hindsight: Understanding the Evolution of UI Vulnerabilities in - Tokens: 20468
# Paper: HisTor": Differentially Private and Robust - Tokens: 22585
# Paper: HoneyPLC: A Next-Generation Honeypot - Tokens: 19179
# Paper: HORNET: High-speed Onion Routing at the Network Layer - Tokens: 23834
# Paper: Happiness index: Right-sizing the cloud’s tenant-provider interface - Tokens: 8307
# Paper: Houdini’s Escape: Breaking the Resource Rein of - Tokens: 19723
# Paper: How They Did It: An Analysis of Emission - Tokens: 33049
# Paper: How to Accurately and Privately Identify Anomalies - Tokens: 31477
# Paper: How to Learn Klingon Without a Dictionary: - Tokens: 26852
# Paper: How to Use Bitcoin to Play Decentralized Poker - Tokens: 23861
# Paper: How Well Do My Results Generalize? Comparing - Tokens: 36435
# Paper: How Did That Get In My Phone? - Tokens: 27424
# Paper: How IoT Re-using Threatens Your Sensitive Data: - Tokens: 23779
# Paper: How Not to Protect Your IP – An Industry-Wide - Tokens: 24126
# Paper: How to Attack and Generate Honeywords - Tokens: 32306
# Paper: Humpty Dumpty: - Tokens: 36793
# Paper: Hypnoguard: Protecting Secrets across Sleep-wake Cycles - Tokens: 22138
# Paper: I Know What You Did Last Login: Inconsistent Messages Tell - Tokens: 21628
# Paper: I Know What You See: Power Side-Channel A￿ack on - Tokens: 22031
# Paper: I Know Where You Parked Last Summer - Tokens: 19248
# Paper: ICLab: A Global, Longitudinal - Tokens: 27519
# Paper: Identifying Personal DNA Methylation Proﬁles by - Tokens: 31444
# Paper: If This Then What? Controlling Flows in IoT Apps - Tokens: 28480
# Paper: IJON: Exploring Deep State Spaces via Fuzzing - Tokens: 23992
# Paper: iLock: Immediate and Automatic Locking of Mobile - Tokens: 16694
# Paper: Implementing and Proving the TLS 1.3 Record Layer - Tokens: 32813
# Paper: Implementing Conjunction Obfuscation under - Tokens: 30723
# Paper: Improved Reconstruction Attacks on - Tokens: 27712
# Paper: Improving Accuracy of Android Malware Detection with - Tokens: 19081
# Paper: Improving Intrusion Detectors by Crook-sourcing - Tokens: 19860
# Paper: Improving security and usability of passphrases with guided - Tokens: 13624
# Paper: Improving Developers’ Understanding of Regex Denial of Service Tools through - Tokens: 30025
# Paper: Improving Password Guessing via - Tokens: 29154
# Paper: Inference Attacks on - Tokens: 18142
# Paper: Inferring User Routes and Locations using - Tokens: 24328
# Paper: Information Leakage in Embedding Models - Tokens: 21667
# Paper: Inlined Information Flow Monitoring for JavaScript - Tokens: 22757
# Paper: Insecure Until Proven Updated: - Tokens: 19166
# Paper: Insecurity of Voice Solution VoLTE in LTE Mobile Networks - Tokens: 21125
# Paper: IntegriDB: Veriﬁable SQL for Outsourced Databases - Tokens: 20734
# Paper: Intriguer: Field-Level Constraint Solving for Hybrid Fuzzing - Tokens: 25671
# Paper: Intriguing Properties of Adversarial ML Attacks - Tokens: 31794
# Paper: Investigating - Tokens: 29836
# Paper: Investigating Package Related Security Threats in Software Registries - Tokens: 26812
# Paper: Invisible Probe: Timing Attacks with PCIe - Tokens: 27729
# Paper: IPvSeeYou: Exploiting Leaked Identiﬁers in IPv6 for - Tokens: 23315
# Paper: Iron: Functional Encryption using Intel SGX - Tokens: 32753
# Paper: IRShield: A Countermeasure Against Adversarial - Tokens: 24416
# Paper: Is Interaction Necessary for Distributed Private Learning? - Tokens: 33732
# Paper: Is Private Learning Possible - Tokens: 27674
# Paper: It’s (DOM) Clobbering Time: Attack Techniques, Prevalence, and Defenses - Tokens: 34090
# Paper: It’s like flossing your teeth: On the Importance and Challenges of - Tokens: 27897
# Paper: IVD: Automatic Learning and Enforcement of - Tokens: 22631
# Paper: IvoriWatch: Exploring Transparent Integrity Verification of - Tokens: 15917
# Paper: JaTE: Transparent and Efﬁcient JavaScript Conﬁnement - Tokens: 16509
# Paper: Jbeil : Temporal Graph-Based Inductive Learning to Infer Lateral Movement in - Tokens: 24079
# Paper: Jigsaw Puzzle: Selective Backdoor Attack to Subvert Malware Classiﬁers - Tokens: 32213
# Paper: JITGuard: Hardening Just-in-time Compilers with SGX - Tokens: 23124
# Paper: JN-SAF : Precise and Efficient NDK/JNI-aware Inter-language - Tokens: 23032
# Paper: JStap: A Static Pre-Filter for Malicious - Tokens: 21349
# Paper: KAIROS : Practical Intrusion Detection and Investigation - Tokens: 29518
# Paper: Kakute: A Precise, Unified Information Flow Analysis System - Tokens: 22361
# Paper: KARONTE : Detecting Insecure - Tokens: 30469
# Paper: Key Reinstallation Attacks: Forcing Nonce Reuse in WPA2 - Tokens: 25396
# Paper: KHyperLogLog: Estimating Reidentiﬁability and - Tokens: 17248
# Paper: Kiss from a Rogue: Evaluating Detectability of - Tokens: 21093
# Paper: Kobold: Evaluating Decentralized Access Control for - Tokens: 20631
# Paper: KRACE : Data Race Fuzzing for Kernel File Systems - Tokens: 28914
# Paper: LAMBRETTA : Learning to Rank for Twitter - Tokens: 24876
# Paper: Large-Scale and Language-Oblivious - Tokens: 23915
# Paper: Latent Typing Biometrics in Online Collaboration Services - Tokens: 15571
# Paper: Lattice Basis Reduction Attack against Physically - Tokens: 17115
# Paper: Lattice-Based Group Signatures and - Tokens: 32786
# Paper: Lawful Device Access without Mass Surveillance Risk: - Tokens: 23015
# Paper: LazyTAP: On-Demand Data Minimization for - Tokens: 31011
# Paper: LBM: A Security Framework for Peripherals within - Tokens: 26552
# Paper: Leakage-Abuse Attacks against Order-Revealing Encryption - Tokens: 26144
# Paper: Leakage-Abuse Attacks Against Searchable Encryption - Tokens: 19131
# Paper: LeakyPick: IoT Audio Spy Detector - Tokens: 18887
# Paper: Learning from Mutants: - Tokens: 17951
# Paper: Learning to Fuzz from Symbolic Execution - Tokens: 28728
# Paper: 2466 IEEE/ACM TRANSACTIONS ON AUDIO, SPEECH, AND LANGUAGE PROCESSING, VOL. 24, NO. 12, DECEMBER 2016 - Tokens: 22119
# Paper: Learning Differentially Private Mechanisms - Tokens: 20892
# Paper: Leave Me Alone: App-level Protection Against - Tokens: 27884
# Paper: Leave Your Phone at the Door: - Tokens: 14786
# Paper: LegoSNARK: Modular Design and Composition of - Tokens: 39738
# Paper: LEMNA: Explaining Deep Learning based Security Applications - Tokens: 26493
# Paper: Let’s Encrypt: An Automated Certificate - Tokens: 27174
# Paper: Let’s Go in for a Closer Look: - Tokens: 29626
# Paper: Leveraging Prefix Structure to Detect Volumetric DDoS Attack Signatures with - Tokens: 29054
# Paper: LevioSA: Lightweight Secure Arithmetic Computation - Tokens: 31433
# Paper: Liar, Liar, Coins on Fire! - Tokens: 22130
# Paper: LibreCAN: Automated CAN Message Translator - Tokens: 24293
# Paper: Lifelong Anomaly Detection Through Unlearning - Tokens: 22617
# ...
# Paper: SoK: How Robust is Image Classiﬁcation Deep - Tokens: 26886
# Paper: SoK: Let the Privacy Games Begin! - Tokens: 27507
# Paper: SoK: Practical Foundations for Software Spectre Defenses - Tokens: 23735
# Paper: SoK: Privacy-Preserving Data Synthesis - Tokens: 36889
# Paper: SoK: Prudent Evaluation Practices for Fuzzing - Tokens: 33614
# Paper: SoK: Quantifying Cyber Risk - Tokens: 26831
# Paper: SoK: Shining Light on Shadow Stacks - Tokens: 21583
# Paper: SoK: The Faults in our ASRs: An Overview of - Tokens: 29633
# Paper: Solidus: - Tokens: 27746
# Paper: Spectral-DP: D ifferentially P rivate Deep Learning through Spectral Perturbation - Tokens: 28182
# Paper: Spectre Declassified: Reading from the Right Place - Tokens: 28476
# Paper: Speculative Probing: Hacking Blind in the Spectre Era - Tokens: 26165
# Paper: Sphinx: Enabling Privacy-Preserving Online Learning over the Cloud - Tokens: 22698
# Paper: SPIDER : Enabling Fast Patch Propagation - Tokens: 30767
# Paper: SPIRAL : Fast, High-Rate Single-Server PIR via FHE Composition - Tokens: 30280
# Paper: Spotless Sandboxes: Evading Malware Analysis - Tokens: 23179
# Paper: Spotlight: Malware Lead Generation at Scale - Tokens: 15024
# Paper: Countering Malicious Processes with - Tokens: 23255
# Paper: Statistical Quantiﬁcation of Differential Privacy: - Tokens: 35572
# Paper: StegoNet : Turn Deep Neural Network into a Stegomalware - Tokens: 18277
# Paper: STOCH FUZZ: Sound and Cost-effective Fuzzing of - Tokens: 34034
# Paper: Stormy: Statistics in Tor by Measuring Securely - Tokens: 33019
# Paper: STRIP: A Defence Against Trojan Attacks on - Tokens: 19262
# Paper: Study and Mitigation of Origin Stripping - Tokens: 23809
# Paper: StyleFool: Fooling Video Classiﬁcation Systems via Style Transfer - Tokens: 30505
# Paper: Sunlight: Fine-grained Targeting Detection at Scale with - Tokens: 23620
# Paper: Surakav: Generating Realistic Traces for a Strong - Tokens: 30831
# Paper: SurroundWeb : Mitigating Privacy Concerns - Tokens: 19849
# Paper: Survivalism: Systematic Analysis of Windows - Tokens: 23899
# Paper: μSWITCH : Fast Kernel Context Isolation with - Tokens: 27492
# Paper: Synthesis of Probabilistic Privacy Enforcement - Tokens: 30129
# Paper: Synthesizing Plausible Privacy-Preserving Location Traces - Tokens: 28692
# Paper: T-Fuzz: fuzzing by program transformation - Tokens: 25123
# Paper: T-Fuzz: fuzzing by program transformation - Tokens: 25655
# Paper: Tactical Provenance Analysis for - Tokens: 29477
# Paper: TaintART: A Practical Multi-level Information-Flow Tracking - Tokens: 17754
# Paper: Take It or Leave It: - Tokens: 22321
# Paper: Talek: Private Group Messaging with Hidden Access Patterns - Tokens: 27857
# Paper: Talking with Familiar Strangers: An Empirical Study on HTTPS - Tokens: 23137
# Paper: Talos: Neutralizing Vulnerabilities with Security - Tokens: 27886
# Paper: TaoStore: Overcoming Asynchronicity in Oblivious - Tokens: 30309
# Paper: Targeted Online Password Guessing: - Tokens: 25815
# Paper: PMTUD is not Panacea: Revisiting IP Fragmentation - Tokens: 29637
# Paper: TEEzz: Fuzzing Trusted Applications on COTS - Tokens: 27099
# Paper: TELEPATH : A Minecraft-based Covert Communication System - Tokens: 17340
# Paper: Temporal Lensing and its Application in - Tokens: 15487
# Paper: TESEC: Accurate Server-side Attack Investigation - Tokens: 24108
# Paper: Tesseract: Real-Time Cryptocurrency Exchange Using - Tokens: 31834
# Paper: The Art and Cra/f_t of Fraudulent App Promotion in Google Play - Tokens: 31759
# Paper: The Attack of the Clones: A Study of the Impact of - Tokens: 61964
# Paper: The Boon and Bane of Cross-Signing: Shedding Light on a - Tokens: 32368
# Paper: The Cards Aren’t Alright: Detecting Counterfeit - Tokens: 15938
# Paper: The Catcher in the Field: A Fieldprint based Spoofing Detection - Tokens: 24285
# Paper: The Code That Never Ran: - Tokens: 24651
# Paper: The Cookie Hunter: Automated Black-box Auditing for Web - Tokens: 29727
# Paper: The Cracked Cookie Jar: HTTP Cookie Hijacking - Tokens: 28717
# Paper: The Feasibility of Dynamically Granted Permissions: - Tokens: 26464
# Paper: The Gap Game - Tokens: 24788
# Paper: The Honey Badger of BFT Protocols - Tokens: 19981
# Paper: The Many Kinds of Creepware Used for - Tokens: 27861
# Paper: The Misuse of Android Unix Domain Sockets - Tokens: 17741
# Paper: The Ring of Gyges: Investigating the Future of Criminal - Tokens: 20330
# Paper: The Rise of the Citizen Developer: Assessing the - Tokens: 21108
# Paper: The Shadow Nemesis: Inference Attacks on Efﬁciently - Tokens: 16700
# Paper: TheSICILIAN Defense: - Tokens: 27888
# Paper: The Spyware Used in Intimate Partner Violence - Tokens: 27700
# Paper: The State of the Uniform: Attacks on Encrypted - Tokens: 31275
# Paper: The Value of Collaboration in Convex Machine - Tokens: 22350
# Paper: The Web’s Sixth Sense: - Tokens: 24654
# Paper: The “Web/Local” Boundary Is Fuzzy: - Tokens: 24822
# Paper: The State of the SameSite: Studying the Usage, - Tokens: 31352
# Paper: Three Birds with One Stone: Efficient Partitioning Attacks on - Tokens: 22297
# Paper: Threshold Password-Hardened Encryption Services - Tokens: 35426
# Paper: Threshold Signatures in the Multiverse - Tokens: 27013
# Paper: Throwing Darts in the Dark? Detecting Bots with - Tokens: 27893
# Paper: Throwing Darts in the Dark? Detecting Bots with - Tokens: 27910
# Paper: Thwarting Memory Disclosure with Efﬁcient - Tokens: 20921
# Paper: Time-Print: Authenticating USB Flash Drives with - Tokens: 22968
# Paper: Tiresias: Predicting Security Events Through Deep Learning - Tokens: 20824
# Paper: TokenScope: Automatically Detecting Inconsistent Behaviors of - Tokens: 38153
# Paper: Toss a Fault to Y our Witcher: Applying Grey-box Coverage-Guided Mutational Fuzzing to Detect - Tokens: 26618
# Paper: Touching the Untouchables: Dynamic Security - Tokens: 25367
# Paper: Towards a Natural Perspective of Smart Homes for - Tokens: 28032
# Paper: Towards Automated Safety Vetting of PLC Code - Tokens: 28810
# Paper: Towards Automatic Generation of Security-Centric - Tokens: 20279
# Paper: Towards Continuous Access Control Validation and Forensics - Tokens: 25159
# Paper: Towards Effective Differential Privacy Communication for - Tokens: 29447
# Paper: Towards Fine-grained Network Security Forensics and Diagnosis - Tokens: 19536
# Paper: Towards Making Systems Forget with Machine Unlearning - Tokens: 36814
# Paper: Towards Practical Differentially Private Convex - Tokens: 24875
# Paper: Towards Realistic Membership Inferences: - Tokens: 19839
# Paper: Towards a Rigorous Statistical Analysis of Empirical - Tokens: 35258
# Paper: Town Crier: - Tokens: 19521
# Paper: Tracking Certiﬁcate Misissuance in the Wild - Tokens: 21186
# Paper: Tracking Ransomware End-to-end - Tokens: 23200
# Paper: Tracking Users across the Web via TLS Session Resumption - Tokens: 13820
# Paper: TrafficSliver: Fighting Website Fingerprinting Attacks with - Tokens: 25478
# Paper: TRAKS: A Universal Key Management Scheme for ERTMS - Tokens: 19308
# Paper: Transcending T RANSCEND : Revisiting Malware - Tokens: 28711
# Paper: Transparent Data Deduplication in the Cloud - Tokens: 26828
# Paper: Triplet Fingerprinting: More Practical and Portable Website - Tokens: 23375
# Paper: TrojanModel: A Practical Trojan Attack against - Tokens: 21908
# Paper: TROLL MAGNIFIER : Detecting State-Sponsored Troll Accounts on Reddit - Tokens: 22682
# Paper: Troubleshooting an Intrusion Detection Dataset: - Tokens: 9985
# Paper: Trouble Over-The-Air: An Analysis of FOTA Apps in the Android Ecosystem - Tokens: 27811
# Paper: TrustOTP: Transforming Smartphones into Secure - Tokens: 19373
# Paper: Trust, But Verify: A Longitudinal Analysis Of - Tokens: 23725
# Paper: Truth Will Out: Departure-Based Process-Level Detection of - Tokens: 21851
# Paper: Twice the Bits, Twice the Trouble: - Tokens: 18902
# Paper: Typing High-Speed Cryptography against Spectre v1 - Tokens: 28629
# Paper: Under the Shadow of Sunshine: Understanding and - Tokens: 28994
# Paper: Understanding Linux Malware - Tokens: 25582
# Paper: Understanding and Bridging the Gap Between Unsupervised Network - Tokens: 28364
# Paper: Understanding the (In)Security of Cross-side Face - Tokens: 26386
# Paper: Unearthing Stealthy Program Attacks - Tokens: 19712
# Paper: Unexpected Data Dependency Creation and - Tokens: 23585
# Paper: UniSan: Proactive Kernel Memory Initialization - Tokens: 22830
# Paper: Universal 3-Dimensional Perturbations for - Tokens: 32577
# Paper: Unveiling Hardware-based Data Prefetcher, a Hidden Source of - Tokens: 23860
# Paper: Updatable Oblivious Key Management for Storage Systems - Tokens: 27622
# Paper: Usage Patterns of Privacy-Enhancing Technologies - Tokens: 26705
# Paper: Use Privacy in Data-Driven Systems - Tokens: 30328
# Paper: This paper is included in the Proceedings of the - Tokens: 21539
# Paper: This paper is included in the Proceedings of the - Tokens: 26583
# Paper: This paper is included in the Proceedings of the - Tokens: 23629
# Paper: This paper is included in the Proceedings of the - Tokens: 26173
# Paper: This paper is included in the Proceedings of the - Tokens: 24922
# Paper: This paper is included in the Proceedings of the - Tokens: 26887
# Paper: This paper is included in the Proceedings of the - Tokens: 19253
# Paper: This paper is included in the Proceedings of the - Tokens: 27235
# Paper: This paper is included in the Proceedings of the - Tokens: 24204
# Paper: This paper is included in the Proceedings of the - Tokens: 24294
# Paper: This paper is included in the Proceedings of the - Tokens: 22445
# Paper: This paper is included in the Proceedings of the - Tokens: 23786
# Paper: This paper is included in the Proceedings of the - Tokens: 22428
# Paper: This paper is included in the Proceedings of the - Tokens: 26238
# Paper: This paper is included in the Proceedings of the - Tokens: 22624
# Paper: This paper is included in the Proceedings of the - Tokens: 27034
# Paper: This paper is included in the Proceedings of the - Tokens: 26051
# Paper: This paper is included in the Proceedings of the - Tokens: 25659
# Paper: This paper is included in the Proceedings of the - Tokens: 24594
# Paper: This paper is included in the Proceedings of the - Tokens: 22013
# Paper: This paper is included in the Proceedings of the - Tokens: 24583
# Paper: This paper is included in the Proceedings of the - Tokens: 31448
# Paper: This paper is included in the Proceedings of the - Tokens: 21627
# Paper: This paper is included in the Proceedings of the - Tokens: 29267
# Paper: This paper is included in the Proceedings of the - Tokens: 30835
# Paper: This paper is included in the Proceedings of the - Tokens: 28951
# Paper: This paper is included in the Proceedings of the - Tokens: 25835
# Paper: This paper is included in the Proceedings of the - Tokens: 25166
# Paper: This paper is included in the Proceedings of the - Tokens: 22812
# Paper: This paper is included in the Proceedings of the - Tokens: 25664
# Paper: This paper is included in the Proceedings of the - Tokens: 23816
# Paper: This paper is included in the Proceedings of the - Tokens: 25780
# Paper: This paper is included in the Proceedings of the - Tokens: 23846
# Paper: This paper is included in the Proceedings of the - Tokens: 22404
# Paper: This paper is included in the Proceedings of the - Tokens: 24275
# Paper: This paper is included in the Proceedings of the - Tokens: 22758
# Paper: This paper is included in the Proceedings of the - Tokens: 25113
# Paper: This paper is included in the Proceedings of the - Tokens: 26416
# Paper: This paper is included in the Proceedings of the - Tokens: 25443
# Paper: This paper is included in the Proceedings of the - Tokens: 23944
# Paper: This paper is included in the Proceedings of the - Tokens: 26311
# Paper: This paper is included in the Proceedings of the - Tokens: 24232
# Paper: This paper is included in the Proceedings of the - Tokens: 26894
# Paper: This paper is included in the Proceedings of the - Tokens: 21339
# Paper: This paper is included in the Proceedings of the - Tokens: 24158
# Paper: This paper is included in the Proceedings of the - Tokens: 23115
# Paper: This paper is included in the Proceedings of the - Tokens: 26484
# Paper: Using Hardware Features for Increased Debugging - Tokens: 22417
# Paper: Utility-Aware Synthesis of Differentially Private and - Tokens: 25938
# Paper: VC3: Trustworthy Data Analytics in the Cloud using SGX - Tokens: 26789
# Paper: Vectorized Batch Private Information Retrieval - Tokens: 23340
# Paper: V erena: End-to-End Integrity Protection - Tokens: 27919
# Paper: V erifying and Synthesizing Constant-Resource Implementations with Types - Tokens: 31042
# Paper: Verifying Security Policies in Multi-agent Workflows with Loops - Tokens: 23303
# Paper: VerX: Safety Veriﬁcation of Smart Contracts - Tokens: 25307
# Paper: V etting SSL Usage in Applications with SSL INT - Tokens: 23985
# Paper: Viden: Attacker Identification on In-Vehicle Networks - Tokens: 25434
# Paper: VisualPhishNet: Zero-Day Phishing Website Detection by - Tokens: 22800
# Paper: VMHunt: A Verifiable Approach to Partially-Virtualized Binary - Tokens: 25848
# Paper: VoiceLive: A Phoneme Localization based Liveness - Tokens: 21439
# Paper: Volttack : Control IoT Devices by Manipulating Power Supply Voltage - Tokens: 22816
# Paper: vRAM: Faster Veriﬁable RAM With - Tokens: 35395
# Paper: vSQL: Verifying Arbitrary SQL Queries over - Tokens: 31624
# Paper: VTint : Protecting Virtual Function Tables’ Integrity - Tokens: 12035
# Paper: Waldo: A Private Time-Series Database from - Tokens: 36303
# Paper: walk2friends: Inferring Social Links from Mobility Profiles - Tokens: 21483
# Paper: Walls Have Ears! Opportunistically Communicating Secret - Tokens: 19658
# Paper: WATSON : Abstracting Behaviors from Audit Logs - Tokens: 28318
# Paper: WaVe: a veriﬁably secure WebAssembly sandboxing runtime - Tokens: 28476
# Paper: WearID: Low-Effort Wearable-Assisted Authentication of Voice - Tokens: 20435
# Paper: W - Tokens: 5118
# Paper: WebCapsule: Towards a Lightweight Forensic Engine - Tokens: 21029
# Paper: What Else is Revealed by Order-Revealing Encryption? - Tokens: 16144
# Paper: When CSI Meets Public WiFi: Inferring Your Mobile Phone - Tokens: 17464
# Paper: When Good Becomes Evil: Keystroke Inference with - Tokens: 21629
# Paper: When the Differences in Frequency Domain are Compensated: - Tokens: 31444
# Paper: When Y our Fitness Tracker Betrays Y ou: Quantifying the Predictability of - Tokens: 22758
# Paper: When and Why Do People Want Ad Targeting Explanations? Evidence from a - Tokens: 26975
# Paper: When Function Signature Recovery Meets Compiler - Tokens: 27219
# Paper: When Top-down Meets Bottom-up: Detecting and - Tokens: 24437
# Paper: Which Privacy and Security Attributes Most Impact Consumers’ Risk - Tokens: 42054
# Paper: Who’s in Control of Your Control System? - Tokens: 18862
# Paper: Why Does Y our Data Leak? Uncovering the Data - Tokens: 21618
# Paper: Why Crypto-detectors Fail : A Systematic Evaluation - Tokens: 33718
# Paper: WIGHT : Wired Ghost Touch Attack on Capacitive - Tokens: 23998
# Paper: Wild Patterns: Ten Years After the Rise of Adversarial Machine - Tokens: 4138
# Paper: Wobfuscator: Obfuscating JavaScript Malware via - Tokens: 28776
# Paper: WooKey: Designing a Trusted and Efficient - Tokens: 19185
# Paper: WTAGRAPH : Web Tracking and Advertising - Tokens: 31198
# Paper: XFL: Naming Functions in Binaries with - Tokens: 23393
# Paper: xMP: Selective Memory Protection - Tokens: 26513
# Paper: Y ou Get Where Y ou’re Looking For - Tokens: 26744
# Paper: You Shall Not Join: A Measurement Study of Cryptocurrency - Tokens: 26640
# Paper: You’ve Changed: Detecting Malicious Browser Extensions - Tokens: 21329
# Paper: “Your Hashed IP Address: Ubuntu.” - Tokens: 23805
# Paper: ZeeStar: Private Smart Contracts by Homomorphic - Tokens: 32289
# Paper: Zero Knowledge Proofs - Tokens: 25162
# Paper: zkay: Specifying and Enforcing Data Privacy in Smart Contracts - Tokens: 32353
# Paper: Zombie Awakening: Stealthy Hijacking of Active Domains - Tokens: 27782
# Paper: ZombieLoad: Cross-Privilege-Boundary Data Sampling - Tokens: 27225
# Paper: o - Tokens: 18282
# Paper: o - Tokens: 18282
# Total number of tokens in the dataset: 32516740

# %% [markdown]
# API access

# %%
load_dotenv('api_key.env')  # load all the variables from '.env' file
api_key=os.getenv("OPENAI_API_KEY")

# %%
# Pre-existing list of datasets
existing_datasets = [
    
    {"unique_id": 1, "dataset_name": "NSL-KDD", "contributors": "Ghulam Mohi-ud-din", 
     "doi": "https://dx.doi.org/10.21227/425a-3e55", 
     "url": None},
    
    {"unique_id": 2, "dataset_name": "UNSW-NB15", "contributors": "Moustafa, Nour, and Jill Slay", 
     "doi": None, 
     "url": "https://research.unsw.edu.au/projects/unsw-nb15-dataset"},
    
    {"unique_id": 3, "dataset_name": "CICIDS2017", "contributors": "Iman Sharafaldin, Arash Habibi Lashkari, and Ali A. Ghorbani", 
     "doi": None, 
     "url": "https://www.unb.ca/cic/datasets/ids-2017.html"},
    
    {"unique_id": 4, "dataset_name": "BoT-IoT dataset", "contributors": "Nickolaos Koroniotis, Nour Moustafa, Elena Sitnikova, Benjamin Turnbull",  
     "doi": None, 
     "url": "https://research.unsw.edu.au/projects/bot-iot-dataset"},
     {"unique_id": 5, "dataset_name": "Drebin", "contributors": "Daniel Arp, Michael Spreitzenbarth, Malte Hubner , Hugo Gascon, and Konrad Rieck",  
     "doi": None, 
     "url": "https://www.ndss-symposium.org/wp-content/uploads/2017/09/11_3_1.pdf"}
]

# %% [markdown]
# PROMPTS

# %%
import json

def generate_system_prompt(paper, task, dataset_names):
    title = paper['title']
    content = paper['content']

    # Extract title first and then reuse in other tasks
    if task == "title":
        return f"""
        You are tasked with extracting the title of the provided cybersecurity paper.
        
        Guidelines:
        \t1. The title is often at the top of the first page.
        \t2. Extract the title in its entirety.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "title": "Title of the paper here"
        }}

        Your response: """

    elif task == "authors_name":
        return f"""
        You are tasked with extracting the authors' names from the provided cybersecurity paper.
        
        Guidelines:
        \t1. The authors' names are usually listed directly below the title.
        \t2. Extract all the authors, separated by commas.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "authors": "Comma-separated list of authors' names here"
        }}

        Your response: """

    elif task == "conference_name":
        return f"""
        You are tasked with extracting the conference name where the paper was presented.
        
        Guidelines:
        \t1. The conference name is usually found at the top or bottom of the first page.
        \t2. Use the short form (USS, NDSS, ACSAC, SP, CCS) if applicable.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "conference": "Short form of conference name (USS, NDSS, ACSAC, SP, CCS)"
        }}

        Your response: """

    elif task == "published_year":
        return f"""
        You are tasked with extracting the year of publication from the provided cybersecurity paper.
        
        Guidelines:
        \t1. The year of publication is usually found near the conference name or at the bottom of the first page.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "year": "Year of publication here"
        }}
        
        Your response: """

    elif task == "school_institution":
        return f"""
        You are tasked with extracting the school or institution name(s) associated with the authors of the provided cybersecurity paper.
        
        Guidelines:
        \t1. The institution or school is often listed near the authors' names, either directly below or in the footer of the first page.
        \t2. Extract all institutions mentioned, separated by commas if there are multiple.
        
        Here is the paper content:
        <Start of Paper Content>
        {content}
        <End of Paper Content>
        
        Your response must be returned in the following JSON format:
        {{
            "school": "Comma-separated list of schools/institutions"
        }}
        
        Your response: """
     
    # Use the title extracted earlier in the remaining tasks
    elif task == "domain":
        title = paper['title']  # Use the extracted title

        research_domains_list = [
            "botnet detection",
            "privacy-preserving computation",
            "Advanced Persistent Threat Detection",
            "Network Security", 
            "Network Intrusion Detection Systems(NIDS)"
            "adversarial data mining",
            "Adversarial Social Networking"
            "IoT security",
            "information security",
            "Web application security",
            "embedded systems security",
            "mobile browser security",
            "password security",
            "malware analysis and detection",
            "machine learning for cybersecurity",
            "deep learning for cybersecurity",
            "cryptographic api misuse detection",
            "adversarial machine learning",
            "access control and authorization",
            "authentication mechanisms",
            "ransomware detection and mitigation",
            "blockchain and cryptographic security",
            "cloud security",
            "big data security"
        ]

        research_domains = ", ".join(research_domains_list)
        
        return f"""
        
        You are tasked with identifying the **research domain** of the cybersecurity paper titled "{title}".
        
        ### Guidelines:

        \t1. **Primary Objective**: Determine the research domain of the paper based on a thorough analysis of its content. The research domain is the high-level category that best represents the primary focus of the paper.

        \t2. **First, Check the Provided List**:
        
        \t\t- Review the following list of research domains:
        {research_domains}
        
        \t\t- **If the paper's research domain matches or is closely related to any domain on this list, select that domain**.
        
        \t3. **If No Suitable Match is Found**:
        \t\t- **If none of the domains on the list accurately reflect the paper's primary focus**, identify a new research domain that does.
        \t\t- **Do not guess**. Read the paper thoroughly to determine the correct research domain.
        
        \t4. **Selection Criteria**:
        \t\t- The research domain should be a concise, high-level category (e.g., "IoT security", "malware analysis", "network security").
        \t\t- **Only provide one research domain per paper**.

        \t5. **For Papers from CCS Conference**:
        \t\t- CCS conference papers often include session headings or themes, typically found in the **top-left corner** of the paper, near the conference name.
        \t\t- Common headings include terms like **Cyber Threats**, **Inference Attacks**, or **Network Security**or **Adversarial Social Networking** etc. Also try to look paper's **Keyword**
        \t\t-**If the heading matches any of the predefined domains, use it as the research domain.**
        \t\t-**For Papers from other Conference**:
        \t\t-Look up the **research_domain** from the **keywords** or the whole **content** of the paper; it might help.

        \t6- Make sure to be consistent with **research_domains** name. For example if two papers have same research_domain like both lies under **network intrusion detection**, then stick with this name for both papers, done return 'network traffic' for another one.
        
        \t7. **Output Format**:
         
         Your response must be returned only in valid pure JSON, using the following format:
        {{
            "research_domain": "the paper's research domain here. All lowercase. Multiple words separated by single whitespace"
        }}
                
        6. **Content Restrictions**:
        - **Do not include any explanations, notes, or additional text**. Only provide the JSON output as specified.

         Here is the paper:
         <Start of Paper Content>
         {content}
         <End of Paper Content>
         Your response: """


    elif task == "dataset_name":
        datasets = [
            {
                "unique_id": "null",  # Set to null if not found in existing datasets
                "dataset_name": "Name of the first dataset you find",
                "contributors": "Comma separated string of contributors names for the first dataset you find",
                "doi": "DOI for the first dataset you find. If not available, this should be an empty string.",
                "url": "URL link to the first dataset you find. If not available, this should be an empty string.",
            },
            {
                "unique_id": "null",  # Set to null if not found in existing datasets
                "dataset_name": "Name of the second dataset you find",
                "contributors": "Comma separated string of contributors names for the second dataset you find",
                "doi": "DOI for the second dataset you find. If not available, this should be an empty string.",
                "url": "URL link to the second dataset you find. If not available, this should be an empty string.",
            }
        ]
        datasets_json = json.dumps({"datasets": datasets}, indent=4)
        
        return f"""

        You are tasked with identifying and extracting datasets from the cybersecurity paper titled "{title}".
        
        Guidelines:
        
        **STRICTLY FOLLOW ALL GUIDELINES**

        \t1.**Definition of a Dataset**:
        \t- A dataset is a named collection of data used for experiments, evaluation, training, testing, or comparison.
        \t- Examples: CICIDS2017, UNSW-NB15, CAIDA, Alexa top 1 million, HDFS, etc. In one paper they can use as much dataset they want, for instance; if they have used 10 dataset so return all 10 dataset in output.
        \t- Custom-created datasets by the authors also count if explicitly mentioned as such.
        \t- Datasets can be mentioned explicitly by name (e.g., "We use UNSW-NB15") or implicitly (e.g., "we use the dataset from [25]" if reference [25] clearly points to a dataset).

        \t2. **Be Comprehensive & Systematic:**
        \t- Carefully read the entire paper content (including references and methodology sections).
        \t- Identify every dataset mentioned, not just the first few. If you find 10 datasets, list all 10.
        \t- If the same dataset is mentioned multiple times under slightly different names (e.g., "HDFS dataset", "HDFS logs"), consider them as referring to the same dataset.
        
        \t3. **Real Example from a Paper**:
        Consider the ACM CCS paper "Recompose Event Sequences vs. Predict Next Events: A Novel Anomaly Detection Approach for Discrete Event Logs" as an example:
        \t- Introduction: "DabLog achieves 97.18% and 80.25% F1 scores in evaluation upon HDFS system logs and UNSW-NB15 traffic logs..."
        \t- Motivation section: "Both methods were evaluated upon the same HDFS dataset [38, 39]..."
        \t- Evaluation section: "We evaluate DabLog with two datasets: UNSW-NB15 traffic logs [29] and HDFS console logs [39]..."
        
        From these mentions, we clearly identify two datasets:
        \t- "HDFS"
        \t- "UNSW-NB15"
        
        In such a scenario, both "HDFS" and "UNSW-NB15" must be returned.
        
        \t4. **Consider Reference-Based Mentions**:
        \t- If the paper references a dataset indirectly, for example, "the same HDFS dataset [38, 39]," then check references. If these references are known sources for the HDFS dataset, include it.
        \t- For Example: in the paper "DoubleX: Statically Detecting Vulnerable Data Flows" author(s) have clearly mentioned "To evaluate DoubleX false negatives, we consider the dataset of vulnerable extensions released by Somé with EmPoWeb. His paper [72] provides a list of extension IDs and corresponding vulnerabilities. Of the 171 Chrome extensions he reported as vulnerable in 2019, 82 still existed on March 16, 2021." So which mean they used this **Chrome extensions dataset** for DoubleX evaluation.
        \t5. **No Guessing or Inferring**:
        
        \t- Do not guess or infer a dataset if it's not explicitly mentioned.
        \t- Attacks, vulnerabilities, software tools, protocols, or platforms are not datasets.
        \t- If after thoroughly reviewing the paper and references you find no dataset mentioned, return 'null':
        
         {{
           "datasets": null
         }}

        \t6.**Do not confuse datasets with other elements**:
        \t- Vulnerability Codes: These are vulnerability codes, so be vigilant. Examples include "CVE-2019-14815", "CVE-2016-4997", and "CVE-2017-9074". Be vigilant with this information, For Example: In the paper "Automated Bug Hunting With Data-Driven Symbolic RootCause Analysis" authors haven't used any dataset, instead CVE (Common Vulnerabilities and Exposures) is used as part of the analysis, particularly focusing on specific vulnerabilities and their contexts. However, CVE is not treated as a "dataset" in the conventional sense, as it serves more as a standardized catalog for identifying known security vulnerabilities. So return this paper's output as 'null' .
        \t\t- Again CVE are not 'datasets', A CVE (Common Vulnerabilities and Exposures) is a publicly disclosed cybersecurity vulnerability or exposure in a software or hardware system. Each CVE is assigned a unique identifier (CVE ID) and is documented in a centralized database to help organizations track, assess, and address security flaws.
        \t- Attacks: These are attack techniques, not datasets. Examples include "SQL injection", "DDoS", and "Phishing".
        \t- Bugs: These represent software flaws or defects. Examples include "software flaws" and "defects".
        \t- Kernel Modules: These are components of the OS, not datasets. Examples include "ipv6.ko" and "nf_tables.ko".
        \t- Network Protocols: These are communication protocols. Examples include "TCP", "UDP", "IPv4", and "IPv6".
        \t- Software Libraries or Packages: These are tools or resources, not datasets. Examples include "libc.so" and "openssl".
        \t- Standalone Applications and Benchmark Suites: SPEC CPU2006, NGINX, and PostgreSQL are not software libraries or packages.
        \t\t- SPEC CPU2006 is a benchmark suite used to evaluate CPU and memory performance across standardized tasks, primarily for research and testing purposes. Fo example in the paper "VIP: Safeguard Value Invariant Property for Thwarting Critical Memory Corruption Attacks", no dataset is used , which mean you will return "null" output, don't consider **SPEC CPU2006** as a dataset.
        \t\t- NGINX is a web server application commonly used to handle HTTP requests, serve static content, and balance load across servers.
        \t\t- PostgreSQL is a standalone database management system (DBMS) that manages data storage, retrieval, and complex querying.
        \t\t- ObliviSync is a secure file synchronization and backup system based on write-only ORAM techniques. It evaluates performance using realistic file size distributions without relying on traditional datasets.
        \t\t\t- Example:The paper "ObliviSync: Practical Oblivious File Backup and Synchronization" evaluates a system for secure file synchronization and backup but does not rely on traditional datasets. So technically, they haven't used any dataset, so it should return 'null'.
        \t- Permissioned Distributed Ledger Platform: Corda is a distributed ledger platform developed by R3 for businesses, focusing on privacy, efficiency, and regulatory compliance. Unlike public blockchains, Corda uses a permissioned network, ensuring that only authorized parties can participate and view transactions. Corda achieves privacy through point-to-point communication and a unique notary system that prevents double-spending without broadcasting transactions. Its modular design supports smart contracts and can be tailored to different industries, making it suitable for applications in finance, healthcare, supply chain, and more. 
        \t- Artifact: sometimes authors release their own artifact and shared it, don't confuse it with dataset.
        \t- Raspberry Pi: Raspberry Pi is a small, affordable computer, often used for educational purposes, DIY projects, and experiments in computing, robotics, and IoT, not a dataset. For example in the paper "Indistinguishability Prevents Scheduler Side Channels in Real-Time Systems" no dataset is used , which mean you will return "null" output, don't consider **Raspberry Pi** as a dataset.
        
        \t7. For each dataset, identify:
        \t- **Name** of the dataset.
        \t- **Contributors** (authors or creators).
        \t- **DOI** The DOI of the dataset (if available)
        \t- **URL** The URL link of the dataset (if available)
        \t\t- Look for DOIs and URLs in the reference section, especially for **custom-created but public** datasets. In these cases, the contributors are usually the authors of the paper, and they often explicitly mention sharing links to platforms like GitHub or other repositories. Be sure to check for these, but do not include any random GitHub or other links—only include links where the authors explicitly state that they have shared their datasets. Remain vigilant in confirming this information. 
        \t\t- If no dataset is found, return:
         
         {{
           "datasets": null
         }}

         \t8. If **dataset_name** task is 'null' so all the other task(s) like **dataset_analysis_combined** , **dataset_categories** and **dataset_utilization** will be 'null' too.
        
        - **Null Cases** Examples (**Check these example thoroughly before returning the ouput for same paper(s) mentioned below**):

        Example 1: The paper "Indistinguishability Prevents Scheduler Side Channels in Real-Time Systems" is not a dataset-related paper, which mean the haven't used any dataset, so return the output as 'null'. And other tasks like **dataset_analysis_combined** , **dataset_categories** and **dataset_usage** will be 'null' too.
        Json Output:
        
        {{
           "datasets": null
         }}
    
        Example 2: In the paper "ZKCPlus: Optimized Fair-exchange Protocol Supporting Practical and Flexible Data Exchange", which mean the haven't used any dataset, so return the output as 'null'. And other tasks like **dataset_analysis_combined** , **dataset_categories** and **dataset_usage** will be 'null' too.
        
        Json Output:
          
        {{
           "datasets": null
         }}

         Example 3: In the paper "DPGen: Automated Program Synthesis for Differential Privacy" , which mean the haven't used any dataset, so return the output as 'null'. And other tasks like **dataset_analysis_combined** , **dataset_categories** and **dataset_usage** will be 'null' too.
         
         Json Output:
           
         {{
           "datasets": null
         }}
         
         Example 4: In the paper "A Security Framework for Distributed Ledgers" , which mean the haven't used any dataset, so return the output as 'null'. And other tasks like **dataset_analysis_combined** , **dataset_categories** and **dataset_usage** will be 'null' too.
         
         Json Output:
           
         {{
           "datasets": null
         }}

         
         - Other Examples:
         
         Example 1: In the paper "WristPrint: Characterizing User Re-identification Risks from Wrist-worn Accelerometry Data", the author used two **public** datasets like "mORAL" and "WISDM".
 {{
        "datasets": [
            {{
                "unique_id": "null",
                "dataset_name": "mORAL",
                "contributors": "Sayma Akther, Nazir Saleheen, Shahin Alan Samiei, Vivek Shetty, Emre Ertin, Santosh Kumar",
                "doi": "",
                "url": ""
            }},
            {{
                "unique_id": "null",
                "dataset_name": "WISDM",
                "contributors": "Gary M Weiss",
                "doi": "",
                "url": "https://www.uci.edu/ml/datasets/wisdm+smartphone+and+smartwatch+activity+and+biometrics+dataset"
            }}
        ]
    }}

           Example 4: In the "A Lightweight IoT Cryptojacking Detection Mechanism in Heterogeneous Smart Home Networks"  a **public **dataset like "Network traffic for machine learning classification" or "Benign dataset" and **Custom-created datasets but public** dataset are used.
    {{
        "datasets": [
            {{
                "unique_id": "null",
                "dataset_name": "Iot cryptojacking",
                "contributors": "Ege Tekiner, Abbas Acar, A. Selcuk Uluagac,
                "doi": "",
                "url": "https://github.com/cslfiu/IoTCryptojacking"
            }},
            {{
                "unique_id": "null",
                "dataset_name": "Benign Dataset",
                "contributors": "Víctor Labayen Guembe, Eduardo Magaña, Daniel Morató, Mikel Izal",
                "doi": "10.17632/5pmnkshffm.1",
                "url": "https://data.mendeley.com/datasets/5pmnkshffm/1"
            }}
        ]
    }}
        
        Here is the list of existing datasets:
        <Existing dataset(s) start>
        {existing_datasets}
        <Existing dataset(s) stop>

        Here is the paper:
        <Start of Paper Content>
        {content}
        <End of Paper Content>

        Your output must be returned in valid JSON format:

        {datasets_json}
    
        Your response: """

     

        
    
    elif task == "dataset_analysis_combined":
        
        return f"""

        You are tasked with identifying the **availability**, **labeling_type**, and **dataset_type** for each dataset extracted in the **dataset_name** task for the cybersecurity paper titled "{title}".

        ### **Guidelines:**

        \t1. For each dataset, you will identify the following:
        \t- **availability**: Whether the dataset is 'public', 'proprietary', 'restricted', 'Custom-created datasets, not shared', or 'Custom-created datasets but public'.
        \t\t- **Public** are freely available for download (e.g., datasets hosted on websites like Kaggle, GitHub, or institutional repositories. **Public** are freely available for download (e.g., datasets hosted on websites like Kaggle, GitHub, or institutional repositories). These datasets existed before the research and were not curated specifically by the authors.
        - Example: in the paper "Black-box Adversarial Attacks on Commercial Speech Platforms with Minimal Information", they used are publicaly available datasets. The output should look like this:
        Json Output:

         {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Common Voice",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "Real-world"
            }},
                "dataset_name": "Song",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "Real-world"
            }},
                "dataset_name": "LibriSpeech",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "Real-world"
            }},
            }},
                "dataset_name": "Voxceleb dataset",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": " Real-world"
            }}
        ]
    }} 

         - Example: in the paper "AHEAD: Adaptive Hierarchical Decomposition for Range Query under Local Differential Privacy", they used are usually publicaly available datasets. The output should look like this:

         Json Output:

         {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Salaries",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
                "dataset_name": "blackfriday",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
                "dataset_name": "Loan",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
            }},
                "dataset_name": "Financial",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }}
        ]
    }} 
         
        
        \t\t- **Proprietary** are owned by organizations and are generally not accessible unless the user has a special agreement.
        \t\t- **Restricted** are accessible only under specific conditions (e.g., requiring permission or collaboration). 
        -Note: Sometimes, authors who create custom datasets may explicitly mention in their paper or dataset documentation (URL/DOI or citation details) that, due to the large size of the dataset, they are unable to share it online but can provide access upon request(don't make random guess). For example, in the paper "Towards Precise Reporting of Cryptographic Misuses", the authors mentioned in their GitHub link: 'Our original datasets consist of a data set of **3,489 open-source Android apps obtained from F-Droid**, and a data set of **1,437 firmwares** collected from 6 vendors. Due to the large size of the two datasets (APK dataset: 49 GB, firmware dataset: 21 GB), it is difficult to share them online. If you are interested in obtaining the original **F-Droid**dataset and **firmware** dataset, please contact us.'. 
        
        -Json output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "F-Droid app dataset",
                "availability": "restricted",
                "labeling_type": "labeled",
                "dataset_type": "realistic"
            }},
                "dataset_name": "Firmware images dataset,
                "availability": "restricted",
                "labeling_type": not mentioned",
                "dataset_type": "realistic"
            }},
        ]
    }}
        
        - Example: Datasets like the NYC TLC **Fare** which is used in the paper **Continuous Release of Data Streams under both Centralized and Local Differential Privacy** require users to submit a formal request and obtain approval before access is granted due to privacy concerns or sensitive information included in the dataset, return it as **restricted**.
        \t\t- **Custom-created datasets, not shared** are generated specifically for the research project and are not shared publicly. For example the custom created dataset in the paper **(Un)informed Consent: Studying GDPR Consent Notices in the Field** is not shared so return it as **Custom-created datasets, not shared**.
        \t\t- **Custom-created datasets but public** are custom datasets created by the authors but shared publicly.
        - Example 1: if authors download data (e.g., APK files or malware samples) from platforms like VirusTotal, then apply filtering, labeling, or feature extraction to create a tailored dataset, the resulting dataset is custom-created. While the original source (e.g. VirusTotal) can be cited, the curated dataset is distinct from the original collection and should be classified as 'Custom-created datasets, not shared' or 'Custom-created datasets but public', depending on whether the authors shared it publicly. Like in the paper **EIGER: Automated IOC Generation for Accurate and Interpretable Endpoint Malware Detection** they have collected 162K Malware Samples from VirusTotal and Benign public sources of free Windows software but didnt shared their dataset so return it as **Custom-created datasets, not shared**. Identify this correctly, the output should look like this:
        -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "162K Malware Samples from VirusTotal",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "realistic"
            }},
            {{
                "dataset_name": "Benign public sources of free Windows software",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "realistic"
            }},
            {{
                "dataset_name": "Hybrid Analysis Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "realistic"
            }}
        ]
    }}
        
        - Example 2: in the paper "C3PO: Large-Scale Study of Covert Monitoring of C&C Servers via Over-Permissioned Protocol Infiltration" where they collected **200,000 malware samples** over 15 year, identify this dataset as **Custom-created datasets, not shared**, since author(s) didnt mentioned sharing this dataset with the community. Identify it correctly, the output should look like this:
        -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "200k Malware Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "realistic"
            }}
        ]
    }}
        
        - Example 3: in the paper "Deterrence of Intelligent DDoS via Multi-Hop Traffic Divergence", the author's collected **49.8 TB real dataset from a department at Tsinghua campus network**, identify this and return it as **Custom-created datasets, not shared**. Identify it correctly, The output should look like this:.
        
        -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Tsinghua Network Traffic Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "Not Mentioned",
                "dataset_type": "realistic
                
                "
            }},
            {{
                "dataset_name": "DDoS pcap trace from Alibaba cloud DDoS HoneyPot",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "Not Mentioned",
                "dataset_type": "real-world"
            }},
        ]
    }}
        - Example 4: In the paper "High Fidelity Data Reduction for Big Data Security Dependency Analyses", the dataset was collected from a real enterprise environment for one month, which makes it a custom-created dataset. However, the authors didn't mention sharing it, so return it as **Custom-created datasets, not shared**, and the **labeling_type** wasn't mentioned either, so return it as **Not Mentioned**. Identify it correctly, The output should look like this:
        
        -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Enterprise Security Dependency Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "Not Mentioned",
                "dataset_type": "real-world"
            }},
        ]
    }}
        
        - Example 5: in the paper "This Sneaky Piggy Went to the Android Ad Market: Misusing Mobile Sensors for Stealthy Data Exfiltration" the datasets used are collected from **4.5K of the most popular apps**, **Two typing datasets** and **one typing datasets** all are **Custom-created datasets, not shared**..
         -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "4.5K Popular Apps Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
                "dataset_name": "Two Typing Datasets",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }},
                "dataset_name": "One Typing Dataset,
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }},
        ]
    }}
        -  Example 6: in the paper "BAPM: Block Attention Profiling Model for Multi-tab Website Fingerprinting Attacks on Tor" has created and used following datasets, The output should look like this:
        - Json Ouput:
        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Close World Multi-Tab Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }},
                "dataset_name": "Open World Multi-Tab Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }},
                "dataset_name": "Three-Tab Dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }},
            }},
                "dataset_name": "real world dataset",
                "availability": "Custom-created datasets but public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }}
        ]
    }}
    
         - Example 7: in the paper "PDiff: Semantic-based Patch Presence Testing for Downstream Kernels" the datasets used are both customer-created but one is **Custom-created datasets, not shared** and another is **Custom-created datasets but public**. The output should look like this:
         
         -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "CVE dataset",
                "availability": "Custom-created datasets, not shared",
                "labeling_type": "Not mentioned",
                "dataset_type": "real-world"
            }},
                "dataset_name": "Kernel Image dataset,
                "availability": "Custom-created datasets but public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
        ]
    }}
      
        \t\t- **Unknown** if you can't find the availability of dataset, return it as 'Unknown'. Don't return Unknown until you check vigilantly. Ensure that no mention of availability, restrictions, or sharing is present in the paper, its supplemental materials, or referenced links before selecting this option.
        \t-.**labeling_type**: Determine the labeling status of the dataset.
        \t\t- **labeled**:  A dataset is considered labeled if the paper or the dataset’s official documentation (accessed via DOI, URL, or citation details) explicitly states that data points have labels or categories.  
        \t\t\t- Example conditions:
        - The paper says “We manually labeled the dataset.”
        - The dataset’s website or documentation includes label files or describes classes/categories for each data point.
        - If labeling is confirmed from external sources (DOI/URL/citation), specify how it was identified, e.g., "labeled (via citation details)" or "labeled (found via URL)".
        - For image datasets, if classes, annotations, or bounding boxes are mentioned, consider them as labeled.
        \t\t- **unlabeled**: A dataset is considered unlabeled only if the paper or dataset documentation **explicitly states** that it has no labels or is unlabeled.  
        \t\t\t- For example, if the paper says, “The dataset is completely unlabeled,” or “We have no ground-truth labels,” then mark it as **unlabeled**.
        \t\t\t- If discovered via an external source (DOI/URL/citation) that explicitly says it’s unlabeled, note that as "unlabeled (found via URL)" or similar.
        \t\t-**hybrid**: A dataset is considered hybrid if it explicitly contains both labeled and unlabeled data.  
        \t\t\t- For instance, if the paper says, “The dataset includes 10,000 labeled samples and 100,000 unlabeled samples,” return **hybrid**.
        \t\t\t- If the dataset’s documentation (DOI/URL/citation) mentions both labeled and unlabeled subsets, also mark it as **hybrid**.
        \t\t- **re-labeled**: If the paper explicitly states that they took an existing dataset and re-annotated or re-labeled it for their study, return **re-labeled**.
        \t\t\t- For example, if it says, “We took the UNSW-NB15 dataset and re-labeled the events according to our criteria,” return **re-labeled**.
        \t\t- **not mentioned**: If after thoroughly checking the paper, its references, and any accessible DOI/URL information, you cannot find any mention of labeling status (no explicit mention of labeling, unlabeled status, hybrid, or re-labeling), return **not mentioned**.  
        \t\t\t- Use **not mentioned** if:
        - The paper never states anything about labeling.
        - The dataset’s official sources (DOI/URL) do not mention labeling.
        - No external citation details clarify the labeling status.
        \t\t- **unknown (unable to access the web)**: If the dataset references a DOI/URL or citation that you should check for labeling information, but you cannot access it (e.g., due to a simulated environment where web access is not possible or the reference is ambiguous), return **unknown (unable to access the web)**.  
        \t\t\t- This should be a last resort. Use this option if the instructions tell you to check external sources, but you do not have the capability to access them. In practice, if you do have citation details and they are accessible, you should attempt to determine labeling from them. Only if truly inaccessible, return **unknown**.


        -**Consistent Example Using HDFS**:
        Suppose the paper mentions the HDFS dataset and references [38,39] for its original introduction:
        \t\t\t- The paper itself doesn’t state whether HDFS is labeled or unlabeled.  
        \t\t\t- The instructions say you can use citation details (i.e., papers [38,39]) to learn about the dataset’s labeling. 
        \t\t\t- After checking the referenced papers (assuming you have "web access" through the citation details—i.e., you can infer what the source papers are known for):
        - If the HDFS dataset source paper (Xu et al., SOSP ’09) mentions that the dataset consists of system logs classified by event types or that it is commonly known that HDFS data is often annotated with specific event types, you can conclude it is **labeled** (e.g., "labeled (via citation details)" if found in the referenced paper).
        - If the source says explicitly it’s unlabeled logs (just raw logs without event types) and you confirm it from citation details, return **unlabeled (via citation details)**.
        - If you find both labeled and unlabeled samples mentioned in the original dataset source, return **hybrid**.
        - If the paper or the reference does not clarify labeling at all and the dataset’s official documentation (if available) is not accessible, return **not mentioned**.
        - If the paper says “We re-labeled the HDFS dataset to fit our classification scheme,” return **re-labeled**.
        - If the dataset’s labeling status can only be found via a URL or DOI that you cannot access, and you know that labeling info should be there, return **unknown (unable to access the web)**.

        \t- **dataset_type**: Determine the type of dataset.
        \t\t- **Real-world**: The dataset is directly collected from a real-world system or environment without significant preprocessing. Examples include raw network traffic logs or unaltered user interaction data or a complete packet capture (PCAP) file from a corporate network during a normal workday.
        \t\t- **realistic**: Data simulating real-world scenarios, but collected in controlled or lab environments to mimic actual conditions. This may involve preprocessing or specific configurations. Example: A network traffic dataset collected from real systems but heavily anonymized or filtered for privacy or anonymized DNS logs or cleaned financial transaction data.
        \t\t- **synthetic**: The dataset is completely generated using simulations, models, or algorithms without any direct data from real-world systems. Examples include simulated attack traffic or algorithmically generated synthetic images, such as the **SYMTCP** and **NSL-KDD** dataset.
        \t\t\t- Note: Datasets generated through symbolic execution (e.g., in the SYMTCP project) are considered **synthetic** used in the paper "SYMTCP: Eluding Stateful Deep Packet Inspection with Automated Discrepancy Discovery", The output should look like this:
        - Json Output:
        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "SYMTCP dataset",
                "availability": "Custom-created datasets but public",
                "labeling_type":"labeled",
                "dataset_type": "synthetic"
            }},
        ]
    }}
        \t\t\t- In the paper "Preparing Network Intrusion Detection Deep Learning Models with Minimal Data Using Adversarial Domain Adaptation", they have used two benchmark datasets; one is **hybrid** and another is **synthetic**.
        - Another json Example:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "UNSW-NB15",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "hybrid"
            }},
            {{
                "dataset_name": "NSL-KDD",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
            }},
        ]
    }}
            
        
        
        \t- **hybrid**:  The dataset combines both real-world and synthetic elements. For example, CICIDS2017 contains real network traffic with injected synthetic attack data, or another example would be the "UNSW-NB15" dataset which is considered a "hybrid dataset", encompassing both real-world and synthetic elements.
        \t\t- For example: in the paper "Filtering DDoS Attacks from Unlabeled Network Traffic Data Using Online Deep Learning", they have used two datasets "CICIDS2017" and "CAIDA2007". Be vigilant with "CICIDS2017" dataset whenever you found it in any paper make sure to return it's **dataset_type** as **hybrid**. The output should look like this:
        -Json Output:

        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "CICIDS2017",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "hybrid"
            }},
            {{
                "dataset_name": "CAIDA UCSD DDoS Attack 2007",
                "availability": "public",
                "labeling_type": "unlabeled",
                "dataset_type": "realistic"
            }},
        ]
    }}
        
        \t\t- **Unknown**: If you cannot determine the dataset type after thorough checking. Return **unknown (unable to access the web)**
        \t\t\t- **Do not return 'Unknown' unless you have checked thoroughly.** 
        \t2. Ensure that the dataset names match the ones extracted from the **dataset_name** task.
        \t3. If no dataset is found in the **dataset_name** task, leave **dataset_analysis_combined** task 'null'. Be vigilant.
        
        **Null cases Examples**
        Example 1 (using the same example used in **dataset_name** task): In the paper "ZKCPlus: Optimized Fair-exchange Protocol Supporting Practical and Flexible Data Exchange", which mean the haven't used any dataset, so return the output as 'null'. And other tasks like **dataset_analysis_combined** , **dataset_categories** and **dataset_usage** will be 'null' too.
        
        - Json Output:

        {{

        "dataset_analysis_combined": null
    }}

        Example 2 (using the same example used in **dataset_name** task): The paper "Indistinguishability Prevents Scheduler Side Channels in Real-Time Systems" is not a dataset-related paper, which mean the haven't used any dataset, so return the output as 'null'. And other tasks like **dataset_analysis_combined** , **dataset_categories** and **dataset_usage** will be 'null' too.

        - Json Output:

        {{

        "dataset_analysis_combined": null
    }}
    
        Here are the datasets extracted earlier:
        {dataset_names}

        <Start of Paper Content>
        {content}
        <End of Paper Content>

        Your output must be returned only in valid JSON format using the following structure:
         
         {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Exact dataset name from the **dataset_name** task",
                "availability": "Extracted availability status (**public**, **proprietary**, **restricted**, **Custom-created datasets, not shared**, **Custom-created datasets but public**, or **Unknown**)",
                "labeling_type": "Extracted labeling type (**labeled**, **unlabeled**, **hybrid**, **Re-labeled**, or **Unknown**)",
                "dataset_type": "Extracted dataset type (**real-world**,**realistic**, **synthetic**, **hybrid**, or **Unknown**)"
            }}
        ]
    }}

    Output Examples:

    **CAREFULLY CHECK THESE PAPER BEFORE RETURNING BACK THE OUTPUT**
    
    - Example 1: For the paper "Reverse Attack: Black-box Attacks on Collaborative Recommendation"
    
    -Json Output:

    
    {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Netflix",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Movielens",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Amazon",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
              {{
                "dataset_name": "Twitter",
                "availability": "public",
                "labeling_type": "unlabeled",
                "dataset_type": "real-world"
            }},
             {{
                "dataset_name": "Google+",
                "availability": "public",
                "labeling_type": "hybrid",
                "dataset_type": "real-world"
            }},
             {{
                "dataset_name": "AMiner Citation Network",
                "availability": "public",
                "labeling_type": "unlabeled ",
                "dataset_type": "real-world"
            }},
        ]
    }}

        - Example 2: For the paper "Differentially Private Publishing of High-dimensional Data".
        -Json Output:

         {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Netflix",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Transaction",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Movielens",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Document",
                "availability": "public",
                "labeling_type":"unlabeled (found via URL)",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "AOL",
                "availability": "public",
                "labeling_type":"unlabeled (found via URL)",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Kosarak",
                "availability": "public",
                "labeling_type": "unlabeled (found via URL)",
                "dataset_type": "real-world"
            }},
        ]
    }}
        - Example 3: For the paper "Recompose Event Sequences vs. Predict Next Events: A Novel Anomaly Detection Approach for Discrete Event Logs", be aware with **HDFS dataset**.
        -Json Output:

             {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "UNSW-NB15",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "hybrid"
            }},
            {{
                "dataset_name": "HDFS dataset",
                "availability": "public",
                "labeling_type": "labeled (via citation details)",
                "dataset_type": "realistic"
            }},
        ]
    }}
            - Example 4: "Model Extraction Attacks on Graph Neural Networks: Taxonomy and Realisation".
            - Json Output:

             {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Cora",
                "availability": "public",
                "labeling_type":"labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Pubmed",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Citeseer",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "real-world"
            }}
        ]
    }}
        - Example 5: For the paper "Continuous Release of Data Streams under both Centralized and Local Differential Privacy", the output should look like:
        -Json Output:
             {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "DNS",
                "availability": "public",
                "labeling_type":"unlabeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Fare",
                "availability": "restricted",
                "labeling_type":"unlabeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "Kosarak",
                "availability": "public",
                "labeling_type":"unlabeled",
                "dataset_type": "real-world"
            }},
            {{
                "dataset_name": "POS",
                "availability": "public",
                "labeling_type": "unlabeled",
                "dataset_type": "real-world"
            }},
        ]
    }}

        - Example 6: As an AI assitant, you have web access so if a dataset is cited is from another work, note its title, contributors, and source publication details for other tasks like **labeling_type**, **availability** or **dataset_type** to extract details by web searching from these citations. For Example:
        - "Vassil Panayotov, Guoguo Chen, Daniel Povey, and Sanjeev Khudanpur. 2015. Librispeech: an ASR corpus based on public domain audiobooks. In Proc. of ICASSP."
        - Example: in the paper "MineSweeper: An In-depth Look into Drive-by Cryptocurrency Mining and Its Defense" the author custom-created only one dataset and the stated "We ran 50 Docker containers in parallel for one week mid-March 2018 to collect data from Alexa’s Top 1 Million websites (as of February 28, 2018)". Also the shared this dataset with the community **https://github.com/vusec/minesweeper**. The output should look like this:
        
        Json Output:
         {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "collected dataset(minesweeper)",
                "availability": "Custom-created datasets but public",
                "labeling_type": "labeled(via URL)",
                "dataset_type": "real-world"
            }},
        ]
    }}
        - Example (c) in the paper "Secure Multi-party Computation of Differentially Private Heavy Hitters", two datasets are used, the output should look like this:
        Json Output:
        
        {{
        "dataset_analysis_combined": [
            {{
                "dataset_name": "Zipf distribution",
                "availability": "public",
                "labeling_type": "labeled",
                "dataset_type": "synthetic"
        
            }},
                "dataset_name": "Online retail dataset",
                "availability": "public",
                "labeling_type": "unlabeled",
                "dataset_type": "real-world"
            }}
        ]
    }} 
   
       
        Your response: """
    
    elif task == "dataset_categories":

        return f"""

        You are tasked with identifying the specific categories and subcategories of datasets extracted from the **dataset_name** task used in the cybersecurity paper titled "{title}".

        Clarification:

        The **dataset_categories** refers specifically to **what the dataset consists of** or contains, not how it is used in the research. Focus on the dataset's inherent characteristics and contents.

        Note: These categories are derived from the taxonomy outlined in the **USENIX paper "Cybersecurity Research Datasets: Taxonomy and Empirical Analysis"** by Zheng et al., which provides a structured framework for categorizing cybersecurity datasets. Additionally, a new category for multimedia data has been added based on evolving research needs.

        Guidelines:

        \t1. By **dataset_categories**, we mean identifying whether a dataset belongs to the following major categories and their subcategories:

        **Major Categories and Subcategories**:

        \t\t- **Attacker-Related**:
        \t\t  1. **Attacks**: Datasets containing information about malicious actions performed to harm systems (e.g., CICIDS2017, Kitsune etc).
        \t\t  2. **Vulnerabilities**: Datasets capturing weaknesses in systems or software that attackers can exploit (e.g., CVE databases).
        \t\t  3. **Exploits**: Information on how attacks are carried out (e.g., details of exploit code but not tied to specific events).
        \t\t  4. **Cybercrime Infrastructures**: Datasets capturing illegal operations and tools, such as botnets, marketplaces, or malware delivery.

        \t\t- **Defender Artifacts**:
        \t\t  1. **Alerts**: Logs or outputs from defensive systems like intrusion detection systems or firewalls.
        \t\t  2. **Configurations**: Information on setup and configurations of defense systems (e.g., SSL certificate settings).

        \t\t- **User & Organizational Characteristics**:
        \t\t  1. **User Activities**: Data on the behavior of users or organizations (e.g., social media activity, browsing logs).
        \t\t  2. **User Attitudes**: Survey data capturing opinions or sentiments on cybersecurity topics.
        \t\t  3. **User Attributes**: Characteristics of users or organizations (e.g., demographic profiles or organizational metadata).

        \t\t- **Macro-Level Internet Characteristics**:
        \t\t  1. **Applications**: Data on Internet services or products (e.g., website rankings, mobile apps).
        \t\t  2. **Network Traces**: Packet-level traffic data or network activity logs.
        \t\t  3. **Topology**: Information on the structure of the Internet, such as AS relationships or routing paths.
        \t\t  4. **Benchmarks**: Performance metrics for network systems (e.g., latency, bandwidth).
        \t\t  5. **Adverse Events**: Data on disruptions or outages, like failures caused by misconfigurations.

        \t\t- **Visual and Multimedia Data** (New Category):
        \t\t  1. **Image Datasets**: Datasets containing static visual data for tasks like classification, recognition, or detection (e.g., CIFAR-10, MNIST).
        \t\t  2. **Video Datasets**: Datasets containing dynamic visual data for tasks like motion tracking or behavior analysis (e.g., UCF101, Kinetics).
        \t\t  3. **Audio-Visual Datasets**: Datasets combining audio and visual data for tasks like lip-reading or synchronization (e.g., VoxCeleb, LRS2).
        \t\t  4. **Multimodal Datasets**: Datasets containing multiple data types (e.g., images and text) for tasks like sentiment analysis or cross-modal retrieval (e.g., MS COCO, Visual7W).
        \t\t  5. **Synthetic Media Datasets**: Artificially generated datasets used for tasks like deepfake detection (e.g., Deepfake Detection Challenge).

        \t2. **Dataset Overlap**:
        \t\t- A single dataset may belong to multiple categories. For instance, **CICIDS2017** could fall under:
        \t\t  - Attacker-Related -> Attacks
        \t\t  - Macro-Level Internet Characteristics -> Network Traces
        \t\t  - Macro-Level Internet Characteristics -> Benchmarks
        \t\t- When this occurs, ensure all relevant categories are captured in the output.

        \t3. **Examples for Clarity**:
        \t\t- A dataset like **Netflix Ratings** used in privacy studies should be categorized under **User & Organizational Characteristics** -> **User Activities**.
        \t\t- A dataset like **CAIDA AS Relationships**, which captures Internet topology data, should be categorized under **Macro-Level Internet Characteristics** -> **Topology**.
        \t\t- A dataset like **CIFAR-10**, used for image classification, should be categorized under **Visual and Multimedia Data** -> **Image Datasets**.

        \t4. **Do Not Confuse with Domain**:
        \t\t- **Domain** refers to the high-level research area (e.g., IoT, malware analysis).
        \t\t- **Dataset Categories** focus exclusively on the dataset's inherent characteristics (e.g., attacks, vulnerabilities, defender artifacts).

        \t5. **Null Cases**:
        \t\t. If no dataset found in **dataset_name** task, leave **dataset_categories** as null.

        Here are the datasets extracted earlier:
        
        {dataset_names}

        ### Output Structure:

        The output must strictly follow this JSON structure:
              
      {{
      
      "dataset_categories": [
            {{
                "dataset_name": "Kitsune",
                "category": "attacker_related",
                "subcategory": "attacks",
                "attacker_related_items":[
                    {{"name": "Fuzzing"}},
                    {{"name": "ARP MitM"}},
                    {{"name": "SSDP Flood"}},
                    {{"name": "SYN DoS"}},
                    {{"name": "Mirai Botnet"}}
                    ]
                }},
                
                {{
                "dataset_name": "CIFAR-10",
                "category": "visual_and_multimedia_data",
                "subcategory": "image_datasets",
                "visual_data_items": [
                    {{"name": "Image Classification"}}
                    ]
                }}
              ]
           }}

    ### Output Example:
    - For the **Kitsune** dataset, which contains nine attacks such as:
        1. OS Scan
        2. Fuzzing
        3. Video Injection
        4. ARP MitM
        5. Active Wiretap
        6. SSDP Flood
        7. SYN DoS
        8. SSL Renegotiation
        9. Mirai Botnet

      If the paper only utilizes attacks 2, 4, 6, 7, and 9, the output should list only those attacks.
      
      <Start of Paper Content>
      {content}
      <End of Paper Content>
      
      Your response: """

        
    elif task == "dataset_usage":
        
        return f"""
        
        You are tasked with determining how much of each dataset is utilized in the cybersecurity paper titled "{title}" (e.g., full utilization or only a specific portion).
        
        Guidelines:
        
        \t1. If the paper does not explicitly mention the number of samples or percentage used, assume the entire dataset was used and classify it as **Full**.
        \t2. If the paper mentions partial usage (e.g., a fraction of the dataset or a specific number of samples), classify it as **Partial**.
        \t3. Ensure that the dataset names match the ones extracted from the **dataset_name** task. You should provide **dataset_usage** for each dataset separately.
        \t4. You should assess the extent to which the attacks, vulnerabilities, and general-purpose datasets are utilized, based on information from the **dataset_categories** task.
        \t\t- If the paper uses the full set of attacks or vulnerabilities from a dataset (e.g., all 9 attacks of Kitsune), classify the usage as **Full**.
        \t\t- If the paper uses only a subset of the dataset’s attacks (e.g., 4 out of 9 attacks), classify it as **Partial**.
        \t\t- For example, in the paper "SYMTCP: Eluding Stateful Deep Packet Inspection with Automated Discrepancy Discovery," published in NDSS in 2020, only a sample of the **SYMTCP dataset** was used, making it **Partial**.
        \t\t- If a sample from the entire dataset is used, consider it **Partial** as well.

        \t5. If the paper does not specify the number of attacks/vulnerabilities used, assume full utilization and mark it as **Full**.
        \t6. If no dataset found in **dataset_name** task, leave **dataset_utilization** as null.
        \t7. Most importantly, compare the actual attack diversity or coverage from the dataset's DOI or URL with the amount of attacks used in the paper. 
        - For example, if a dataset contains 9 attacks but only 2 are used in the paper, mark it as **Partial**. The same approach applies to vulnerabilities and general-purpose datasets.
        \t8. Try to look for words like 'sample', 're-sampled', or 'resample', and determine if they relate to the usage of the dataset. If it is explicitly mentioned that they have taken a sample from the dataset or sampled out the dataset, it means they have used it **Partial**.
        \t9. Ensure that the dataset names match the ones extracted from the **dataset_name** task.

        

        Here are the datasets extracted earlier:

        {dataset_names}

        Your output must be returned only in valid JSON format using the following structure:

        {{
            "dataset_utilization": "Full"  # Either Full or Partial
        }}

        Start of Paper Content:
        {content}
        End of Paper Content:                                                                                                           
        Your response: """ 
    
    else:
        raise ValueError("Invalid task")

# %% [markdown]
# PROCESS PAPER

# %%
import os
import openai
client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY")
)

# Function to process papers for multiple tasks using the new OpenAI API
def process_papers_for_tasks(papers, tasks):
    task_results = {}

    for i, paper in enumerate(papers): 
        paper_title = paper['title']
        print(f"Processing paper: {paper_title}")
        
        task_results[paper_title] = {}
        
        # Process each paper individually for each task
        for task in tasks:
            # user_prompt = f"Process this cybersecurity paper for {task}: {paper}\n"                
            user_prompt = generate_system_prompt(paper, task, task_results[paper_title].get('dataset_name', None))
            # Call OpenAI API using the updated Completion method
            try:
                response = client.chat.completions.create(
                    model='gpt-4o-mini',  # Adjust model if needed
                     messages=[
                            {
                                "role": "user",
                                "content": user_prompt,
                            }
                        ],
                    # prompt=user_prompt,  # Use 'prompt' instead of 'messages'
                    temperature=0.2, 
                    max_tokens=5000  # Adjust max tokens based on your response length needs
                )
                # print(response)
                response_text = response.choices[0].message.content            
                print(response_text)
                task_results[paper_title][task] = response_text

            except Exception as e:
                print(f"Error processing {task} for paper {i+1}: {e}")
                task_results[paper_title][task] = "error" + str(e)

    return task_results

# %% [markdown]
# known papers

# %%
import json

tasks = [ 
    "title", 
    "authors_name", 
    "conference_name", 
    "published_year", 
    "school_institution", 
    "domain", 
    "dataset_name", 
    "dataset_analysis_combined", 
    "dataset_categories", 
    "dataset_usage"
]

# Function to load papers from a JSONL file
def load_papers_from_jsonl(file_path):
    papers = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            papers.append(json.loads(line.strip()))
    return papers

# Load papers from the JSONL file
jsonl_file_path = 'extracted_test_papers_new_NEWEST.jsonl'
papers = load_papers_from_jsonl(jsonl_file_path)

# List of specific titles to match
specific_titles = [
    "ZKCPlus: Optimized Fair-exchange Protocol",
    "New Directions in Automated Traffic Analysis",
    "Understanding Route Origin Validation (ROV)",
    "I Can See the Light: Attacks on Autonomous Vehicles Using",
    "Indistinguishability Prevents Scheduler Side Channels",
    "WristPrint: Characterizing User Re-identification Risks from",
    "Automated Bug Hunting With Data-Driven Symbolic Root",
    "Model Extraction Attacks on Graph Neural Networks",
    "Poirot: Aligning Attack Behavior with Kernel Audit Records for",
    "VIP: Safeguard Value Invariant Property for",
    "A Security Framework for Distributed Ledgers",
]

# Filter to find the specific papers by title
target_papers = [paper for paper in papers if paper['title'].strip() in specific_titles]

# Check if we found the target papers
if target_papers:
    # Process the selected papers for all tasks
    all_results_specific = process_papers_for_tasks(target_papers, tasks)

    # Print the final results for each task
    #for title, task_results in all_results.items():
        #print(f"Results for '{title}':")
        #for task, result in task_results.items():
            #print(f"\t{task}: {result}")
#else:
    #print("No papers found with the specified titles.")

#print("Processing complete.")
# Out:
# Processing paper: Understanding Route Origin Validation (ROV)
# ```json
# {
#     "title": "Understanding Route Origin Validation (ROV) Deployment in the Real World and Why MANRS Action 1 Is Not Followed"
# }
# ```
# ```json
# {
#     "authors": "Lancheng Qin, Li Chen, Dan Li, Honglin Ye, Yutian Wang"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# {
#     "year": "2024"
# }
# ```json
# {
#     "school": "Tsinghua University, Zhongguancun Laboratory, BNRist"
# }
# ```
# ```json
# {
#     "research_domain": "network security"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: Poirot: Aligning Attack Behavior with Kernel Audit Records for
# {
#     "title": "Poirot: Aligning Attack Behavior with Kernel Audit Records for Cyber Threat Hunting"
# }
# ```json
# {
#     "authors": "Sadegh M. Milajerdi, Birhanu Eshete, Rigel Gjomemo, V.N. Venkatakrishnan"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2019"
# }
# ```
# ```json
# {
#     "school": "University of Illinois at Chicago, University of Michigan-Dearborn"
# }
# ```
# ```json
# {
#     "research_domain": "advanced persistent threat detection"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "DARPA Transparent Computing (TC) program",
#             "contributors": "DARPA",
#             "doi": "",
#             "url": "https://github.com/darpa-i2o/Transparent-Computing"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Publicly released real-world incident reports",
#             "contributors": "",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Attack-free activities generated by ordinary users",
#             "contributors": "",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "DARPA Transparent Computing (TC) program",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Publicly released real-world incident reports",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Attack-free activities generated by ordinary users",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "not mentioned",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "DARPA Transparent Computing (TC) program",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Red-team vs. Blue-team engagement"}
#       ]
#     },
#     {
#       "dataset_name": "Publicly released real-world incident reports",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Various attack scenarios"}
#       ]
#     },
#     {
#       "dataset_name": "Attack-free activities generated by ordinary users",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Benign user activities"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "DARPA Transparent Computing (TC) program": "Full",
#         "Publicly released real-world incident reports": "Full",
#         "Attack-free activities generated by ordinary users": "Partial"
#     }
# }
# ```
# Processing paper: ZKCPlus: Optimized Fair-exchange Protocol
# ```json
# {
#     "title": "ZKCPlus: Optimized Fair-exchange Protocol Supporting Practical and Flexible Data Exchange"
# }
# ```
# ```json
# {
#     "authors": "Yun Li, Cun Ye, Yuguang Hu, Ivring Morpheus, Yu Guo, Chao Zhang, Yupeng Zhang, Zhipeng Sun, Yiwen Lu, Haodi Wang"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "Tsinghua University, K-Orange/SECBIT Labs, SECBIT Labs, Texas A&M University, Beijing Normal University"
# }
# ```
# ```json
# {
#     "research_domain": "cryptographic api misuse detection"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: New Directions in Automated Traffic Analysis
# {
#     "title": "New Directions in Automated Traffic Analysis"
# }
# ```json
# {
#     "authors": "Jordan Holland, Paul Schmitt, Nick Feamster, Prateek Mittal"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "Princeton University, University of Chicago"
# }
# ```
# ```json
# {
#     "research_domain": "network security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Network Device Dataset",
#             "contributors": "Jordan Holland, Paul Schmitt",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "CICIDS 2017",
#             "contributors": "Iman Sharafaldin, Arash Habibi Lashkari, Ali A. Ghorbani",
#             "doi": "",
#             "url": "https://www.unb.ca/cic/datasets/ids-2017.html"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "netML IoT",
#             "contributors": "Unknown",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "netML Non-VPN",
#             "contributors": "Unknown",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Cross Platform",
#             "contributors": "Unknown",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Streaming Video Providers",
#             "contributors": "Unknown",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "netML Challenge",
#             "contributors": "Onur Barut, Yan Luo, Tong Zhang, Weigang Li, Peilong Li",
#             "doi": "",
#             "url": "https://eval.ai/web/challenges/challenge-page/526/leaderboard/1473"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Network Device Dataset",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "CICIDS 2017",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "netML IoT",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "netML Non-VPN",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Cross Platform",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Streaming Video Providers",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "netML Challenge",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "CICIDS 2017",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Intrusion Detection"},
#         {"name": "Passive OS Detection"}
#       ]
#     },
#     {
#       "dataset_name": "Network Device Dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_attributes",
#       "user_attributes_items": [
#         {"name": "Device Fingerprinting"}
#       ]
#     },
#     {
#       "dataset_name": "netML IoT",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Malware Detection"}
#       ]
#     },
#     {
#       "dataset_name": "netML Non-VPN",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Type of Traffic in Capture"}
#       ]
#     },
#     {
#       "dataset_name": "Cross Platform",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Determine Country of Origin for Mobile Applications"}
#       ]
#     },
#     {
#       "dataset_name": "Streaming Video Providers",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Identify Streaming Video Service"}
#       ]
#     },
#     {
#       "dataset_name": "netML Challenge",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Intrusion Detection"},
#         {"name": "Malware Detection"},
#         {"name": "Traffic Identification"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Network Device Dataset": "Partial",
#         "CICIDS 2017": "Full",
#         "netML IoT": "Full",
#         "netML Non-VPN": "Full",
#         "Cross Platform": "Full",
#         "Streaming Video Providers": "Full",
#         "netML Challenge": "Full"
#     }
# }
# ```
# Processing paper: I Can See the Light: Attacks on Autonomous Vehicles Using
# ```json
# {
#     "title": "I Can See the Light: Attacks on Autonomous Vehicles Using Invisible Lights"
# }
# ```
# ```json
# {
#     "authors": "Wei Wang, Yao Yao, Xin Liu, Xiang Li, Pei Hao, Ting Zhu"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "University of Maryland Baltimore County, Cambricon SingGo"
# }
# ```
# ```json
# {
#     "research_domain": "iot security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Bosch Night dataset",
#             "contributors": "Bosch",
#             "doi": "",
#             "url": "https://hci.iwr.uni-heidelberg.de/content/bosch-small-traffic-lights-dataset"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Kitti dataset",
#             "contributors": "Various contributors",
#             "doi": "",
#             "url": "http://www.cvlibs.net/datasets/kitti/"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Bosch Night dataset",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Kitti dataset",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Bosch Night dataset",
#       "category": "visual_and_multimedia_data",
#       "subcategory": "image_datasets",
#       "visual_data_items": [
#         {"name": "Nighttime Traffic Light Detection"},
#         {"name": "Environmental Perception"}
#       ]
#     },
#     {
#       "dataset_name": "Kitti dataset",
#       "category": "visual_and_multimedia_data",
#       "subcategory": "image_datasets",
#       "visual_data_items": [
#         {"name": "Autonomous Driving"},
#         {"name": "3D Object Detection"},
#         {"name": "Visual Odometry"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Bosch Night dataset": "Full",
#         "Kitti dataset": "Full"
#     }
# }
# ```
# Processing paper: WristPrint: Characterizing User Re-identification Risks from
# ```json
# {
#     "title": "WristPrint: Characterizing User Re-identification Risks from Wrist-worn Accelerometry Data"
# }
# ```
# ```json
# {
#     "authors": "Nazir Saleheen, Md Azim Ullah, Supriyo Chakraborty, Deniz S. Ones, Mani Srivastava, Santosh Kumar"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "University of Memphis, IBM T. J. Watson Research Center, University of Minnesota, University of California, Los Angeles"
# }
# ```
# ```json
# {
#     "research_domain": "privacy preserving computation"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "mORAL",
#             "contributors": "Sayma Akther, Nazir Saleheen, Shahin Alan Samiei, Vivek Shetty, Emre Ertin, Santosh Kumar",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "WISDM",
#             "contributors": "Gary M Weiss",
#             "doi": "",
#             "url": "https://www.uci.edu/ml/datasets/wisdm+smartphone+and+smartwatch+activity+and+biometrics+dataset"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "mORAL",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "WISDM",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "mORAL",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Oral Hygiene Behaviors"}
#       ]
#     },
#     {
#       "dataset_name": "WISDM",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Smartphone and Smartwatch Activity"},
#         {"name": "Biometrics"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "mORAL": "Full",
#         "WISDM": "Full"
#     }
# }
# ```
# Processing paper: A Security Framework for Distributed Ledgers
# ```json
# {
#     "title": "A Security Framework for Distributed Ledgers"
# }
# ```
# ```json
# {
#     "authors": "Mike Graf, Daniel Rausch, Viktoria Ronge, Christoph Egger, Ralf Küsters, Dominique Schröder"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "University of Stuttgart, FAU Erlangen-Nürnberg"
# }
# ```
# ```json
# {
#     "research_domain": "blockchain and cryptographic security"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: Automated Bug Hunting With Data-Driven Symbolic Root
# {
#     "title": "Automated Bug Hunting With Data-Driven Symbolic Root Cause Analysis"
# }
# ```json
# {
#     "authors": "Carter Yagemann, Simon P. Chung, Brendan Saltaformaggio, Wenke Lee"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "Georgia Institute of Technology"
# }
# ```
# ```json
# {
#     "research_domain": "software and application security"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: VIP: Safeguard Value Invariant Property for
# ```json
# {
#     "title": "VIP: Safeguard Value Invariant Property for Thwarting Critical Memory Corruption Attacks"
# }
# ```
# ```json
# {
#     "authors": "Mohannad Ismail, Jinwoo Yom, Christopher Jelesnianski, Yeongjin Jang, Changwoo Min"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# {
#     "school": "Virginia Tech, Oregon State University"
# }
# ```json
# {
#     "research_domain": "information security"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```

# %%
import csv

# File path for the CSV output
output_csv_path = 'results_specific.csv'

# Write the results to CSV if available
if all_results_specific:
    with open(output_csv_path, 'w', newline='', encoding='utf-8') as file:
        csv_writer = csv.writer(file)

        # Write the header
        csv_writer.writerow(tasks)

        # Iterate over each paper and its corresponding results
        for title, results in all_results_specific.items():
            row = []
            for task in tasks:
                task_result = results.get(task, "No result")
                if isinstance(task_result, dict) or isinstance(task_result, list):
                    task_result = json.dumps(task_result)  # Convert dict or list to string for CSV
                row.append(task_result)  # Add the task result to the row

            csv_writer.writerow(row)  # Write the completed row to the CSV

    print(f"Results have been written to '{output_csv_path}'.")
else:
    print("No results available to write to CSV.")
# Out:
# Results have been written to 'results_specific.csv'.

# %%
import json

# File path for the JSONL output
output_jsonl_path = 'results.jsonl_specific'

# Open a new JSONL file
with open(output_jsonl_path, 'w', encoding='utf-8') as jsonl_file:
    # Iterate over each paper and its corresponding results
    for results in all_results_specific.values():
        jsonl_file.write(json.dumps(results) + "\n")

print(f"Results have been written to {output_jsonl_path}")
# Out:
# Results have been written to results.jsonl_specific

# %% [markdown]
# **Final RUN

# %%
test_papers = papers[:100]

# %%
# Define the tasks you are going to process
tasks = [ 
    "title", 
    "authors_name", 
    "conference_name", 
    "published_year", 
    "school_institution", 
    "domain", 
    "dataset_name", 
    "dataset_analysis_combined", 
    "dataset_categories", 
    "dataset_usage"
]
# Process the selected 100 papers for all tasks
all_results = process_papers_for_tasks(test_papers, tasks)

# Print the final results for each task
# for task, results in all_results.items():
#     print(f"Results for {task}:")
#     for result in results:
#         print(result)

# print("Processing complete.")
# Out:
# Processing paper: NetCA T: Practical Cache Attacks from the Network
# {
#     "title": "NetCA T: Practical Cache Attacks from the Network"
# }
# {
#     "authors": "Michael Kurth, Ben Gras, Dennis Andriesse, Cristiano Giuffrida, Herbert Bos, Kaveh Razavi"
# }
# ```json
# {
#     "conference": "SP"
# }
# ```
# {
#     "year": "2020"
# }
# {
#     "school": "Vrije Universiteit Amsterdam, ETH Zurich"
# }
# ```json
# {
#     "research_domain": "network security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Publicly available dataset for keystroke timing attacks",
#             "contributors": "K. S. Killourhy, R. A. Maxion",
#             "doi": "",
#             "url": "https://www.cs.cmu.edu/~keystroke/"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Publicly available dataset for keystroke timing attacks",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Publicly available dataset for keystroke timing attacks",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Keystroke Timing Attack"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": "Partial"
# }
# ```
# Processing paper: (Un)informed Consent: Studying GDPR Consent Notices in the
# ```json
# {
#     "title": "(Un)informed Consent: Studying GDPR Consent Notices in the Field"
# }
# ```
# ```json
# {
#     "authors": "Christine Utz, Martin Degeling, Sascha Fahl, Florian Schaub, Thorsten Holz"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2019"
# }
# ```
# ```json
# {
#     "school": "Ruhr-Universität Bochum, University of Michigan"
# }
# ```
# ```json
# {
#     "research_domain": "privacy preserving computation"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "1,000 consent notices",
#             "contributors": "Christine Utz, Martin Degeling, Sascha Fahl, Florian Schaub, Thorsten Holz",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "82,890 unique users",
#             "contributors": "Christine Utz, Martin Degeling, Sascha Fahl, Florian Schaub, Thorsten Holz",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "1,000 consent notices",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "82,890 unique users",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "1,000 consent notices",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Analysis of consent notice designs"},
#         {"name": "User interaction with consent notices"}
#       ]
#     },
#     {
#       "dataset_name": "82,890 unique users",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_attributes",
#       "user_attributes_items": [
#         {"name": "Demographic data of users"},
#         {"name": "User interaction metrics"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "1,000 consent notices": "Full",
#         "82,890 unique users": "Full"
#     }
# }
# ```
# Processing paper: (Un)linkable Pseudonyms for Governmental Databases
# {
#     "title": "(Un)linkable Pseudonyms for Governmental Databases"
# }
# ```json
# {
#     "authors": "Jan Camenisch, Anja Lehmann"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2015"
# }
# ```
# ```json
# {
#     "school": "IBM Research – Zurich"
# }
# ```
# ```json
# {
#     "research_domain": "privacy preserving computation"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: ObliviSync: Practical Oblivious
# ```json
# {
#     "title": "ObliviSync: Practical Oblivious File Backup and Synchronization"
# }
# ```
# ```json
# {
#     "authors": "Adam J. Aviv, Seung Geol Choi, Travis Mayberry, Daniel S. Roche"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# {
#     "year": "2017"
# }
# ```json
# {
#     "school": "United States Naval Academy"
# }
# ```
# ```json
# {
#     "research_domain": "privacy-preserving computation"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: SYMTCP: Eluding Stateful Deep Packet Inspection
# ```json
# {
#     "title": "SYMTCP: Eluding Stateful Deep Packet Inspection with Automated Discrepancy Discovery"
# }
# ```
# ```json
# {
#     "authors": "Zhongjie Wang, Shitong Zhu, Yue Cao, Zhiyun Qian, Chengyu Song, Srikanth V. Krishnamurthy, Kevin S. Chany, Tracy D. Brauny"
# }
# ```
# {
#     "conference": "NDSS"
# }
# ```json
# {
#     "year": "2020"
# }
# ```
# ```json
# {
#     "school": "University of California, Riverside, U.S. Army Research Lab"
# }
# ```
# ```json
# {
#     "research_domain": "network security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "S YMTCP",
#             "contributors": "Zhongjie Wang, Shitong Zhu, Yue Cao, Zhiyun Qian, Chengyu Song, Srikanth V. Krishnamurthy, Kevin S. Chan, Tracy D. Braun",
#             "doi": "",
#             "url": "https://github.com/seclab-ucr/sym-tcp"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "SYMTCP",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "synthetic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "SYMTCP",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Insertion Packets"},
#         {"name": "Evasion Packets"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": "Partial"
# }
# ```
# Processing paper: Interpretable Federated Transformer Log Learning
# {
#     "title": "Interpretable Federated Transformer Log Learning for Cloud Threat Forensics"
# }
# ```json
# {
#     "authors": "Gonzalo De La Torre Parra, Luis Selveray, Joseph Khoury, Hector Irizarry, Elias Bou-Harb, Paul Rady"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2022"
# }
# ```
# ```json
# {
#     "school": "University of the Incarnate Word, The University of Texas at San Antonio, Raytheon Technologies"
# }
# ```
# ```json
# {
#     "research_domain": "machine learning for cybersecurity"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "HDFS",
#             "contributors": "null",
#             "doi": "null",
#             "url": "https://doi.org/10.5281/zenodo.3227177"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "CTDD",
#             "contributors": "Gonzalo De La Torre Parra, Luis Selveray, Joseph Khoury, Hector Irizarry, Elias Bou-Harb, Paul Rady",
#             "doi": "null",
#             "url": "https://github.com/cyberthreat-datasets/ctdd-2021-os-syslogs"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "HDFS",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "CTDD",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "HDFS",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Syslogs"},
#         {"name": "Execution flows"}
#       ]
#     },
#     {
#       "dataset_name": "CTDD",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Syslogs"},
#         {"name": "Cloud collaboration services logs"}
#       ],
#       "category": "attacker_related",
#       "subcategory": "exploits",
#       "attacker_related_items": [
#         {"name": "Ransomware"},
#         {"name": "DDoS"},
#         {"name": "Botnets"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "HDFS": "Full",
#         "CTDD": "Full"
#     }
# }
# ```
# Processing paper: How to Count Bots
# ```json
# {
#     "title": "How to Count Bots in Longitudinal Datasets of IP Addresses"
# }
# ```
# ```json
# {
#     "authors": "Leon Böck, Dave Levin, Ramakrishna Padmanabhan, Christian Doerr, Max Mühlhäuser"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2023"
# }
# ```
# ```json
# {
#     "school": "Technische Universität Darmstadt, University of Maryland, CAIDA, Hasso Plattner Institute, University of Potsdam"
# }
# ```
# ```json
# {
#     "research_domain": "botnet detection"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Hajime",
#             "contributors": "Herwig et al.",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Mirai",
#             "contributors": "Grifﬁoen and Doerr",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "RIPE Atlas",
#             "contributors": "RIPE NCC",
#             "doi": "",
#             "url": "https://atlas.ripe.net/"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Hajime",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Mirai",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "RIPE Atlas",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Hajime",
#       "category": "attacker_related",
#       "subcategory": "cybercrime_infrastructures",
#       "attacker_related_items": [
#         {"name": "Hajime Botnet"}
#       ]
#     },
#     {
#       "dataset_name": "Mirai",
#       "category": "attacker_related",
#       "subcategory": "cybercrime_infrastructures",
#       "attacker_related_items": [
#         {"name": "Mirai Botnet"}
#       ]
#     },
#     {
#       "dataset_name": "RIPE Atlas",
#       "category": "macro_level_internet_characteristics",
#       "subcategory": "network_traces",
#       "macro_level_internet_characteristics_items": [
#         {"name": "IP Address Assignment Durations"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Hajime": "Partial",
#         "Mirai": "Partial",
#         "RIPE Atlas": "Full"
#     }
# }
# ```
# Processing paper: Testability Tarpits: the Impact of Code Patterns
# ```json
# {
#     "title": "Testability Tarpits: the Impact of Code Patterns on the Security Testing of Web Applications"
# }
# ```
# ```json
# {
#     "authors": "Feras Al Kassar, Giulia Clerici, Luca Compagna, Fabian Yamaguchi, Davide Balzarotti"
# }
# ```
# {
#     "conference": "NDSS"
# }
# ```json
# {
#     "year": "2022"
# }
# ```
# ```json
# {
#     "school": "SAP Security Research, ShiftLeft Inc, EURECOM"
# }
# ```
# ```json
# {
#     "research_domain": "web application security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "GL",
#             "contributors": "Feras Al Kassar, Giulia Clerici, Luca Compagna, Fabian Yamaguchi, Davide Balzarotti",
#             "doi": "",
#             "url": "https://github.com/enferas/TestabilityTarpits"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "GM",
#             "contributors": "Feras Al Kassar, Giulia Clerici, Luca Compagna, Fabian Yamaguchi, Davide Balzarotti",
#             "doi": "",
#             "url": "https://github.com/enferas/TestabilityTarpits"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "GH",
#             "contributors": "Feras Al Kassar, Giulia Clerici, Luca Compagna, Fabian Yamaguchi, Davide Balzarotti",
#             "doi": "",
#             "url": "https://github.com/enferas/TestabilityTarpits"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "SC",
#             "contributors": "Feras Al Kassar, Giulia Clerici, Luca Compagna, Fabian Yamaguchi, Davide Balzarotti",
#             "doi": "",
#             "url": "https://github.com/enferas/TestabilityTarpits"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "GL",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "GM",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "GH",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "SC",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "GL",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Static Analysis Alerts"},
#         {"name": "Dynamic Analysis Alerts"}
#       ]
#     },
#     {
#       "dataset_name": "GM",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Static Analysis Alerts"},
#         {"name": "Dynamic Analysis Alerts"}
#       ]
#     },
#     {
#       "dataset_name": "GH",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Static Analysis Alerts"},
#         {"name": "Dynamic Analysis Alerts"}
#       ]
#     },
#     {
#       "dataset_name": "SC",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Static Analysis Alerts"},
#         {"name": "Dynamic Analysis Alerts"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "GL": "Full",
#         "GM": "Full",
#         "GH": "Full",
#         "SC": "Full"
#     }
# }
# ```
# Processing paper: FedCRI: Federated Mobile Cyber-Risk Intelligence
# {
#     "title": "FedCRI: Federated Mobile Cyber-Risk Intelligence"
# }
# ```json
# {
#     "authors": "Hossein Fereidooni, Alexandra Dmitrienkoy, Phillip Rieger, Markus Miettinen, Ahmad-Reza Sadeghi, Felix Madlener"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2022"
# }
# ```
# ```json
# {
#     "school": "Technical University of Darmstadt, University of Würzburg, KOBIL"
# }
# ```
# ```json
# {
#     "research_domain": "mobile security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Risk Dataset",
#             "contributors": "Hossein Fereidooni, Alexandra Dmitrienkoy, Phillip Rieger, Markus Miettinen, Ahmad-Reza Sadeghi, Felix Madlener",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "User databases from nine different service providers",
#             "contributors": "Hossein Fereidooni, Alexandra Dmitrienkoy, Phillip Rieger, Markus Miettinen, Ahmad-Reza Sadeghi, Felix Madlener",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Risk Dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "User databases from nine different service providers",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Risk Dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "User behavior data from mobile apps"}
#       ]
#     },
#     {
#       "dataset_name": "User databases from nine different service providers",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_attributes",
#       "user_attributes_items": [
#         {"name": "Demographic profiles of users"},
#         {"name": "Organizational metadata from service providers"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Risk Dataset": "Full",
#         "User databases from nine different service providers": "Full"
#     }
# }
# ```
# Processing paper: Hybrid Trust Multi-party Computation with
# ```json
# {
#     "title": "Hybrid Trust Multi-party Computation with Trusted Execution Environment"
# }
# ```
# ```json
# {
#     "authors": "Pengfei Wuy, Jianting Ning, Jiamin Shen, Hongbing Wang, Ee-Chien Chang"
# }
# ```
# {
#     "conference": "NDSS"
# }
# ```json
# {
#     "year": "2022"
# }
# ```
# {
#     "school": "School of Computing, National University of Singapore, College of Computer and Cyber Security, Fujian Normal University, Institute of Information Engineering, Chinese Academy of Sciences"
# }
# ```json
# {
#     "research_domain": "privacy-preserving computation"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Distributed Database Scenario",
#             "contributors": "Pengfei Wu, Jianting Ning, Jiamin Shen, Hongbing Wang, Ee-Chien Chang",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "220 Records Dataset",
#             "contributors": "Pengfei Wu, Jianting Ning, Jiamin Shen, Hongbing Wang, Ee-Chien Chang",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Distributed Database Scenario",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "Not Mentioned",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "220 Records Dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "Not Mentioned",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Distributed Database Scenario": "Partial",
#         "220 Records Dataset": "Full"
#     }
# }
# ```
# Processing paper: A Lightweight IoT Cryptojacking Detection
# {
#     "title": "A Lightweight IoT Cryptojacking Detection Mechanism in Heterogeneous Smart Home Networks"
# }
# {
#     "authors": "Ege Tekiner, Abbas Acar, A. Selcuk Uluagac"
# }
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2022"
# }
# ```
# ```json
# {
#     "school": "Florida International University"
# }
# ```
# ```json
# {
#     "research_domain": "iot security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Iot cryptojacking",
#             "contributors": "Ege Tekiner, Abbas Acar, A. Selcuk Uluagac",
#             "doi": "",
#             "url": "https://github.com/cslfiu/IoTCryptojacking"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Benign Dataset",
#             "contributors": "Víctor Labayen Guembe, Eduardo Magaña, Daniel Morató, Mikel Izal",
#             "doi": "10.17632/5pmnkshffm.1",
#             "url": "https://data.mendeley.com/datasets/5pmnkshffm/1"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Iot cryptojacking",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Benign Dataset",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Iot cryptojacking",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "In-browser cryptojacking"},
#         {"name": "Host-based cryptojacking"}
#       ]
#     },
#     {
#       "dataset_name": "Benign Dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Network traffic from benign activities"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Iot cryptojacking": "Full",
#         "Benign Dataset": "Full"
#     }
# }
# ```
# Processing paper: Hiding My Real Self! Protecting Intellectual
# {
#     "title": "Hiding My Real Self! Protecting Intellectual Property in Additive Manufacturing Systems Against Optical Side-Channel Attacks"
# }
# ```json
# {
#     "authors": "Sizhuang Liang, Saman Zonouz, Raheem Beyah"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2022"
# }
# ```
# ```json
# {
#     "school": "Georgia Institute of Technology, Rutgers University"
# }
# ```
# ```json
# {
#     "research_domain": "information security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Optical Side-Channel Attack Dataset",
#             "contributors": "Sizhuang Liang, Saman Zonouz, Raheem Beyah",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Training Dataset for Optical Side-Channel Attack",
#             "contributors": "Sizhuang Liang, Saman Zonouz, Raheem Beyah",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Testing Dataset 1",
#             "contributors": "Sizhuang Liang, Saman Zonouz, Raheem Beyah",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Testing Dataset 2",
#             "contributors": "Sizhuang Liang, Saman Zonouz, Raheem Beyah",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Optical Side-Channel Attack Dataset",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Training Dataset for Optical Side-Channel Attack",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Testing Dataset 1",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Testing Dataset 2",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Optical Side-Channel Attack Dataset",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Optical Side-Channel Attack"}
#       ]
#     },
#     {
#       "dataset_name": "Training Dataset for Optical Side-Channel Attack",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Optical Side-Channel Attack"}
#       ]
#     },
#     {
#       "dataset_name": "Testing Dataset 1",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Optical Side-Channel Attack"}
#       ]
#     },
#     {
#       "dataset_name": "Testing Dataset 2",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Optical Side-Channel Attack"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Optical Side-Channel Attack Dataset": "Full",
#         "Training Dataset for Optical Side-Channel Attack": "Full",
#         "Testing Dataset 1": "Full",
#         "Testing Dataset 2": "Full"
#     }
# }
# ```
# Processing paper: Towards Precise Reporting of
# {
#     "title": "Towards Precise Reporting of Cryptographic Misuses"
# }
# ```json
# {
#     "authors": "Yikang Chen, Yibo Liu, Ka Lok Wu, Duc V. Le, Sze Yiu Chau"
# }
# ```
# {
#     "conference": "NDSS"
# }
# ```json
# {
#     "year": "2024"
# }
# ```
# ```json
# {
#     "school": "The Chinese University of Hong Kong, Arizona State University, University of Bern"
# }
# ```
# ```json
# {
#     "research_domain": "cryptographic api misuse detection"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "3489 open-source Android apps",
#             "contributors": "Yikang Chen, Yibo Liu, Ka Lok Wu, Duc V. Le, Sze Yiu Chau",
#             "doi": "",
#             "url": "https://f-droid.org/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "1177 firmware images",
#             "contributors": "Yikang Chen, Yibo Liu, Ka Lok Wu, Duc V. Le, Sze Yiu Chau",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "3489 open-source Android apps",
#             "availability": "restricted",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "1177 firmware images",
#             "availability": "restricted",
#             "labeling_type": "Not mentioned",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "3489 open-source Android apps",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Static analysis for cryptographic API misuse"}
#       ]
#     },
#     {
#       "dataset_name": "1177 firmware images",
#       "category": "attacker_related",
#       "subcategory": "exploits",
#       "attacker_related_items": [
#         {"name": "Static analysis for cryptographic API misuse"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "3489 open-source Android apps": "Full",
#         "1177 firmware images": "Full"
#     }
# }
# ```
# Processing paper: Understanding and Analyzing Appraisal Systems in
# ```json
# {
#     "title": "Understanding and Analyzing Appraisal Systems in the Underground Marketplaces"
# }
# ```
# ```json
# {
#     "authors": "Zhengyi Li, Xiaojing Liao"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2024"
# }
# ```
# ```json
# {
#     "school": "Indiana University Bloomington"
# }
# ```
# ```json
# {
#     "research_domain": "cyber threat intelligence"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "CrimeBB",
#             "contributors": "CrimeBB dataset contributors",
#             "doi": "",
#             "url": "https://support.clean-mx.com/clean-mx/index.php"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Nulled database",
#             "contributors": "Nulled database contributors",
#             "doi": "",
#             "url": "https://www.nulled.to/forum/45-marketplace/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "dark net markets (DNM) archive",
#             "contributors": "DNM archive contributors",
#             "doi": "",
#             "url": "https://www.gwern.net/DNM-archives"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Self-scraped dataset",
#             "contributors": "Zhengyi Li, Xiaojing Liao",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "CrimeBB",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Nulled database",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "dark net markets (DNM) archive",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Self-scraped dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "Not Mentioned",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "CrimeBB",
#       "category": "attacker_related",
#       "subcategory": "cybercrime_infrastructures",
#       "attacker_related_items": [
#         {"name": "Underground marketplace communication traces"},
#         {"name": "User account information"}
#       ]
#     },
#     {
#       "dataset_name": "Nulled database",
#       "category": "attacker_related",
#       "subcategory": "cybercrime_infrastructures",
#       "attacker_related_items": [
#         {"name": "User information"},
#         {"name": "Private messages"}
#       ]
#     },
#     {
#       "dataset_name": "dark net markets (DNM) archive",
#       "category": "attacker_related",
#       "subcategory": "cybercrime_infrastructures",
#       "attacker_related_items": [
#         {"name": "Tor-based marketplace traces"}
#       ]
#     },
#     {
#       "dataset_name": "Self-scraped dataset",
#       "category": "attacker_related",
#       "subcategory": "cybercrime_infrastructures",
#       "attacker_related_items": [
#         {"name": "Communication traces from underground marketplaces"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "CrimeBB": "Full",
#         "Nulled database": "Full",
#         "dark net markets (DNM) archive": "Full",
#         "Self-scraped dataset": "Full"
#     }
# }
# ```
# Processing paper: Understanding Route Origin Validation (ROV)
# ```json
# {
#     "title": "Understanding Route Origin Validation (ROV) Deployment in the Real World and Why MANRS Action 1 Is Not Followed"
# }
# ```
# ```json
# {
#     "authors": "Lancheng Qin, Li Chen, Dan Li, Honglin Ye, Yutian Wang"
# }
# ```
# {
#     "conference": "NDSS"
# }
# {
#     "year": "2024"
# }
# ```json
# {
#     "school": "Tsinghua University, Zhongguancun Laboratory, BNRist"
# }
# ```
# ```json
# {
#     "research_domain": "network security"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: MPCD IFF: Testing and Repairing MPC-Hardened
# {
#     "title": "MPCD IFF: Testing and Repairing MPC-Hardened Deep Learning Models"
# }
# ```json
# {
#     "authors": "Qi Pang, Yuanyuan Yuan, Shuai Wang"
# }
# ```
# {
#     "conference": "NDSS"
# }
# ```json
# {
#     "year": "2024"
# }
# ```
# ```json
# {
#     "school": "Carnegie Mellon University, HKUST"
# }
# ```
# ```json
# {
#     "research_domain": "privacy-preserving computation"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "MNIST",
#             "contributors": "Y. LeCun, L. Bottou, Y. Bengio, P. Haffner",
#             "doi": "",
#             "url": "http://yann.lecun.com/exdb/mnist/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Credit",
#             "contributors": "I.-C. Yeh, C.-h. Lien",
#             "doi": "",
#             "url": "https://archive.ics.uci.edu/ml/datasets/default+of+credit+card+clients"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Bank",
#             "contributors": "S. Moro, P. Cortez, P. Rita",
#             "doi": "",
#             "url": "https://archive.ics.uci.edu/ml/datasets/bank+marketing"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "MNIST",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Credit",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Bank",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "MNIST",
#       "category": "visual_and_multimedia_data",
#       "subcategory": "image_datasets",
#       "visual_data_items": [
#         {"name": "Image Classification"}
#       ]
#     },
#     {
#       "dataset_name": "Credit",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_attributes",
#       "user_attributes_items": [
#         {"name": "Client Demographics"},
#         {"name": "Payment History"},
#         {"name": "Bill Statement Amount"}
#       ]
#     },
#     {
#       "dataset_name": "Bank",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_attributes",
#       "user_attributes_items": [
#         {"name": "Consumer Price Index"},
#         {"name": "Consumer Confidence Index"},
#         {"name": "Marketing Campaign Results"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "MNIST": "Full",
#         "Credit": "Full",
#         "Bank": "Full"
#     }
# }
# ```
# Processing paper: DorPatch: Distributed and Occlusion-Robust
# {
#     "title": "DorPatch: Distributed and Occlusion-Robust Adversarial Patch to Evade Certifiable Defenses"
# }
# ```json
# {
#     "authors": "Chaoxiang He, Xiaojing Ma, Bin B. Zhu, Yimiao Zeng, Hanqing Hu, Xiaofan Bai, Hai Jin, Dongmei Zhang"
# }
# ```
# ```json
# {
#     "conference": "NDSS"
# }
# ```
# ```json
# {
#     "year": "2024"
# }
# ```
# ```json
# {
#     "school": "Huazhong University of Science and Technology, Microsoft"
# }
# ```
# ```json
# {
#     "research_domain": "adversarial machine learning"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: Differentially Private Publishing of High-dimensional Data
# {
#     "title": "Differentially Private Publishing of High-dimensional Data Using Sensitivity Control"
# }
# ```json
# {
#     "authors": "Wei-Y en Day, Ninghui Li"
# }
# ```
# ```json
# {
#     "conference": "ASIA CCS"
# }
# ```
# ```json
# {
#     "year": "2015"
# }
# ```
# ```json
# {
#     "school": "Purdue University"
# }
# ```
# ```json
# {
#     "research_domain": "privacy-preserving computation"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Netflix",
#             "contributors": "Netflix",
#             "doi": "",
#             "url": "http://www.netflixprize.com/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Transaction",
#             "contributors": "KDD-cup 2000",
#             "doi": "",
#             "url": "http://www.kdd.org/kdd-cup-2000-online-retailer-website-clickstream-analysis"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Movielens",
#             "contributors": "GroupLens Research",
#             "doi": "",
#             "url": "http://grouplens.org/datasets/movielens/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Document",
#             "contributors": "PubMed",
#             "doi": "",
#             "url": "http://archive.ics.uci.edu/ml/datasets/Bag+of+Words"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "AOL",
#             "contributors": "AOL",
#             "doi": "",
#             "url": "http://www.cim.mcgill.ca/~dudek/206/Logs/AOL-user-ct-collection/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Kosarak",
#             "contributors": "Hungarian news portal",
#             "doi": "",
#             "url": "http://fimi.ua.ac.be/data/kosarak.dat"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Netflix",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Transaction",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Movielens",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Document",
#             "availability": "public",
#             "labeling_type": "unlabeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "AOL",
#             "availability": "public",
#             "labeling_type": "unlabeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Kosarak",
#             "availability": "public",
#             "labeling_type": "unlabeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Netflix",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "User ratings of movies"}
#       ]
#     },
#     {
#       "dataset_name": "Transaction",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "User purchases"}
#       ]
#     },
#     {
#       "dataset_name": "Movielens",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "User ratings of movies"}
#       ]
#     },
#     {
#       "dataset_name": "Document",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Medical document contents"}
#       ]
#     },
#     {
#       "dataset_name": "AOL",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "User search queries"}
#       ]
#     },
#     {
#       "dataset_name": "Kosarak",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "User clickstream data"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Netflix": "Full",
#         "Transaction": "Full",
#         "Movielens": "Full",
#         "Document": "Full",
#         "AOL": "Full",
#         "Kosarak": "Full"
#     }
# }
# ```
# Processing paper: 27 Years and 81 Million Opportunities Later:
# {
#     "title": "27 Years and 81 Million Opportunities Later: Investigating the Use of Email Encryption for an Entire University"
# }
# ```json
# {
#     "authors": "Christian Stransky, Oliver Wiesey, Volker Rothy, Yasemin Acar, Sascha Fahl"
# }
# ```
# ```json
# {
#     "conference": "SP"
# }
# ```
# ```json
# {
#     "year": "2022"
# }
# ```
# {
#     "school": "Leibniz University Hannover, Freie Universität Berlin, Max Planck Institute for Security and Privacy, CISPA Helmholtz-Center for Information Security"
# }
# ```json
# {
#     "research_domain": "email encryption"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Email dataset",
#             "contributors": "Christian Stransky, Oliver Wiese, Volker Roth, Yasemin Acar, Sascha Fahl",
#             "doi": "10.1109/SP46214.2022.00012",
#             "url": "https://publications.teamusec.de/2022-oakland-email/"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Email dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "not mentioned",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Email dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "Email communication"},
#         {"name": "Use of S/MIME"},
#         {"name": "Use of PGP"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": "Full"
# }
# ```
# Processing paper: 28 Blinks Later: Tackling Practical Challenges of
# {
#     "title": "28 Blinks Later: Tackling Practical Challenges of Eye Movement Biometrics"
# }
# ```json
# {
#     "authors": "Simon Eberz, Giulio Lovisotto, Kasper B. Rasmussen, Vincent Lenders, Ivan Martinovic"
# }
# ```
# {
#     "conference": "CCS"
# }
# ```json
# {
#     "year": "2019"
# }
# ```
# ```json
# {
#     "school": "University of Oxford, armasuisse"
# }
# ```
# ```json
# {
#     "research_domain": "biometrics"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Eye Movement Dataset",
#             "contributors": "Simon Eberz, Giulio Lovisotto, Kasper B. Rasmussen, Vincent Lenders, Ivan Martinovic",
#             "doi": "",
#             "url": "https://simonizor.github.io/28blinkslater"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Eye Movement Dataset",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Eye Movement Dataset",
#       "category": "User & Organizational Characteristics",
#       "subcategory": "User Activities",
#       "user_activities_items": [
#         {"name": "Eye movement data from participants"},
#         {"name": "Data collected under varying tasks and lighting conditions"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": "Full"
# }
# ```
# Processing paper: High Fidelity Data Reduction for Big Data Security
# {
#     "title": "High Fidelity Data Reduction for Big Data Security Dependency Analyses"
# }
# ```json
# {
#     "authors": "Zhang Xuy, Zhenyu Wu, Zhichun Li, Kangkook Jee, Junghwan Rhee, Xusheng Xiao, Fengyuan Xu, Haining Wang, Guofei Jiang"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2016"
# }
# ```
# ```json
# {
#     "school": "NofutzNetworks Inc., NEC Labs America, Nanjing University, University of Delaware"
# }
# ```
# ```json
# {
#     "research_domain": "big data security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Real-world auditing systems log traces",
#             "contributors": "Zhang Xu, Zhenyu Wu, Zhichun Li, Kangkook Jee, Junghwan Rhee, Xusheng Xiao, Fengyuan Xu, Haining Wang, Guofei Jiang",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Real-world auditing systems log traces",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "Not Mentioned",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Real-world auditing systems log traces",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "System event logs"},
#         {"name": "Audit logs"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": "Full"
# }
# ```
# Processing paper: Identifying Open-Source License Violation and 1-day Security
# ```json
# {
#     "title": "Identifying Open-Source License Violation and 1-day Security Risk at Large Scale"
# }
# ```
# ```json
# {
#     "authors": "Ruian Duan, Ashish Bijlani, Meng Xu, Taesoo Kim, Wenke Lee"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2017"
# }
# ```
# {
#     "school": "Georgia Institute of Technology"
# }
# ```json
# {
#     "research_domain": "information security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "C/C++ OSS Collection",
#             "contributors": "Ruian Duan, Ashish Bijlani, Meng Xu, Taesoo Kim, Wenke Lee",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Java OSS Collection",
#             "contributors": "Ruian Duan, Ashish Bijlani, Meng Xu, Taesoo Kim, Wenke Lee",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "FDroid Apps",
#             "contributors": "Ruian Duan, Ashish Bijlani, Meng Xu, Taesoo Kim, Wenke Lee",
#             "doi": "",
#             "url": "https://f-droid.org"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "C/C++ OSS Collection",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Java OSS Collection",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "FDroid Apps",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "C/C++ OSS Collection",
#       "category": "attacker_related",
#       "subcategory": "vulnerabilities",
#       "attacker_related_items": [
#         {"name": "GPL Violations"},
#         {"name": "AGPL Violations"}
#       ]
#     },
#     {
#       "dataset_name": "Java OSS Collection",
#       "category": "attacker_related",
#       "subcategory": "vulnerabilities",
#       "attacker_related_items": [
#         {"name": "GPL Violations"},
#         {"name": "AGPL Violations"}
#       ]
#     },
#     {
#       "dataset_name": "FDroid Apps",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activities_items": [
#         {"name": "App Usage Data"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "C/C++ OSS Collection": "Full",
#         "Java OSS Collection": "Full",
#         "FDroid Apps": "Full"
#     }
# }
# ```
# Processing paper: POISED: Spotting Twitter Spam Off the Beaten Paths
# {
#     "title": "POISED: Spotting Twitter Spam Off the Beaten Paths"
# }
# ```json
# {
#     "authors": "Shirin Nilizadeh, François Labrèche, Alireza Sedighian, Ali Zand, José Fernandez, Christopher Kruegel, Gianluca Stringhini, Giovanni Vigna"
# }
# ```
# ```json
# {
#     "conference": "CCS"
# }
# ```
# ```json
# {
#     "year": "2017"
# }
# ```
# ```json
# {
# ...
# }
# ```json
# {
#     "research_domain": "web application security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Close world multi-tab dataset",
#             "contributors": "Zhong Guan, Gang Xiong, Gaopeng Gou, Zhen Li, Mingxin Cui, Chang Liu",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Open world multi-tab dataset",
#             "contributors": "Zhong Guan, Gang Xiong, Gaopeng Gou, Zhen Li, Mingxin Cui, Chang Liu",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Three-tab dataset",
#             "contributors": "Zhong Guan, Gang Xiong, Gaopeng Gou, Zhen Li, Mingxin Cui, Chang Liu",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Real world multi-tab dataset",
#             "contributors": "Zhong Guan, Gang Xiong, Gaopeng Gou, Zhen Li, Mingxin Cui, Chang Liu",
#             "doi": "",
#             "url": "https://drive.google.com/drive/folders/1vfE34oYICpSnNMVvxfeVfcWzBooqAQfR?usp=sharing"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Close world multi-tab dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Open world multi-tab dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Three-tab dataset",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Real world multi-tab dataset",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Close world multi-tab dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activity_items": [
#         {"name": "Multi-tab browsing behavior"}
#       ]
#     },
#     {
#       "dataset_name": "Open world multi-tab dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activity_items": [
#         {"name": "Multi-tab browsing behavior"}
#       ]
#     },
#     {
#       "dataset_name": "Three-tab dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activity_items": [
#         {"name": "Multi-tab browsing behavior"}
#       ]
#     },
#     {
#       "dataset_name": "Real world multi-tab dataset",
#       "category": "user_and_organizational_characteristics",
#       "subcategory": "user_activities",
#       "user_activity_items": [
#         {"name": "Multi-tab browsing behavior"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Close world multi-tab dataset": "Full",
#         "Open world multi-tab dataset": "Full",
#         "Three-tab dataset": "Full",
#         "Real world multi-tab dataset": "Full"
#     }
# }
# ```
# Processing paper: CommanderGabble: A Universal Attack
# {
#     "title": "CommanderGabble: A Universal Attack Against ASR Systems Leveraging Fast Speech"
# }
# {
#     "authors": "Zhaohe Zhang, Edwin Yang, Song Fang"
# }
# {
#     "conference": "ACSAC"
# }
# {
#     "year": "2021"
# }
# ```json
# {
#     "school": "University of Oklahoma"
# }
# ```
# ```json
# {
#     "research_domain": "adversarial machine learning"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: An Exploration of ARM System-Level Cache and GPU Side
# {
#     "title": "An Exploration of ARM System-Level Cache and GPU Side Channels"
# }
# ```json
# {
#     "authors": "Patrick Cronin, Xing Gao, Haining Wang, Chase Cotton"
# }
# ```
# {
#     "conference": "ACSAC"
# }
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "University of Delaware, Virginia Tech"
# }
# ```
# ```json
# {
#     "research_domain": "embedded systems security"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Abbreviated Open World Dataset",
#             "contributors": "Patrick Cronin, Xing Gao, Haining Wang, Chase Cotton",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Larger Dataset for Evaluation",
#             "contributors": "Patrick Cronin, Xing Gao, Haining Wang, Chase Cotton",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Abbreviated Open World Dataset",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Larger Dataset for Evaluation",
#             "availability": "Custom-created datasets but public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Abbreviated Open World Dataset",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Website Fingerprinting"}
#       ]
#     },
#     {
#       "dataset_name": "Larger Dataset for Evaluation",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Website Fingerprinting"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Abbreviated Open World Dataset": "Full",
#         "Larger Dataset for Evaluation": "Full"
#     }
# }
# ```
# Processing paper: Two Souls in an Adversarial Image: Towards
# {
#     "title": "Two Souls in an Adversarial Image: Towards Universal Adversarial Example Detection using Multi-view Inconsistency"
# }
# {
#     "authors": "Sohaib Kiani, Sana Awan, Chao Lan, Fengjun Li, Bo Luo"
# }
# {
#     "conference": "ACSAC"
# }
# ```json
# {
#     "year": "2021"
# }
# ```
# {
#     "school": "The University of Kansas, The University of Oklahoma"
# }
# ```json
# {
#     "research_domain": "adversarial machine learning"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "GTSRB",
#             "contributors": "J. Stallkamp, M. Schlipsing, J. Salmen, C. Igel",
#             "doi": "",
#             "url": "http://benchmark.ini.rub.de/?section=gtsrb&subsection=news"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "R-ImageNet",
#             "contributors": "Not specified",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "CIFAR10",
#             "contributors": "Alex Krizhevsky",
#             "doi": "",
#             "url": "https://www.cs.toronto.edu/~kriz/cifar.html"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "GTSRB",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "R-ImageNet",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "CIFAR10",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "GTSRB",
#       "category": "visual_and_multimedia_data",
#       "subcategory": "image_datasets",
#       "visual_data_items": [
#         {"name": "Traffic Sign Recognition"}
#       ]
#     },
#     {
#       "dataset_name": "R-ImageNet",
#       "category": "visual_and_multimedia_data",
#       "subcategory": "image_datasets",
#       "visual_data_items": [
#         {"name": "Image Classification"}
#       ]
#     },
#     {
#       "dataset_name": "CIFAR10",
#       "category": "visual_and_multimedia_data",
#       "subcategory": "image_datasets",
#       "visual_data_items": [
#         {"name": "Image Classification"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "GTSRB": "Full",
#         "R-ImageNet": "Full",
#         "CIFAR10": "Full"
#     }
# }
# ```
# Processing paper: Can We Leverage Predictive Uncertainty to Detect Dataset Shift
# {
#     "title": "Can We Leverage Predictive Uncertainty to Detect Dataset Shift and Adversarial Examples in Android Malware Detection?"
# }
# ```json
# {
#     "authors": "Deqiang Li, Tian Qiu, Shuo Chen, Qianmu Li, Shouhuai Xu"
# }
# ```
# ```json
# {
#     "conference": "ACSAC"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "Nanjing University of Science and Technology, RIKEN, University of Colorado Colorado Springs"
# }
# ```
# ```json
# {
#     "research_domain": "malware analysis and detection"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Drebin",
#             "contributors": "Daniel Arp, Michael Spreitzenbarth, Malte Hubner, Hugo Gascon, and Konrad Rieck",
#             "doi": "",
#             "url": "https://www.ndss-symposium.org/wp-content/uploads/2017/09/11_3_1.pdf"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "VirusShare",
#             "contributors": "Forensics Corvus",
#             "doi": "",
#             "url": "https://virusshare.com/"
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Androzoo",
#             "contributors": "Kevin Allix, Tegawendé F. Bissyandé, et al.",
#             "doi": "",
#             "url": "https://androzoo.uni.lu/"
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Drebin",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "VirusShare",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Androzoo",
#             "availability": "public",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Drebin",
#       "category": "attacker_related",
#       "subcategory": "exploits",
#       "attacker_related_items": [
#         {"name": "Malware Detection"},
#         {"name": "Android Malware"}
#       ]
#     },
#     {
#       "dataset_name": "VirusShare",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Malware Samples"}
#       ]
#     },
#     {
#       "dataset_name": "Androzoo",
#       "category": "attacker_related",
#       "subcategory": "attacks",
#       "attacker_related_items": [
#         {"name": "Malware Samples"},
#         {"name": "Android APKs"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Drebin": "Full",
#         "VirusShare": "Full",
#         "Androzoo": "Full"
#     }
# }
# ```
# Processing paper: SODA: A System for Cyber Deception Orchestration and
# {
#     "title": "SODA: A System for Cyber Deception Orchestration and Automation"
# }
# ```json
# {
#     "authors": "Md Sajidul Islam Sajid, Jinpeng Wei, Basel Abdeen, Ehab Al-Shaer, Md Mazharul Islam, Walter Diong, Latifur Khan"
# }
# ```
# ```json
# {
#     "conference": "ACSAC"
# }
# ```
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "University of North Carolina at Charlotte, University of Texas at Dallas, Carnegie Mellon University"
# }
# ```
# ```json
# {
#     "research_domain": "malware analysis and detection"
# }
# ```
# ```json
# {
#     "datasets": [
#         {
#             "unique_id": "null",
#             "dataset_name": "Malware Samples",
#             "contributors": "Md Sajidul Islam Sajid, Jinpeng Wei, Basel Abdeen, Ehab Al-Shaer, Md Mazharul Islam, Walter Diong, Latifur Khan",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Ground Truth (GT1)",
#             "contributors": "Md Sajidul Islam Sajid, Ehab Al-Shaer",
#             "doi": "",
#             "url": ""
#         },
#         {
#             "unique_id": "null",
#             "dataset_name": "Ground Truth (GT2)",
#             "contributors": "Md Sajidul Islam Sajid, Ehab Al-Shaer",
#             "doi": "",
#             "url": ""
#         }
#     ]
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": [
#         {
#             "dataset_name": "Malware Samples",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "real-world"
#         },
#         {
#             "dataset_name": "Ground Truth (GT1)",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         },
#         {
#             "dataset_name": "Ground Truth (GT2)",
#             "availability": "Custom-created datasets, not shared",
#             "labeling_type": "labeled",
#             "dataset_type": "realistic"
#         }
#     ]
# }
# ```
# ```json
# {
#   "dataset_categories": [
#     {
#       "dataset_name": "Malware Samples",
#       "category": "attacker_related",
#       "subcategory": "exploits",
#       "attacker_related_items": [
#         {"name": "Information Stealers"},
#         {"name": "Ransomware"},
#         {"name": "Remote Access Trojans (RATs)"}
#       ]
#     },
#     {
#       "dataset_name": "Ground Truth (GT1)",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Malware Behavior Identification"}
#       ]
#     },
#     {
#       "dataset_name": "Ground Truth (GT2)",
#       "category": "defender_artifacts",
#       "subcategory": "alerts",
#       "defender_artifacts_items": [
#         {"name": "Remote Access Trojan Behavior"}
#       ]
#     }
#   ]
# }
# ```
# ```json
# {
#     "dataset_utilization": {
#         "Malware Samples": "Full",
#         "Ground Truth (GT1)": "Full",
#         "Ground Truth (GT2)": "Full"
#     }
# }
# ```
# Processing paper: TEEKAP : Self-Expiring Data Capsule using
# {
#     "title": "TEEKAP : Self-Expiring Data Capsule using Trusted Execution Environment"
# }
# ```json
# {
#     "authors": "Mingyuan Gao, Hung Dang, Ee-Chien Chang"
# }
# ```
# ```json
# {
#     "conference": "ACSAC"
# }
# ```
# {
#     "year": "2021"
# }
# {
#     "school": "National University of Singapore, IRICS"
# }
# ```json
# {
#     "research_domain": "privacy-preserving computation"
# }
# ```
# {
#     "datasets": null
# }
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```
# Processing paper: Try before You Buy: Privacy-preserving Data Evaluation on
# {
#     "title": "Try before You Buy: Privacy-preserving Data Evaluation on Cloud-based Machine Learning Data Marketplace"
# }
# {
#     "authors": "Qiyang Song, Jiahao Cao, Kun Sun, Qi Li, Ke Xu"
# }
# {
#     "conference": "ACSAC"
# }
# ```json
# {
#     "year": "2021"
# }
# ```
# ```json
# {
#     "school": "Center for Secure Information Systems, George Mason University, Tsinghua University, Institute for Network Sciences and Cyberspace & BNRist, Tsinghua University"
# }
# ```
# ```json
# {
#     "research_domain": "privacy-preserving computation"
# }
# ```
# ```json
# {
#     "datasets": null
# }
# ```
# ```json
# {
#     "dataset_analysis_combined": null
# }
# ```
# ```json
# {
#   "dataset_categories": null
# }
# ```
# ```json
# {
#     "dataset_utilization": null
# }
# ```

# %% [markdown]
# CSV OUTPUT

# %%
import csv

# Define the tasks as headers
tasks = [ 
    "title", 
    "authors_name", 
    "conference_name", 
    "published_year", 
    "school_institution", 
    "domain", 
    "dataset_name", 
    "dataset_analysis_combined", 
    "dataset_categories", 
    "dataset_usage"
]

# File path for the CSV output
output_csv_path = 'results_test.csv'

# Open a new CSV file
with open(output_csv_path, 'w', newline='', encoding='utf-8') as file:
    csv_writer = csv.writer(file)
    # Write the header
    csv_writer.writerow(tasks)

    # Iterate over each paper and its corresponding results
    for _, results in all_results.items():  # Remove the paper_title reference
        # Prepare a row based on task results
        row = []
        # Append each task result to the row in the order of the tasks list
        for task in tasks:
            task_result = results.get(task, "No result")
            if isinstance(task_result, dict) or isinstance(task_result, list):
                task_result = json.dumps(task_result)  # Convert dict or list to string for CSV
            row.append(task_result)
        # Write the completed row to the CSV file
        csv_writer.writerow(row)

print(f"Results have been written to {output_csv_path}")
# Out:
# Results have been written to results_test.csv

# %% [markdown]
# "Accuracy Evaluation: 95% Confidence Interval"

# %%
from statsmodels.stats.proportion import proportion_confint

# Inputs for TP, FP, FN, TN
TP = 76
FP = 1
FN = 1
TN = 23

# Total predictions (n) and correct predictions (x)
n = TP + FP + FN + TN  # Total number of predictions
x = TP + TN            # Correct predictions

# Calculate 95% Clopper-Pearson Confidence Interval
ci_low, ci_high = proportion_confint(count=x, nobs=n, alpha=0.05, method='beta')

# Print the results
print(f"95% Confidence Interval for Accuracy: ({ci_low:.4f}, {ci_high:.4f})")
